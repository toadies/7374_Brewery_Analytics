# %%
from dotenv import load_dotenv
import urllib.parse as urlparse
import requests
import json
import os
from datetime import datetime

class Untappd:

    def __init__(self, clientId = "", clientSecret = ""):
        load_dotenv(dotenv_path="../.env")
        self._clientId = os.getenv("CLIENT_ID")
        self._clientSecret = os.getenv("CLIENT_SECRET")
        self._baseUrl = "https://api.untappd.com/v4/"


    def keys(self):
        return {
            "client_id": self._clientId,
            "client_secret": self._clientSecret
        }

    def findBrewery(self, brewery="", writeFile=False):
        methodUrl = self._baseUrl + "search/brewery"
        params = {
            "q": brewery
        }
        requestUrl = methodUrl + "?" + urlparse.urlencode({**params, **self.keys()})
        response = requests.get(requestUrl)
        
        headers = response.headers
        counter = int(headers["X-Ratelimit-Remaining"])
        breweries = [] 
        
        if response.status_code == 200:
            content = response.json()
            
            
            if content["response"]["found"] > 0:
                breweries = content["response"]["brewery"]["items"]
        
        return breweries, counter, response
    
    def breweryInfo(self, breweryId="", writeFile=False):
        methodUrl = self._baseUrl + "brewery/info/"
        requestUrl = methodUrl + str(breweryId) + "?" + urlparse.urlencode(self.keys())
        response = requests.get(requestUrl)
        
        headers = response.headers
        counter = int(headers["X-Ratelimit-Remaining"])
        
        if response.status_code == 200:
            content = response.json()

        return content["response"], counter, response

# %% [markdown]
# ### Create a brewery dataset

# %%
import numpy as np
import pandas as pd
import pickle

try:
    with open ("../data/all_breweries.pkl", "rb") as fp:
        all_breweries = pickle.load(fp)
except:
    print( "No file existed, creating one!" )
    breweries = pd.read_csv("../data/Texas Breweries.csv")
    brewpubs = pd.read_csv("../data/Texas Brewpubs.csv")
    brewery_list = list(breweries.T.to_dict().values())
    all_breweries = brewery_list + list( brewpubs.T.to_dict().values() )

    #remove duplicates
    brewery_count = pd.DataFrame(all_breweries).groupby(["Name"])["Status"].count()
    dups = brewery_count.loc[ brewery_count > 1].reset_index()
    dups = dups["Name"].to_list()
    print("Duplicates to be removed", dups)
    brewery_parsed = [ brewery for brewery in all_breweries if brewery["Name"] not in dups ]

    #Make name searchable
    for brewery in all_breweries:
        brewery["Name"] = brewery["Name"].replace("Company","")
        brewery["Name"] = brewery["Name"].replace(".","")
        brewery["Name"] = brewery["Name"].replace("&"," ")
        brewery["Name"] = brewery["Name"].replace("Cooperative","")
    
    with open('../data/all_breweries.pkl', 'wb') as fp:
        pickle.dump(all_breweries, fp)
        
  
display( all_breweries[0:2] )
# Out:
# [{'Name': '111 Brewing',
#   'Street Address': 111,
#   'Road': 'S FANNIN AVENUE',
#   'City': 'DENISON',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '4/10/2019',
#   'Status': 'In the works',
#   'untappd': [{'brewery': {'brewery_id': 66888,
#      'beer_count': 65,
#      'brewery_name': 'Milepost 111 Brewing Company',
#      'brewery_slug': 'milepost-111-brewing-company',
#      'brewery_page_url': '/milepostbeer',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-Milepost111_66888_590e6.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Cashmere',
#       'brewery_state': 'WA',
#       'lat': 47.5244,
#       'lng': -120.47}}}]},
#  {'Name': '2 Docs Brewing Co',
#   'Street Address': 502,
#   'Road': 'TEXAS AVENUE',
#   'City': 'LUBBOCK',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '10/5/2018',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 420745,
#      'beer_count': 22,
#      'brewery_name': 'Two Docs Brewing Co.',
#      'brewery_slug': 'two-docs-brewing-co',
#      'brewery_page_url': '/TwoDocsBrewingCo',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Lubbock',
#       'brewery_state': 'TX',
#       'lat': 33.5909,
#       'lng': -101.846}}}],
#   'brewery_id': 420745,
#   'brewery_info': {'brewery': {'brewery_id': 420745,
#     'brewery_name': 'Two Docs Brewing Co.',
#     'brewery_slug': 'two-docs-brewing',
#     'brewery_page_url': '/TwoDocsBrewingCo',
#     'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#     'brewery_label_hd': '',
#     'country_name': 'United States',
#     'brewery_in_production': 0,
#     'is_independent': 1,
#     'claimed_status': {'is_claimed': True,
#      'claimed_slug': 'TwoDocsBrewingCo',
#      'follow_status': False,
#      'follower_count': 72,
#      'uid': 6376655,
#      'mute_status': 'none'},
#     'beer_count': 22,
#     'contact': {'twitter': '',
#      'facebook': 'https://www.facebook.com/twodocsbrewing',
#      'instagram': 'twodocsbrewing',
#      'url': 'https://twodocsbrewing.com/'},
#     'brewery_type': 'Micro Brewery',
#     'brewery_type_id': 2,
#     'location': {'brewery_address': '502 Texas Ave',
#      'brewery_city': 'Lubbock',
#      'brewery_state': 'TX',
#      'brewery_lat': 33.5909,
#      'brewery_lng': -101.846},
#     'rating': {'count': 1943, 'rating_score': 3.791},
#     'brewery_description': 'We want to share our love of craft beer with West Texas. When you come into our taproom an expert staff will welcome you to a place where you can explore beer, expand your tastes, and have a great time.',
#     'stats': {'total_count': 2400,
#      'unique_count': 711,
#      'monthly_count': 153,
#      'weekly_count': 0,
#      'user_count': 0,
#      'age_on_service': 271.9091550925926},
#     'owners': {'count': 0, 'items': []},
#     'media': {'count': 15,
#      'items': [{'photo_id': 261142284,
#        'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_29/233f0ee846113f965095404c85eb37a2_200x200.jpg',
#         'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_29/233f0ee846113f965095404c85eb37a2_640x640.jpg',
#         'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_29/233f0ee846113f965095404c85eb37a2_1280x1280.jpg',
#         'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_29/233f0ee846113f965095404c85eb37a2_raw.jpg'},
#        'created_at': 'Tue, 29 Oct 2019 00:03:24 +0000',
#        'checkin_id': 823141672,
#        'beer': {'bid': 3408493,
#         'beer_name': 'Hayes-E Baby IPA',
#         'beer_abv': 7.1,
#         'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#         'beer_style': 'IPA - New England'},
#        'brewery': {'brewery_id': 420745,
#         'brewery_name': 'Two Docs Brewing Co.',
#         'brewery_slug': 'two-docs-brewing',
#         'brewery_page_url': '/TwoDocsBrewingCo',
#         'brewery_type': 'Micro Brewery',
#         'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#         'country_name': 'United States',
#         'contact': {'twitter': '',
#          'facebook': 'https://www.facebook.com/twodocsbrewing',
#          'instagram': 'twodocsbrewing',
#          'url': 'https://twodocsbrewing.com/'},
#         'location': {'brewery_city': 'Lubbock',
#          'brewery_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'brewery_active': 1},
#        'user': {'uid': 1129994,
#         'user_name': 'Mikegib',
#         'first_name': 'Michael',
#         'last_name': 'G',
#         'user_avatar': 'https://untappd.akamaized.net/profile/8e268bea2010265abea610af88cbdbe7_100x100.jpg',
#         'is_private': 0},
#        'venue': {'venue_id': 9090786,
#         'venue_name': 'Growler USA - Lubbock',
#         'venue_slug': 'growler-usa-lubbock',
#         'primary_category': 'Food',
#         'parent_category_id': '4d4b7105d754a06374d81259',
#         'categories': {'count': 1,
#          'items': [{'category_key': 'restaurant',
#            'category_name': 'Restaurant',
#            'category_id': '4bf58dd8d48988d1c4941735',
#            'is_primary': True}]},
#         'location': {'venue_address': '6030 Marsha Sharp Fwy, Suite 200',
#          'venue_city': 'Lubbock',
#          'venue_state': 'TX',
#          'lat': 33.5485,
#          'lng': -101.95},
#         'contact': {'twitter': '@GrowlerLubbock',
#          'venue_url': 'Growlerusa.com/Lubbock'},
#         'foursquare': {'foursquare_id': '5d10ed17de944500235ea31d',
#          'foursquare_url': 'https://4sq.com/2LcGU91'},
#         'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_9090786_674f03d3_bg_64.png',
#          'md': 'https://untappd.akamaized.net/venuelogos/venue_9090786_674f03d3_bg_88.png',
#          'lg': 'https://untappd.akamaized.net/venuelogos/venue_9090786_674f03d3_bg_176.png?v=1'},
#         'is_verified': 1}},
#       {'photo_id': 261057600,
#        'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_28/568310a2ebafd3160a91198fea23db06_200x200.jpg',
#         'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_28/568310a2ebafd3160a91198fea23db06_640x640.jpg',
#         'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_28/568310a2ebafd3160a91198fea23db06_1280x1280.jpg',
#         'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_28/568310a2ebafd3160a91198fea23db06_raw.jpg'},
#        'created_at': 'Mon, 28 Oct 2019 00:20:38 +0000',
#        'checkin_id': 822940561,
#        'beer': {'bid': 3408493,
#         'beer_name': 'Hayes-E Baby IPA',
#         'beer_abv': 7.1,
#         'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#         'beer_style': 'IPA - New England'},
#        'brewery': {'brewery_id': 420745,
#         'brewery_name': 'Two Docs Brewing Co.',
#         'brewery_slug': 'two-docs-brewing',
#         'brewery_page_url': '/TwoDocsBrewingCo',
#         'brewery_type': 'Micro Brewery',
#         'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#         'country_name': 'United States',
#         'contact': {'twitter': '',
#          'facebook': 'https://www.facebook.com/twodocsbrewing',
#          'instagram': 'twodocsbrewing',
#          'url': 'https://twodocsbrewing.com/'},
#         'location': {'brewery_city': 'Lubbock',
#          'brewery_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'brewery_active': 1},
#        'user': {'uid': 3203713,
#         'user_name': 'gpkennedy',
#         'first_name': 'Gabriel',
#         'last_name': 'K',
#         'user_avatar': 'https://untappd.akamaized.net/profile/02337b9a1b7b3852c11c8922b8b3d13a_100x100.jpg',
#         'is_private': 0},
#        'venue': {'venue_id': 8707470,
#         'venue_name': 'Two Docs Brewing Co.',
#         'venue_slug': 'two-docs-brewing-co',
#         'primary_category': 'Nightlife Spot',
#         'parent_category_id': '4d4b7105d754a06376d81259',
#         'categories': {'count': 1,
#          'items': [{'category_key': 'brewery',
#            'category_name': 'Brewery',
#            'category_id': '50327c8591d4c4b30a586d5d',
#            'is_primary': True}]},
#         'location': {'venue_address': '502 Texas Ave',
#          'venue_city': 'Lubbock',
#          'venue_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#         'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#          'foursquare_url': 'https://4sq.com/2IJTFbR'},
#         'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#          'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#          'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#         'is_verified': 1}},
#       {'photo_id': 261031935,
#        'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photo/2019_10_27/84cd98d68bd9eed8e7c0f1abd3f9b6ed_c_822872119_200x200.jpg',
#         'photo_img_md': 'https://untappd.akamaized.net/photo/2019_10_27/84cd98d68bd9eed8e7c0f1abd3f9b6ed_c_822872119_640x640.jpg',
#         'photo_img_lg': 'https://untappd.akamaized.net/photo/2019_10_27/84cd98d68bd9eed8e7c0f1abd3f9b6ed_c_822872119_1280x1280.jpg',
#         'photo_img_og': 'https://untappd.akamaized.net/photo/2019_10_27/84cd98d68bd9eed8e7c0f1abd3f9b6ed_c_822872119_raw.jpg'},
#        'created_at': 'Sun, 27 Oct 2019 21:52:57 +0000',
#        'checkin_id': 822872119,
#        'beer': {'bid': 3440110,
#         'beer_name': 'Doktoberfest',
#         'beer_abv': 6.1,
#         'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#         'beer_style': 'Festbier'},
#        'brewery': {'brewery_id': 420745,
#         'brewery_name': 'Two Docs Brewing Co.',
#         'brewery_slug': 'two-docs-brewing',
#         'brewery_page_url': '/TwoDocsBrewingCo',
#         'brewery_type': 'Micro Brewery',
#         'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#         'country_name': 'United States',
#         'contact': {'twitter': '',
#          'facebook': 'https://www.facebook.com/twodocsbrewing',
#          'instagram': 'twodocsbrewing',
#          'url': 'https://twodocsbrewing.com/'},
#         'location': {'brewery_city': 'Lubbock',
#          'brewery_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'brewery_active': 1},
#        'user': {'uid': 1242913,
#         'user_name': 'fthames',
#         'first_name': 'Frank',
#         'last_name': 'T',
#         'user_avatar': 'https://untappd.akamaized.net/profile/493c1601aacb58f0a4b764b93d780b51_100x100.jpg',
#         'is_private': 0},
#        'venue': {'venue_id': 8707470,
#         'venue_name': 'Two Docs Brewing Co.',
#         'venue_slug': 'two-docs-brewing-co',
#         'primary_category': 'Nightlife Spot',
#         'parent_category_id': '4d4b7105d754a06376d81259',
#         'categories': {'count': 1,
#          'items': [{'category_key': 'brewery',
#            'category_name': 'Brewery',
#            'category_id': '50327c8591d4c4b30a586d5d',
#            'is_primary': True}]},
#         'location': {'venue_address': '502 Texas Ave',
#          'venue_city': 'Lubbock',
#          'venue_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#         'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#          'foursquare_url': 'https://4sq.com/2IJTFbR'},
#         'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#          'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#          'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#         'is_verified': 1}},
#       {'photo_id': 260736276,
#        'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_26/36a735bfcb51f5b43464a2407f6e6f4a_200x200.jpg',
#         'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_26/36a735bfcb51f5b43464a2407f6e6f4a_640x640.jpg',
#         'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_26/36a735bfcb51f5b43464a2407f6e6f4a_1280x1280.jpg',
#         'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_26/36a735bfcb51f5b43464a2407f6e6f4a_raw.jpg'},
#        'created_at': 'Sat, 26 Oct 2019 19:22:30 +0000',
#        'checkin_id': 822145054,
#        'beer': {'bid': 3209433,
#         'beer_name': 'Dos Doctores',
#         'beer_abv': 5.4,
#         'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#         'beer_style': 'Lager - Vienna'},
#        'brewery': {'brewery_id': 420745,
#         'brewery_name': 'Two Docs Brewing Co.',
#         'brewery_slug': 'two-docs-brewing',
#         'brewery_page_url': '/TwoDocsBrewingCo',
#         'brewery_type': 'Micro Brewery',
#         'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#         'country_name': 'United States',
#         'contact': {'twitter': '',
#          'facebook': 'https://www.facebook.com/twodocsbrewing',
#          'instagram': 'twodocsbrewing',
#          'url': 'https://twodocsbrewing.com/'},
#         'location': {'brewery_city': 'Lubbock',
#          'brewery_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'brewery_active': 1},
#        'user': {'uid': 2109800,
#         'user_name': 'Jdlbk',
#         'first_name': 'Jess',
#         'last_name': 'W',
#         'user_avatar': 'https://gravatar.com/avatar/26951d2bdb4acfcb18b10ab0b2a7ea4a?size=100&d=https%3A%2F%2Funtappd.akamaized.net%2Fsite%2Fassets%2Fimages%2Fdefault_avatar_v3_gravatar.jpg%3Fv%3D2',
#         'is_private': 0},
#        'venue': {'venue_id': 8707470,
#         'venue_name': 'Two Docs Brewing Co.',
#         'venue_slug': 'two-docs-brewing-co',
#         'primary_category': 'Nightlife Spot',
#         'parent_category_id': '4d4b7105d754a06376d81259',
#         'categories': {'count': 1,
#          'items': [{'category_key': 'brewery',
#            'category_name': 'Brewery',
#            'category_id': '50327c8591d4c4b30a586d5d',
#            'is_primary': True}]},
#         'location': {'venue_address': '502 Texas Ave',
#          'venue_city': 'Lubbock',
#          'venue_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#         'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#          'foursquare_url': 'https://4sq.com/2IJTFbR'},
#         'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#          'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#          'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#         'is_verified': 1}},
#       {'photo_id': 260725438,
#        'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_26/d1f0ceddf29f2ac76a93a31d5e16f173_200x200.jpg',
#         'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_26/d1f0ceddf29f2ac76a93a31d5e16f173_640x640.jpg',
#         'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_26/d1f0ceddf29f2ac76a93a31d5e16f173_1280x1280.jpg',
#         'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_26/d1f0ceddf29f2ac76a93a31d5e16f173_raw.jpg'},
#        'created_at': 'Sat, 26 Oct 2019 19:00:20 +0000',
#        'checkin_id': 822119811,
#        'beer': {'bid': 3063015,
#         'beer_name': 'Prairie Dawg Porter',
#         'beer_abv': 5.9,
#         'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-3063015_38cdd_sm.jpeg',
#         'beer_style': 'Porter - American'},
#        'brewery': {'brewery_id': 420745,
#         'brewery_name': 'Two Docs Brewing Co.',
#         'brewery_slug': 'two-docs-brewing',
#         'brewery_page_url': '/TwoDocsBrewingCo',
#         'brewery_type': 'Micro Brewery',
#         'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#         'country_name': 'United States',
#         'contact': {'twitter': '',
#          'facebook': 'https://www.facebook.com/twodocsbrewing',
#          'instagram': 'twodocsbrewing',
#          'url': 'https://twodocsbrewing.com/'},
#         'location': {'brewery_city': 'Lubbock',
#          'brewery_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'brewery_active': 1},
#        'user': {'uid': 2109800,
#         'user_name': 'Jdlbk',
#         'first_name': 'Jess',
#         'last_name': 'W',
#         'user_avatar': 'https://gravatar.com/avatar/26951d2bdb4acfcb18b10ab0b2a7ea4a?size=100&d=https%3A%2F%2Funtappd.akamaized.net%2Fsite%2Fassets%2Fimages%2Fdefault_avatar_v3_gravatar.jpg%3Fv%3D2',
#         'is_private': 0},
#        'venue': {'venue_id': 8707470,
#         'venue_name': 'Two Docs Brewing Co.',
#         'venue_slug': 'two-docs-brewing-co',
#         'primary_category': 'Nightlife Spot',
#         'parent_category_id': '4d4b7105d754a06376d81259',
#         'categories': {'count': 1,
#          'items': [{'category_key': 'brewery',
#            'category_name': 'Brewery',
#            'category_id': '50327c8591d4c4b30a586d5d',
#            'is_primary': True}]},
#         'location': {'venue_address': '502 Texas Ave',
#          'venue_city': 'Lubbock',
#          'venue_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#         'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#          'foursquare_url': 'https://4sq.com/2IJTFbR'},
#         'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#          'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#          'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#         'is_verified': 1}},
#       {'photo_id': 260582371,
#        'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_26/d597f0ce32b3c872525eb9102e92ea20_200x200.jpg',
#         'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_26/d597f0ce32b3c872525eb9102e92ea20_640x640.jpg',
#         'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_26/d597f0ce32b3c872525eb9102e92ea20_1280x1280.jpg',
#         'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_26/d597f0ce32b3c872525eb9102e92ea20_raw.jpg'},
#        'created_at': 'Sat, 26 Oct 2019 04:19:47 +0000',
#        'checkin_id': 821803598,
#        'beer': {'bid': 3500094,
#         'beer_name': 'Prairie Dog Porter - Mexican Cocoa',
#         'beer_abv': 0,
#         'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#         'beer_style': 'Porter - Other'},
#        'brewery': {'brewery_id': 420745,
#         'brewery_name': 'Two Docs Brewing Co.',
#         'brewery_slug': 'two-docs-brewing',
#         'brewery_page_url': '/TwoDocsBrewingCo',
#         'brewery_type': 'Micro Brewery',
#         'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#         'country_name': 'United States',
#         'contact': {'twitter': '',
#          'facebook': 'https://www.facebook.com/twodocsbrewing',
#          'instagram': 'twodocsbrewing',
#          'url': 'https://twodocsbrewing.com/'},
#         'location': {'brewery_city': 'Lubbock',
#          'brewery_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'brewery_active': 1},
#        'user': {'uid': 1429511,
#         'user_name': 'dcsfoyle',
#         'first_name': 'Eric',
#         'last_name': 'R',
#         'user_avatar': 'https://untappd.akamaized.net/profile/a313cb1054443db78d8e914c4780daa4_100x100.jpg',
#         'is_private': 0},
#        'venue': {'venue_id': 8707470,
#         'venue_name': 'Two Docs Brewing Co.',
#         'venue_slug': 'two-docs-brewing-co',
#         'primary_category': 'Nightlife Spot',
#         'parent_category_id': '4d4b7105d754a06376d81259',
#         'categories': {'count': 1,
#          'items': [{'category_key': 'brewery',
#            'category_name': 'Brewery',
#            'category_id': '50327c8591d4c4b30a586d5d',
#            'is_primary': True}]},
#         'location': {'venue_address': '502 Texas Ave',
#          'venue_city': 'Lubbock',
#          'venue_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#         'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#          'foursquare_url': 'https://4sq.com/2IJTFbR'},
#         'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#          'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#          'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#         'is_verified': 1}},
#       {'photo_id': 260581452,
#        'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_26/9b2232b8a81c4408e643552cb57c7351_200x200.jpg',
#         'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_26/9b2232b8a81c4408e643552cb57c7351_640x640.jpg',
#         'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_26/9b2232b8a81c4408e643552cb57c7351_1280x1280.jpg',
#         'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_26/9b2232b8a81c4408e643552cb57c7351_raw.jpg'},
#        'created_at': 'Sat, 26 Oct 2019 04:09:49 +0000',
#        'checkin_id': 821802229,
#        'beer': {'bid': 3440110,
#         'beer_name': 'Doktoberfest',
#         'beer_abv': 6.1,
#         'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#         'beer_style': 'Festbier'},
#        'brewery': {'brewery_id': 420745,
#         'brewery_name': 'Two Docs Brewing Co.',
#         'brewery_slug': 'two-docs-brewing',
#         'brewery_page_url': '/TwoDocsBrewingCo',
#         'brewery_type': 'Micro Brewery',
#         'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#         'country_name': 'United States',
#         'contact': {'twitter': '',
#          'facebook': 'https://www.facebook.com/twodocsbrewing',
#          'instagram': 'twodocsbrewing',
#          'url': 'https://twodocsbrewing.com/'},
#         'location': {'brewery_city': 'Lubbock',
#          'brewery_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'brewery_active': 1},
#        'user': {'uid': 1017530,
#         'user_name': 'johnnyreina',
#         'first_name': 'Satan',
#         'last_name': '',
#         'user_avatar': 'https://untappd.akamaized.net/profile/e7291361ca25ff19c5944aea3e01e530_100x100.jpg',
#         'is_private': 0},
#        'venue': {'venue_id': 8707470,
#         'venue_name': 'Two Docs Brewing Co.',
#         'venue_slug': 'two-docs-brewing-co',
#         'primary_category': 'Nightlife Spot',
#         'parent_category_id': '4d4b7105d754a06376d81259',
#         'categories': {'count': 1,
#          'items': [{'category_key': 'brewery',
#            'category_name': 'Brewery',
#            'category_id': '50327c8591d4c4b30a586d5d',
#            'is_primary': True}]},
#         'location': {'venue_address': '502 Texas Ave',
#          'venue_city': 'Lubbock',
#          'venue_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#         'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#          'foursquare_url': 'https://4sq.com/2IJTFbR'},
#         'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#          'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#          'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#         'is_verified': 1}},
#       {'photo_id': 260578609,
#        'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_26/89e576a05a08f64a2906a74f2f78ba51_200x200.jpg',
#         'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_26/89e576a05a08f64a2906a74f2f78ba51_640x640.jpg',
#         'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_26/89e576a05a08f64a2906a74f2f78ba51_1280x1280.jpg',
#         'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_26/89e576a05a08f64a2906a74f2f78ba51_raw.jpg'},
#        'created_at': 'Sat, 26 Oct 2019 03:42:42 +0000',
#        'checkin_id': 821794344,
#        'beer': {'bid': 3408493,
#         'beer_name': 'Hayes-E Baby IPA',
#         'beer_abv': 7.1,
#         'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#         'beer_style': 'IPA - New England'},
#        'brewery': {'brewery_id': 420745,
#         'brewery_name': 'Two Docs Brewing Co.',
#         'brewery_slug': 'two-docs-brewing',
#         'brewery_page_url': '/TwoDocsBrewingCo',
#         'brewery_type': 'Micro Brewery',
#         'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#         'country_name': 'United States',
#         'contact': {'twitter': '',
#          'facebook': 'https://www.facebook.com/twodocsbrewing',
#          'instagram': 'twodocsbrewing',
#          'url': 'https://twodocsbrewing.com/'},
#         'location': {'brewery_city': 'Lubbock',
#          'brewery_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'brewery_active': 1},
#        'user': {'uid': 1017530,
#         'user_name': 'johnnyreina',
#         'first_name': 'Satan',
#         'last_name': '',
#         'user_avatar': 'https://untappd.akamaized.net/profile/e7291361ca25ff19c5944aea3e01e530_100x100.jpg',
#         'is_private': 0},
#        'venue': {'venue_id': 8707470,
#         'venue_name': 'Two Docs Brewing Co.',
#         'venue_slug': 'two-docs-brewing-co',
#         'primary_category': 'Nightlife Spot',
#         'parent_category_id': '4d4b7105d754a06376d81259',
#         'categories': {'count': 1,
#          'items': [{'category_key': 'brewery',
#            'category_name': 'Brewery',
#            'category_id': '50327c8591d4c4b30a586d5d',
#            'is_primary': True}]},
#         'location': {'venue_address': '502 Texas Ave',
#          'venue_city': 'Lubbock',
#          'venue_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#         'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#          'foursquare_url': 'https://4sq.com/2IJTFbR'},
#         'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#          'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#          'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#         'is_verified': 1}},
#       {'photo_id': 260577499,
#        'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_26/0cec2d2c63d8195ea71e09037d2650b9_200x200.jpg',
#         'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_26/0cec2d2c63d8195ea71e09037d2650b9_640x640.jpg',
#         'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_26/0cec2d2c63d8195ea71e09037d2650b9_1280x1280.jpg',
#         'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_26/0cec2d2c63d8195ea71e09037d2650b9_raw.jpg'},
#        'created_at': 'Sat, 26 Oct 2019 03:33:34 +0000',
#        'checkin_id': 821791136,
#        'beer': {'bid': 3408493,
#         'beer_name': 'Hayes-E Baby IPA',
#         'beer_abv': 7.1,
#         'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#         'beer_style': 'IPA - New England'},
#        'brewery': {'brewery_id': 420745,
#         'brewery_name': 'Two Docs Brewing Co.',
#         'brewery_slug': 'two-docs-brewing',
#         'brewery_page_url': '/TwoDocsBrewingCo',
#         'brewery_type': 'Micro Brewery',
#         'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#         'country_name': 'United States',
#         'contact': {'twitter': '',
#          'facebook': 'https://www.facebook.com/twodocsbrewing',
#          'instagram': 'twodocsbrewing',
#          'url': 'https://twodocsbrewing.com/'},
#         'location': {'brewery_city': 'Lubbock',
#          'brewery_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'brewery_active': 1},
#        'user': {'uid': 1017530,
#         'user_name': 'johnnyreina',
#         'first_name': 'Satan',
#         'last_name': '',
#         'user_avatar': 'https://untappd.akamaized.net/profile/e7291361ca25ff19c5944aea3e01e530_100x100.jpg',
#         'is_private': 0},
#        'venue': {'venue_id': 8707470,
#         'venue_name': 'Two Docs Brewing Co.',
#         'venue_slug': 'two-docs-brewing-co',
#         'primary_category': 'Nightlife Spot',
#         'parent_category_id': '4d4b7105d754a06376d81259',
#         'categories': {'count': 1,
#          'items': [{'category_key': 'brewery',
#            'category_name': 'Brewery',
#            'category_id': '50327c8591d4c4b30a586d5d',
#            'is_primary': True}]},
#         'location': {'venue_address': '502 Texas Ave',
#          'venue_city': 'Lubbock',
#          'venue_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#         'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#          'foursquare_url': 'https://4sq.com/2IJTFbR'},
#         'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#          'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#          'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#         'is_verified': 1}},
#       {'photo_id': 260552871,
#        'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_26/952e03e92a6d47a8af5381e91cf136db_200x200.jpg',
#         'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_26/952e03e92a6d47a8af5381e91cf136db_640x640.jpg',
#         'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_26/952e03e92a6d47a8af5381e91cf136db_1280x1280.jpg',
#         'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_26/952e03e92a6d47a8af5381e91cf136db_raw.jpg'},
#        'created_at': 'Sat, 26 Oct 2019 01:20:44 +0000',
#        'checkin_id': 821721707,
#        'beer': {'bid': 3063015,
#         'beer_name': 'Prairie Dawg Porter',
#         'beer_abv': 5.9,
#         'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-3063015_38cdd_sm.jpeg',
#         'beer_style': 'Porter - American'},
#        'brewery': {'brewery_id': 420745,
#         'brewery_name': 'Two Docs Brewing Co.',
#         'brewery_slug': 'two-docs-brewing',
#         'brewery_page_url': '/TwoDocsBrewingCo',
#         'brewery_type': 'Micro Brewery',
#         'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#         'country_name': 'United States',
#         'contact': {'twitter': '',
#          'facebook': 'https://www.facebook.com/twodocsbrewing',
#          'instagram': 'twodocsbrewing',
#          'url': 'https://twodocsbrewing.com/'},
#         'location': {'brewery_city': 'Lubbock',
#          'brewery_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'brewery_active': 1},
#        'user': {'uid': 5298782,
#         'user_name': 'redlacedoxfords',
#         'first_name': 'Kelsey',
#         'last_name': 'S',
#         'user_avatar': 'https://untappd.akamaized.net/profile/56835bf4a415ef8dbb681ba00e7e7b5d_100x100.jpg',
#         'is_private': 0},
#        'venue': []},
#       {'photo_id': 260293102,
#        'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_24/9e3175a4e87a3954c8cd40fa72a9270b_200x200.jpg',
#         'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_24/9e3175a4e87a3954c8cd40fa72a9270b_640x640.jpg',
#         'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_24/9e3175a4e87a3954c8cd40fa72a9270b_1280x1280.jpg',
#         'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_24/9e3175a4e87a3954c8cd40fa72a9270b_raw.jpg'},
#        'created_at': 'Thu, 24 Oct 2019 22:43:27 +0000',
#        'checkin_id': 821113091,
#        'beer': {'bid': 3440110,
#         'beer_name': 'Doktoberfest',
#         'beer_abv': 6.1,
#         'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#         'beer_style': 'Festbier'},
#        'brewery': {'brewery_id': 420745,
#         'brewery_name': 'Two Docs Brewing Co.',
#         'brewery_slug': 'two-docs-brewing',
#         'brewery_page_url': '/TwoDocsBrewingCo',
#         'brewery_type': 'Micro Brewery',
#         'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#         'country_name': 'United States',
#         'contact': {'twitter': '',
#          'facebook': 'https://www.facebook.com/twodocsbrewing',
#          'instagram': 'twodocsbrewing',
#          'url': 'https://twodocsbrewing.com/'},
#         'location': {'brewery_city': 'Lubbock',
#          'brewery_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'brewery_active': 1},
#        'user': {'uid': 3414905,
#         'user_name': 'dpftex',
#         'first_name': 'Danny',
#         'last_name': 'F',
#         'user_avatar': 'https://untappd.akamaized.net/profile/2d871269d7f4e088e418dfe2793e064d_100x100.jpeg',
#         'is_private': 0},
#        'venue': {'venue_id': 3408071,
#         'venue_name': 'Flippers Tavern',
#         'venue_slug': 'flippers-tavern',
#         'primary_category': 'Food',
#         'parent_category_id': '4d4b7105d754a06374d81259',
#         'categories': {'count': 3,
#          'items': [{'category_key': 'hot_dog_joint',
#            'category_name': 'Hot Dog Joint',
#            'category_id': '4bf58dd8d48988d16f941735',
#            'is_primary': True},
#           {'category_key': 'arcade',
#            'category_name': 'Arcade',
#            'category_id': '4bf58dd8d48988d1e1931735',
#            'is_primary': False},
#           {'category_key': 'bar',
#            'category_name': 'Bar',
#            'category_id': '4bf58dd8d48988d116941735',
#            'is_primary': False}]},
#         'location': {'venue_address': '1406 Avenue Q',
#          'venue_city': 'Lubbock',
#          'venue_state': 'TX',
#          'lat': 33.5824,
#          'lng': -101.855},
#         'contact': {'twitter': '', 'venue_url': ''},
#         'foursquare': {'foursquare_id': '55caaa5a498e79b3b94477a7',
#          'foursquare_url': 'http://4sq.com/1N1TItL'},
#         'venue_icon': {'sm': 'https://ss3.4sqi.net/img/categories_v2/food/hotdog_bg_64.png',
#          'md': 'https://ss3.4sqi.net/img/categories_v2/food/hotdog_bg_88.png',
#          'lg': 'https://ss3.4sqi.net/img/categories_v2/food/hotdog_bg_512.png'},
#         'is_verified': 0}},
#       {'photo_id': 260166345,
#        'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_23/b86e4251d6569cf2edf0a1068aeff541_200x200.jpg',
#         'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_23/b86e4251d6569cf2edf0a1068aeff541_640x640.jpg',
#         'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_23/b86e4251d6569cf2edf0a1068aeff541_1280x1280.jpg',
#         'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_23/b86e4251d6569cf2edf0a1068aeff541_raw.jpg'},
#        'created_at': 'Wed, 23 Oct 2019 23:02:43 +0000',
#        'checkin_id': 820818891,
#        'beer': {'bid': 3062868,
#         'beer_name': 'Buddy Hoppy IPA',
#         'beer_abv': 8.2,
#         'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#         'beer_style': 'IPA - American'},
#        'brewery': {'brewery_id': 420745,
#         'brewery_name': 'Two Docs Brewing Co.',
#         'brewery_slug': 'two-docs-brewing',
#         'brewery_page_url': '/TwoDocsBrewingCo',
#         'brewery_type': 'Micro Brewery',
#         'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#         'country_name': 'United States',
#         'contact': {'twitter': '',
#          'facebook': 'https://www.facebook.com/twodocsbrewing',
#          'instagram': 'twodocsbrewing',
#          'url': 'https://twodocsbrewing.com/'},
#         'location': {'brewery_city': 'Lubbock',
#          'brewery_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'brewery_active': 1},
#        'user': {'uid': 661191,
#         'user_name': 'Jgthomp',
#         'first_name': 'Jason',
#         'last_name': 'T',
#         'user_avatar': 'https://untappd.akamaized.net/profile/72eb38d3243cfba9b57035294292226e_100x100.jpg',
#         'is_private': 0},
#        'venue': {'venue_id': 8707470,
#         'venue_name': 'Two Docs Brewing Co.',
#         'venue_slug': 'two-docs-brewing-co',
#         'primary_category': 'Nightlife Spot',
#         'parent_category_id': '4d4b7105d754a06376d81259',
#         'categories': {'count': 1,
#          'items': [{'category_key': 'brewery',
#            'category_name': 'Brewery',
#            'category_id': '50327c8591d4c4b30a586d5d',
#            'is_primary': True}]},
#         'location': {'venue_address': '502 Texas Ave',
#          'venue_city': 'Lubbock',
#          'venue_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#         'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#          'foursquare_url': 'https://4sq.com/2IJTFbR'},
#         'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#          'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#          'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#         'is_verified': 1}},
#       {'photo_id': 260059867,
#        'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_22/1b87a5ec23cf1196e413e032e6e0bae1_200x200.jpg',
#         'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_22/1b87a5ec23cf1196e413e032e6e0bae1_640x640.jpg',
#         'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_22/1b87a5ec23cf1196e413e032e6e0bae1_1280x1280.jpg',
#         'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_22/1b87a5ec23cf1196e413e032e6e0bae1_raw.jpg'},
#        'created_at': 'Tue, 22 Oct 2019 23:32:43 +0000',
#        'checkin_id': 820573344,
#        'beer': {'bid': 3440110,
#         'beer_name': 'Doktoberfest',
#         'beer_abv': 6.1,
#         'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#         'beer_style': 'Festbier'},
#        'brewery': {'brewery_id': 420745,
#         'brewery_name': 'Two Docs Brewing Co.',
#         'brewery_slug': 'two-docs-brewing',
#         'brewery_page_url': '/TwoDocsBrewingCo',
#         'brewery_type': 'Micro Brewery',
#         'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#         'country_name': 'United States',
#         'contact': {'twitter': '',
#          'facebook': 'https://www.facebook.com/twodocsbrewing',
#          'instagram': 'twodocsbrewing',
#          'url': 'https://twodocsbrewing.com/'},
#         'location': {'brewery_city': 'Lubbock',
#          'brewery_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'brewery_active': 1},
#        'user': {'uid': 184852,
#         'user_name': 'MarkTTU',
#         'first_name': 'Mark',
#         'last_name': '',
#         'user_avatar': 'https://untappd.akamaized.net/profile/4b6c6af4442c4021c99069ddb3c2648d_100x100.jpg',
#         'is_private': 0},
#        'venue': {'venue_id': 8707470,
#         'venue_name': 'Two Docs Brewing Co.',
#         'venue_slug': 'two-docs-brewing-co',
#         'primary_category': 'Nightlife Spot',
#         'parent_category_id': '4d4b7105d754a06376d81259',
#         'categories': {'count': 1,
#          'items': [{'category_key': 'brewery',
#            'category_name': 'Brewery',
#            'category_id': '50327c8591d4c4b30a586d5d',
#            'is_primary': True}]},
#         'location': {'venue_address': '502 Texas Ave',
#          'venue_city': 'Lubbock',
#          'venue_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#         'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#          'foursquare_url': 'https://4sq.com/2IJTFbR'},
#         'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#          'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#          'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#         'is_verified': 1}},
#       {'photo_id': 259817533,
#        'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_20/a457d5e9ec3377b0d1bea8553990d879_200x200.jpg',
#         'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_20/a457d5e9ec3377b0d1bea8553990d879_640x640.jpg',
#         'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_20/a457d5e9ec3377b0d1bea8553990d879_1280x1280.jpg',
#         'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_20/a457d5e9ec3377b0d1bea8553990d879_raw.jpg'},
#        'created_at': 'Sun, 20 Oct 2019 19:23:51 +0000',
#        'checkin_id': 819991411,
#        'beer': {'bid': 3408493,
#         'beer_name': 'Hayes-E Baby IPA',
#         'beer_abv': 7.1,
#         'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#         'beer_style': 'IPA - New England'},
#        'brewery': {'brewery_id': 420745,
#         'brewery_name': 'Two Docs Brewing Co.',
#         'brewery_slug': 'two-docs-brewing',
#         'brewery_page_url': '/TwoDocsBrewingCo',
#         'brewery_type': 'Micro Brewery',
#         'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#         'country_name': 'United States',
#         'contact': {'twitter': '',
#          'facebook': 'https://www.facebook.com/twodocsbrewing',
#          'instagram': 'twodocsbrewing',
#          'url': 'https://twodocsbrewing.com/'},
#         'location': {'brewery_city': 'Lubbock',
#          'brewery_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'brewery_active': 1},
#        'user': {'uid': 1847754,
#         'user_name': 'Nobandsland1',
#         'first_name': 'Dirk',
#         'last_name': 'D',
#         'user_avatar': 'https://untappd.akamaized.net/profile/25a524f8bc4cf1a6b70877258bf9906f_100x100.jpg',
#         'is_private': 0},
#        'venue': {'venue_id': 8707470,
#         'venue_name': 'Two Docs Brewing Co.',
#         'venue_slug': 'two-docs-brewing-co',
#         'primary_category': 'Nightlife Spot',
#         'parent_category_id': '4d4b7105d754a06376d81259',
#         'categories': {'count': 1,
#          'items': [{'category_key': 'brewery',
#            'category_name': 'Brewery',
#            'category_id': '50327c8591d4c4b30a586d5d',
#            'is_primary': True}]},
#         'location': {'venue_address': '502 Texas Ave',
#          'venue_city': 'Lubbock',
#          'venue_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#         'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#          'foursquare_url': 'https://4sq.com/2IJTFbR'},
#         'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#          'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#          'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#         'is_verified': 1}},
#       {'photo_id': 259817000,
#        'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_20/27f53e0838d906a53ac265e1ef6acabb_200x200.jpg',
#         'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_20/27f53e0838d906a53ac265e1ef6acabb_640x640.jpg',
#         'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_20/27f53e0838d906a53ac265e1ef6acabb_1280x1280.jpg',
#         'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_20/27f53e0838d906a53ac265e1ef6acabb_raw.jpg'},
#        'created_at': 'Sun, 20 Oct 2019 19:21:56 +0000',
#        'checkin_id': 819990171,
#        'beer': {'bid': 3440110,
#         'beer_name': 'Doktoberfest',
#         'beer_abv': 6.1,
#         'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#         'beer_style': 'Festbier'},
#        'brewery': {'brewery_id': 420745,
#         'brewery_name': 'Two Docs Brewing Co.',
#         'brewery_slug': 'two-docs-brewing',
#         'brewery_page_url': '/TwoDocsBrewingCo',
#         'brewery_type': 'Micro Brewery',
#         'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#         'country_name': 'United States',
#         'contact': {'twitter': '',
#          'facebook': 'https://www.facebook.com/twodocsbrewing',
#          'instagram': 'twodocsbrewing',
#          'url': 'https://twodocsbrewing.com/'},
#         'location': {'brewery_city': 'Lubbock',
#          'brewery_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'brewery_active': 1},
#        'user': {'uid': 1847754,
#         'user_name': 'Nobandsland1',
#         'first_name': 'Dirk',
#         'last_name': 'D',
#         'user_avatar': 'https://untappd.akamaized.net/profile/25a524f8bc4cf1a6b70877258bf9906f_100x100.jpg',
#         'is_private': 0},
#        'venue': {'venue_id': 8707470,
#         'venue_name': 'Two Docs Brewing Co.',
#         'venue_slug': 'two-docs-brewing-co',
#         'primary_category': 'Nightlife Spot',
#         'parent_category_id': '4d4b7105d754a06376d81259',
#         'categories': {'count': 1,
#          'items': [{'category_key': 'brewery',
#            'category_name': 'Brewery',
#            'category_id': '50327c8591d4c4b30a586d5d',
#            'is_primary': True}]},
#         'location': {'venue_address': '502 Texas Ave',
#          'venue_city': 'Lubbock',
#          'venue_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#         'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#          'foursquare_url': 'https://4sq.com/2IJTFbR'},
#         'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#          'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#          'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#         'is_verified': 1}}]},
#     'checkins': {'count': 15,
#      'items': [{'checkin_id': 823627778,
#        'created_at': 'Thu, 31 Oct 2019 01:19:13 +0000',
#        'checkin_comment': '',
#        'rating_score': 0,
#        'user': {'uid': 2328105,
#         'user_name': 'Sdugger1',
#         'first_name': 'Scott',
#         'last_name': 'D.',
#         'location': '',
#         'url': '',
#         'is_supporter': 0,
#         'bio': '',
#         'relationship': None,
#         'user_avatar': 'https://gravatar.com/avatar/03a310a2ae08be9acdec8c93722cec44?size=100&d=https%3A%2F%2Funtappd.akamaized.net%2Fsite%2Fassets%2Fimages%2Fdefault_avatar_v3_gravatar.jpg%3Fv%3D2',
#         'is_private': 0},
#        'beer': {'bid': 3104744,
#         'beer_name': 'Lubbock Light',
#         'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#         'beer_abv': 4,
#         'beer_ibu': 9,
#         'beer_slug': 'two-docs-brewing-co-lubbock-light',
#         'beer_description': 'An All-American Light beer. Think golf, tailgates, poolside or really anytime you are thirsty and need a beer... or 4.',
#         'beer_style': 'Lager - Helles',
#         'has_had': False,
#         'beer_active': 1},
#        'brewery': {'brewery_id': 420745,
#         'brewery_name': 'Two Docs Brewing Co.',
# ...
#         'is_in_production': 1,
#         'created_at': 'Sat, 02 Feb 2019 01:54:03 +0000',
#         'user_rating_score': 0,
#         'rating_score': 3.788,
#         'rating_count': 72,
#         'on_list': False,
#         'auth_rating': 0,
#         'wish_list': False},
#        'brewery': {'brewery_id': 420745,
#         'brewery_name': 'Two Docs Brewing Co.',
#         'brewery_slug': 'two-docs-brewing',
#         'brewery_page_url': '/TwoDocsBrewingCo',
#         'brewery_type': 'Micro Brewery',
#         'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#         'country_name': 'United States',
#         'contact': {'twitter': '',
#          'facebook': 'https://www.facebook.com/twodocsbrewing',
#          'instagram': 'twodocsbrewing',
#          'url': 'https://twodocsbrewing.com/'},
#         'location': {'brewery_city': 'Lubbock',
#          'brewery_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'brewery_active': 1},
#        'friends': {'items': [], 'count': 0}},
#       {'total_user_count': 0,
#        'has_had': None,
#        'total_count': 78,
#        'beer': {'bid': 3104757,
#         'beer_name': 'Easy Blonde',
#         'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#         'beer_style': 'Blonde Ale',
#         'beer_abv': 4,
#         'beer_ibu': 16,
#         'beer_slug': 'two-docs-brewing-co-easy-blonde',
#         'beer_description': 'Light, crisp and refreshing with a little kiss of Amarillo hops at the end. This blonde is hard to resist and keeps you coming back for more.',
#         'is_in_production': 1,
#         'created_at': 'Fri, 01 Mar 2019 20:52:50 +0000',
#         'user_rating_score': 0,
#         'rating_score': 3.664,
#         'rating_count': 67,
#         'on_list': False,
#         'auth_rating': 0,
#         'wish_list': False},
#        'brewery': {'brewery_id': 420745,
#         'brewery_name': 'Two Docs Brewing Co.',
#         'brewery_slug': 'two-docs-brewing',
#         'brewery_page_url': '/TwoDocsBrewingCo',
#         'brewery_type': 'Micro Brewery',
#         'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#         'country_name': 'United States',
#         'contact': {'twitter': '',
#          'facebook': 'https://www.facebook.com/twodocsbrewing',
#          'instagram': 'twodocsbrewing',
#          'url': 'https://twodocsbrewing.com/'},
#         'location': {'brewery_city': 'Lubbock',
#          'brewery_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'brewery_active': 1},
#        'friends': {'items': [], 'count': 0}},
#       {'total_user_count': 0,
#        'has_had': None,
#        'total_count': 71,
#        'beer': {'bid': 3104736,
#         'beer_name': 'Steampunk Ale',
#         'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#         'beer_style': 'California Common',
#         'beer_abv': 4.4,
#         'beer_ibu': 33,
#         'beer_slug': 'two-docs-brewing-co-steampunk-ale',
#         'beer_description': 'Smooth drinking amber colored ale brewed with lager yeast. Bay Area inspired, High Plains crafted.',
#         'is_in_production': 1,
#         'created_at': 'Fri, 01 Mar 2019 20:45:17 +0000',
#         'user_rating_score': 0,
#         'rating_score': 3.68,
#         'rating_count': 64,
#         'on_list': False,
#         'auth_rating': 0,
#         'wish_list': False},
#        'brewery': {'brewery_id': 420745,
#         'brewery_name': 'Two Docs Brewing Co.',
#         'brewery_slug': 'two-docs-brewing',
#         'brewery_page_url': '/TwoDocsBrewingCo',
#         'brewery_type': 'Micro Brewery',
#         'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#         'country_name': 'United States',
#         'contact': {'twitter': '',
#          'facebook': 'https://www.facebook.com/twodocsbrewing',
#          'instagram': 'twodocsbrewing',
#          'url': 'https://twodocsbrewing.com/'},
#         'location': {'brewery_city': 'Lubbock',
#          'brewery_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'brewery_active': 1},
#        'friends': {'items': [], 'count': 0}},
#       {'total_user_count': 0,
#        'has_had': None,
#        'total_count': 18,
#        'beer': {'bid': 3376550,
#         'beer_name': 'Watermelon Gose',
#         'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#         'beer_style': 'Shandy / Radler',
#         'beer_abv': 3.64,
#         'beer_ibu': 0,
#         'beer_slug': 'two-docs-brewing-co-watermelon-gose',
#         'beer_description': 'Needing a cool down? For a limited time, enjoy our newly crafted Watermelon Gose for a nice time on the patio. ',
#         'is_in_production': 1,
#         'created_at': 'Sat, 10 Aug 2019 15:47:59 +0000',
#         'user_rating_score': 0,
#         'rating_score': 3.8,
#         'rating_count': 15,
#         'on_list': False,
#         'auth_rating': 0,
#         'wish_list': False},
#        'brewery': {'brewery_id': 420745,
#         'brewery_name': 'Two Docs Brewing Co.',
#         'brewery_slug': 'two-docs-brewing',
#         'brewery_page_url': '/TwoDocsBrewingCo',
#         'brewery_type': 'Micro Brewery',
#         'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#         'country_name': 'United States',
#         'contact': {'twitter': '',
#          'facebook': 'https://www.facebook.com/twodocsbrewing',
#          'instagram': 'twodocsbrewing',
#          'url': 'https://twodocsbrewing.com/'},
#         'location': {'brewery_city': 'Lubbock',
#          'brewery_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'brewery_active': 1},
#        'friends': {'items': [], 'count': 0}},
#       {'total_user_count': 0,
#        'has_had': None,
#        'total_count': 10,
#        'beer': {'bid': 3466636,
#         'beer_name': 'Pickle Gose',
#         'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#         'beer_style': 'Sour - Other',
#         'beer_abv': 4.5,
#         'beer_ibu': 8,
#         'beer_slug': 'two-docs-brewing-co-pickle-gose',
#         'beer_description': '',
#         'is_in_production': 1,
#         'created_at': 'Sat, 05 Oct 2019 13:57:57 +0000',
#         'user_rating_score': 0,
#         'rating_score': 3.825,
#         'rating_count': 10,
#         'on_list': False,
#         'auth_rating': 0,
#         'wish_list': False},
#        'brewery': {'brewery_id': 420745,
#         'brewery_name': 'Two Docs Brewing Co.',
#         'brewery_slug': 'two-docs-brewing',
#         'brewery_page_url': '/TwoDocsBrewingCo',
#         'brewery_type': 'Micro Brewery',
#         'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#         'country_name': 'United States',
#         'contact': {'twitter': '',
#          'facebook': 'https://www.facebook.com/twodocsbrewing',
#          'instagram': 'twodocsbrewing',
#          'url': 'https://twodocsbrewing.com/'},
#         'location': {'brewery_city': 'Lubbock',
#          'brewery_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'brewery_active': 1},
#        'friends': {'items': [], 'count': 0}},
#       {'total_user_count': 0,
#        'has_had': None,
#        'total_count': 10,
#        'beer': {'bid': 3488043,
#         'beer_name': 'Brunch Bock',
#         'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#         'beer_style': 'Bock - Single / Traditional',
#         'beer_abv': 5.4,
#         'beer_ibu': 19,
#         'beer_slug': 'two-docs-brewing-co-brunch-bock',
#         'beer_description': '',
#         'is_in_production': 1,
#         'created_at': 'Fri, 18 Oct 2019 23:05:45 +0000',
#         'user_rating_score': 0,
#         'rating_score': 0,
#         'rating_count': 7,
#         'on_list': False,
#         'auth_rating': 0,
#         'wish_list': False},
#        'brewery': {'brewery_id': 420745,
#         'brewery_name': 'Two Docs Brewing Co.',
#         'brewery_slug': 'two-docs-brewing',
#         'brewery_page_url': '/TwoDocsBrewingCo',
#         'brewery_type': 'Micro Brewery',
#         'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#         'country_name': 'United States',
#         'contact': {'twitter': '',
#          'facebook': 'https://www.facebook.com/twodocsbrewing',
#          'instagram': 'twodocsbrewing',
#          'url': 'https://twodocsbrewing.com/'},
#         'location': {'brewery_city': 'Lubbock',
#          'brewery_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'brewery_active': 1},
#        'friends': {'items': [], 'count': 0}},
#       {'total_user_count': 0,
#        'has_had': None,
#        'total_count': 4,
#        'beer': {'bid': 3432355,
#         'beer_name': 'Ruby Red Grapefruit Shandy',
#         'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#         'beer_style': 'Shandy / Radler',
#         'beer_abv': 4,
#         'beer_ibu': 0,
#         'beer_slug': 'two-docs-brewing-co-ruby-red-grapefruit-shandy',
#         'beer_description': '',
#         'is_in_production': 1,
#         'created_at': 'Sat, 14 Sep 2019 13:52:35 +0000',
#         'user_rating_score': 0,
#         'rating_score': 0,
#         'rating_count': 4,
#         'on_list': False,
#         'auth_rating': 0,
#         'wish_list': False},
#        'brewery': {'brewery_id': 420745,
#         'brewery_name': 'Two Docs Brewing Co.',
#         'brewery_slug': 'two-docs-brewing',
#         'brewery_page_url': '/TwoDocsBrewingCo',
#         'brewery_type': 'Micro Brewery',
#         'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#         'country_name': 'United States',
#         'contact': {'twitter': '',
#          'facebook': 'https://www.facebook.com/twodocsbrewing',
#          'instagram': 'twodocsbrewing',
#          'url': 'https://twodocsbrewing.com/'},
#         'location': {'brewery_city': 'Lubbock',
#          'brewery_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'brewery_active': 1},
#        'friends': {'items': [], 'count': 0}},
#       {'total_user_count': 0,
#        'has_had': None,
#        'total_count': 3,
#        'beer': {'bid': 3412130,
#         'beer_name': 'Game Day IPA',
#         'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#         'beer_style': 'IPA - American',
#         'beer_abv': 0,
#         'beer_ibu': 0,
#         'beer_slug': 'two-docs-brewing-co-game-day-ipa',
#         'beer_description': '',
#         'is_in_production': 1,
#         'created_at': 'Sat, 31 Aug 2019 23:28:45 +0000',
#         'user_rating_score': 0,
#         'rating_score': 0,
#         'rating_count': 3,
#         'on_list': False,
#         'auth_rating': 0,
#         'wish_list': False},
#        'brewery': {'brewery_id': 420745,
#         'brewery_name': 'Two Docs Brewing Co.',
#         'brewery_slug': 'two-docs-brewing',
#         'brewery_page_url': '/TwoDocsBrewingCo',
#         'brewery_type': 'Micro Brewery',
#         'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#         'country_name': 'United States',
#         'contact': {'twitter': '',
#          'facebook': 'https://www.facebook.com/twodocsbrewing',
#          'instagram': 'twodocsbrewing',
#          'url': 'https://twodocsbrewing.com/'},
#         'location': {'brewery_city': 'Lubbock',
#          'brewery_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'brewery_active': 1},
#        'friends': {'items': [], 'count': 0}},
#       {'total_user_count': 0,
#        'has_had': None,
#        'total_count': 3,
#        'beer': {'bid': 3453729,
#         'beer_name': 'BlackBerry Gose',
#         'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#         'beer_style': 'Sour - Gose - Fruited',
#         'beer_abv': 4.5,
#         'beer_ibu': 8,
#         'beer_slug': 'two-docs-brewing-co-blackberry-gose',
#         'beer_description': '',
#         'is_in_production': 1,
#         'created_at': 'Fri, 27 Sep 2019 21:42:07 +0000',
#         'user_rating_score': 0,
#         'rating_score': 0,
#         'rating_count': 2,
#         'on_list': False,
#         'auth_rating': 0,
#         'wish_list': False},
#        'brewery': {'brewery_id': 420745,
#         'brewery_name': 'Two Docs Brewing Co.',
#         'brewery_slug': 'two-docs-brewing',
#         'brewery_page_url': '/TwoDocsBrewingCo',
#         'brewery_type': 'Micro Brewery',
#         'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#         'country_name': 'United States',
#         'contact': {'twitter': '',
#          'facebook': 'https://www.facebook.com/twodocsbrewing',
#          'instagram': 'twodocsbrewing',
#          'url': 'https://twodocsbrewing.com/'},
#         'location': {'brewery_city': 'Lubbock',
#          'brewery_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'brewery_active': 1},
#        'friends': {'items': [], 'count': 0}},
#       {'total_user_count': 0,
#        'has_had': None,
#        'total_count': 1,
#        'beer': {'bid': 3500094,
#         'beer_name': 'Prairie Dog Porter - Mexican Cocoa',
#         'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#         'beer_style': 'Porter - Other',
#         'beer_abv': 0,
#         'beer_ibu': 0,
#         'beer_slug': 'two-docs-brewing-co-prairie-dog-porter-mexican-cocoa',
#         'beer_description': 'Two Docs Prairie Dog Porter infused with Mexican Cocoa. Extremely limited release. Oct. 25, 2019',
#         'is_in_production': 1,
#         'created_at': 'Sat, 26 Oct 2019 04:12:03 +0000',
#         'user_rating_score': 0,
#         'rating_score': 0,
#         'rating_count': 1,
#         'on_list': False,
#         'auth_rating': 0,
#         'wish_list': False},
#        'brewery': {'brewery_id': 420745,
#         'brewery_name': 'Two Docs Brewing Co.',
#         'brewery_slug': 'two-docs-brewing',
#         'brewery_page_url': '/TwoDocsBrewingCo',
#         'brewery_type': 'Micro Brewery',
#         'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#         'country_name': 'United States',
#         'contact': {'twitter': '',
#          'facebook': 'https://www.facebook.com/twodocsbrewing',
#          'instagram': 'twodocsbrewing',
#          'url': 'https://twodocsbrewing.com/'},
#         'location': {'brewery_city': 'Lubbock',
#          'brewery_state': 'TX',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'brewery_active': 1},
#        'friends': {'items': [], 'count': 0}}],
#      'collaborations': {'count': 0, 'items': []},
#      'sort_name': 'Most Popular',
#      'sort_key': 'most_popular'},
#     'locations': {'count': 1,
#      'items': [{'venue': {'venue_id': 8707470,
#         'venue_name': 'Two Docs Brewing Co.',
#         'venue_slug': 'two-docs-brewing-co',
#         'primary_category_key': 'Nightlife Spot',
#         'primary_category': 'Nightlife Spot',
#         'parent_category_id': '4d4b7105d754a06376d81259',
#         'categories': {'count': 1,
#          'items': [{'category_key': 'brewery',
#            'category_name': 'Brewery',
#            'category_id': '50327c8591d4c4b30a586d5d',
#            'is_primary': True}]},
#         'location': {'venue_address': '502 Texas Ave',
#          'venue_city': 'Lubbock',
#          'venue_state': 'TX',
#          'venue_country': 'United States',
#          'lat': 33.5909,
#          'lng': -101.846},
#         'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#         'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#          'foursquare_url': 'https://4sq.com/2IJTFbR'},
#         'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#          'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#          'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#         'is_verified': True}}]}}}}]

# %% [markdown]
# Due to untappd's 100 requests an hour, i'll need to run this over a couple of hours.  Thus saving results for future reference.

# %%
import pickle
import numpy as np
import pandas as pd
from IPython.display import clear_output

# Load data
with open ("../data/all_breweries.pkl", "rb") as fp:
    all_breweries = pickle.load(fp)

untappd = Untappd()
 
for brewery in all_breweries:
    if "untappd" not in brewery:
        brewery_result, counter, response = untappd.findBrewery(brewery["Name"])
        
        if len( brewery_result ) > 0:
            brewery["untappd"] = brewery_result
        else:
            brewery["untappd"] = [{"no_results":True}]

        clear_output(wait=True)
        display(counter)
        if counter == 0:
            break
        
#         break
#Save results
with open("../data/all_breweries.pkl", "wb") as fp:
    pickle.dump(all_breweries, fp)

print( "sample output" )
print( all_breweries[0] )
# Out:
# 38
# sample output
# {'Name': '111 Brewing', 'Street Address': 111, 'Road': 'S FANNIN AVENUE', 'City': 'DENISON', 'State': 'TX', 'Brewery License': 'Brewery', 'License Date': '4/10/2019', 'Status': 'In the works', 'untappd': [{'brewery': {'brewery_id': 66888, 'beer_count': 65, 'brewery_name': 'Milepost 111 Brewing Company', 'brewery_slug': 'milepost-111-brewing-company', 'brewery_page_url': '/milepostbeer', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-Milepost111_66888_590e6.jpeg', 'country_name': 'United States', 'location': {'brewery_city': 'Cashmere', 'brewery_state': 'WA', 'lat': 47.5244, 'lng': -120.47}}}]}

# %%
import pickle
import pandas as pd
from IPython.display import clear_output

# Load data
with open ("../data/all_breweries.pkl", "rb") as fp:
    all_breweries = pickle.load(fp)
 
# Normalized the results
brewery_parsed = []
i = 0
for brewery in all_breweries:
    clear_output(wait=True)
    display(i)
    i+=1
    for entries in brewery["untappd"]:
        if "no_results" not in entries:
            brewery_parsed.append({
                "Name":brewery["Name"],
                "Street Address":brewery["Street Address"],
                "Road":brewery["Road"],
                "City":brewery["City"],
                "State":brewery["State"],
                "Brewery License":brewery["Brewery License"],
                "License Date":brewery["License Date"],
                "Status":brewery["Status"],
                "search_count":len(brewery["untappd"]),
                "brewery_id":entries["brewery"]["brewery_id"],
                "brewery_name":entries["brewery"]["brewery_name"],
                "beer_count":entries["brewery"]["beer_count"],
                "brewery_city":entries["brewery"]["location"]["brewery_city"],
                "brewery_state":entries["brewery"]["location"]["brewery_state"],
                "brewery_lat":entries["brewery"]["location"]["lat"],
                "brewery_lng":entries["brewery"]["location"]["lng"]
            })
        

# Remove results where not in texas
brewery_parsed = [ brewery for brewery in brewery_parsed if "TX" in brewery["brewery_state"]]
    
# Must have 10 beers!
# brewery_parsed = [ brewery for brewery in brewery_parsed if brewery["beer_count"] > 9 ]

#remove duplicates
# brewery_count = pd.DataFrame(brewery_parsed).groupby(["Name"])["Status"].count()
# dups = brewery_count.loc[ brewery_count > 1].reset_index()
# dups = dups["Name"].to_list()
# print("Duplicates to be removed", dups)
# brewery_parsed = [ brewery for brewery in brewery_parsed if brewery["Name"] not in dups ]

# #Add Brewery ID back in to primary data
for brewery in all_breweries:
    for b in brewery_parsed:
        if brewery["Name"] in b["Name"]:
            brewery["brewery_id"] = b["brewery_id"]
            
# #Save results
with open("../data/all_breweries.pkl", "wb") as fp:
    pickle.dump(all_breweries, fp)
# #Convert to Pandas and save it
# # brewery_parsed = pd.DataFrame( brewery_parsed )
# # brewery_parsed.to_csv("../data/brewery_search.csv")
pd.options.display.max_rows = 999
display( pd.DataFrame( brewery_parsed ) )
pd.options.display.max_rows = 15
# Out:
# 365
#                                      Name Street Address                            Road                  City State Brewery License License Date        Status  search_count  brewery_id                             brewery_name  beer_count          brewery_city brewery_state  brewery_lat  brewery_lng
# 0                       2 Docs Brewing Co            502                    TEXAS AVENUE               LUBBOCK    TX         Brewery    10/5/2018          Open             1      420745                     Two Docs Brewing Co.          22               Lubbock            TX      33.5909    -101.8460
# 1                       3 Nations Brewing           2405          SQUIRE PLACE SUITE 200        FARMERS BRANCH    TX         Brewery     5/6/2015          Open             1      205645                        3 Nations Brewing          43        Farmers Branch            TX      32.9310     -96.8983
# 2                        4th Tap Brewing           10615                METRIC BOULEVARD                AUSTIN    TX         Brewery    4/13/2015          Open             1      229660                    4th Tap Brewing Co-Op          90                Austin            TX      30.3852     -97.7119
# 3                            512 Brewing             407               RADAM LANE 'F200'                AUSTIN    TX         Brewery    5/20/2008          Open             1           1                    (512) Brewing Company         156                Austin            TX      30.2236     -97.7697
# 4                      8th Wonder Brewery           2202                   DALLAS STREET               HOUSTON    TX         Brewery   12/29/2011          Open             1       45113                       8th Wonder Brewery         157               Houston            TX      29.7492     -95.3558
# 5                              Alamo Beer            415                   BURNET STREET           SAN ANTONIO    TX         Brewery    9/29/2014          Open             1       43137                       Alamo Beer Company          69           San Antonio            TX      29.4295     -98.4773
# 6               Altmeyer   Lewis Brewing           15898                   HWY 123 NORTH            SAN MARCOS    TX         Brewery    7/16/2015          Open             1      294420         Altmeyer & Lewis Brewing Company           0            San Marcos            TX      29.7874     -97.9467
# 7                     Armadillo Ale Works            221                   S BELL AVENUE                DENTON    TX         Brewery    2/19/2015          Open             1        9316                     Armadillo Ale Works™          28                Denton            TX      33.2126     -97.1281
# 8                         Athens Brewing             101                  E TYLER STREET                ATHENS    TX         Brewery    4/18/2016          Open             1      267312                   Athens Brewing Company          35                Athens            TX      32.2054     -95.8538
# 9                        Austin Beerworks           3009    INDUSTRIAL TERRACE SUITE 150                AUSTIN    TX         Brewery   12/30/2010          Open             1       11819                         Austin Beerworks         266                Austin            TX      30.3798     -97.7302
# 10                     Backstory  Brewery            211                 MAGNOLIA STREET       SULPHUR SPRINGS    TX         Brewery   10/31/2017          Open             1      393158                       BackStory Brewery           40       Sulphur Springs            TX      33.1348     -95.6048
# 11                     Bear King Brewing             207                           AVE G          MARBLE FALLS    TX         Brewery   11/28/2018          Open             1      421863                Bear King Brewing Company          14          Marble Falls            TX      30.5703     -98.2749
# 12                Bitter Sisters Brewing           15103              SURVEYOR BOULEVARD               ADDISON    TX         Brewery    8/22/2014          Open             1       72194           Bitter Sisters Brewing Company          41               Addison            TX      32.9618     -96.8292
# 13                       Bluebonnet Beer            1700           BRYANT DRIVE UNIT 107            ROUND ROCK    TX         Brewery     4/1/2014          Open             1      168065                  Bluebonnet Beer Company          51            Round Rock            TX      30.4919     -97.6470
# 14                    Brotherwell Brewing            400                 E BRIDGE STREET                  WACO    TX         Brewery    11/9/2017          Open             2      385504                      Brotherwell Brewing          14                  Waco            TX      31.5645     -97.1243
# 15                    Brotherwell Brewing            400                 E BRIDGE STREET                  WACO    TX         Brewery    11/9/2017          Open             2      185400       Brotherwell Brewing Co. (Homebrew)           0                  Waco            TX      31.5493     -97.1467
# 16                 Buffalo Bayou Brewing            2101                   SUMMER STREET               HOUSTON    TX         Brewery    9/24/2018          Open             1       15624                    Buffalo Bayou Brewing         189               Houston            TX      29.7762     -95.4159
# 17                     Bull Creek Brewing           7100              FM 3405 BUILDING 1          LIBERTY HILL    TX         Brewery    3/12/2013          Open             1      208827                      Bull Creek Brewing           32          Liberty Hill            TX      30.7052     -97.8702
# 18                          Celis Brewery          10001                METRIC BOULEVARD                AUSTIN    TX         Brewery    5/15/2017          Open             1      305923                            Celis Brewery          48                Austin            TX      30.3797     -97.7160
# 19                        Community Beer            1530     INSPIRATION DRIVE SUITE 200                DALLAS    TX         Brewery     2/1/2013          Open             2       48372                   Community Beer Company         213                Dallas            TX      32.7909     -96.8158
# 20            Cypress Creek Southern Ales            200               E CARNEGIE STREET             WINNSBORO    TX         Brewery    8/18/2017          Open             1      340519              Cypress Creek Southern Ales          47             Winnsboro            TX      32.9558     -95.2895
# 21                    Deep Ellum Brewing            2823              SAINT LOUIS STREET                DALLAS    TX         Brewery    3/17/2017          Open             1       11028               Deep Ellum Brewing Company          65                Dallas            TX      32.7808     -96.7817
# 22                      Dirty Job Brewing            117                   N MAIN STREET             MANSFIELD    TX         Brewery     5/4/2017          Open             1      226688                        Dirty Job Brewing          51             Mansfield            TX      32.5643     -97.1422
# 23                     Eccentric Brewing            1402                COTTON FLAT ROAD               MIDLAND    TX         Brewery     5/4/2018          Open             1      399986                Eccentric Brewing Company          16               Midland            TX      31.9803    -102.0950
# 24                 Edgewise Eight Brewing           6488                          FM 920           WEATHERFORD    TX         Brewery   10/17/2018          Open             1      358992                   Edgewise Eight Brewing          24           Weatherford            TX      32.7593     -97.7973
# 25                   Four Bullets Brewery            640             N INTERURBAN STREET            RICHARDSON    TX         Brewery    10/7/2014          Open             1       48543                     Four Bullets Brewery          22            Richardson            TX      32.9592     -96.7261
# 26                Four Corners Brewing Co           1311                         S ERVAY                DALLAS    TX         Brewery    5/15/2017          Open             1       29815             Four Corners Brewing Company         133                Dallas            TX      32.7720     -96.7918
# 27                     Franconia Brewing             495                MCKINNEY PARKWAY              MCKINNEY    TX         Brewery    1/23/2008          Open             1        7329               Franconia Brewing Company           79              McKinney            TX      33.2134     -96.6091
# 28                      Frontyard Brewing           1607     N CUERNAVACA DRIVE UNIT 202                AUSTIN    TX         Brewery     5/8/2017          Open             2      383520                        Frontyard Brewing           6                Austin            TX      30.3394     -97.8634
# 29                     Fulbrook Ale Works           1125                          FM 359              RICHMOND    TX         Brewery   11/17/2017          Open             1      375720                       Fulbrook Ale Works          38              Richmond            TX      29.6119     -95.7438
# 30                    Galveston Bay Beer           12900                         FM 3436            TEXAS CITY    TX         Brewery    8/12/2014          Open             1      173145               Galveston Bay Beer Company          90             Dickinson            TX      29.4836     -95.0086
# 31                        Gilmer Brewing             101                  W TYLER STREET                GILMER    TX         Brewery     9/6/2018          Open             1      372138                   Gilmer Brewing Company           9                Gilmer            TX      32.7285     -94.9447
# 32                        Goliad Brewing             252                    METTING ROAD                GOLIAD    TX         Brewery   12/10/2013          Open             1      113303                   Goliad Brewing Company          18                Goliad            TX      28.6683     -97.3883
# 33                       Hedgehog Brewing           3200          WOODALL DRIVE UNIT C-1            CEDAR PARK    TX         Brewery    1/23/2019          Open             3      427843                         Hedgehog Brewing           3            Cedar Park            TX      30.5149     -97.8770
# 34                     Hemisphere Brewing           2015                     KRISTY LANE              ROCKWALL    TX         Brewery     6/1/2016          Open             1      330978                      Hemisphere Brewing           39              Rockwall            TX      32.9126     -96.4405
# 35                      Highwheel Brewing           1902                 S FLORES STREET           SAN ANTONIO    TX         Brewery    9/24/2015          Open             2      292601          Dorćol Distilling + Brewing Co.          27           San Antonio            TX      29.4057     -98.5023
# 36                         Holler Brewing           2206          EDWARDS STREET SUITE A               HOUSTON    TX         Brewery     9/8/2015          Open             3      270322                       Holler Brewing Co.         114               Houston            TX      29.7708     -95.3803
# 37                 Hop And Sting Brewing             906                     JEAN STREET             GRAPEVINE    TX         Brewery   10/24/2017          Open             1      330503            Hop And Sting Brewing Company          44             Grapevine            TX      32.9326     -97.0748
# 38                    Hopfusion Ale Works            200               E BROADWAY AVENUE            FORT WORTH    TX         Brewery    1/29/2016          Open             1      197427                      HopFusion Ale Works          91            Fort Worth            TX      32.7416     -97.3247
# 39                Independence Brewing Co           3913                    TODD LN #607                AUSTIN    TX         Brewery    9/22/2004          Open             1        2252                 Independence Brewing Co.          25                Austin            TX      30.2131     -97.7358
# 40                      Ivanhoe Ale Works            220                   W MAIN STREET               DENISON    TX         Brewery     1/2/2015          Open             1      204652                        Ivanhoe Ale Works          19               Denison            TX      33.7551     -96.5378
# 41                       Karbach Brewing            2032                  KARBACH STREET               HOUSTON    TX         Brewery     3/7/2011          Open             1       14665                       Karbach Brewing Co          83               Houston            TX      29.8059     -95.4610
# 42                      Lakewood Brewing            2302                 EXECUTIVE DRIVE               GARLAND    TX         Brewery     5/1/2012          Open             1       11862                 Lakewood Brewing Company          90               Garland            TX      32.8899     -96.6809
# 43                          Landon Winery           2400                  JOHNSON STREET            GREENVILLE    TX         Brewery     3/9/2017  In the works             1      356910                            Landon Winery           5            Greenville            TX      33.1401     -96.1067
# 44                    Legal Draft Beer Co            500               E DIVISION STREET             ARLINGTON    TX         Brewery     4/1/2016          Open             1      235234                     Legal Draft Beer Co.          55             Arlington            TX      32.7382     -97.1025
# 45                      Live Oak Brewing            1615                    CROZIER LANE                AUSTIN    TX         Brewery   10/20/2015          Open             1         797                 Live Oak Brewing Company          41                Austin            TX      30.2200     -97.6608
# 46                      Lone Pint Brewery            507                 COMMERCE STREET              MAGNOLIA    TX         Brewery    9/10/2012          Open             1       47425                        Lone Pint Brewery          45              Magnolia            TX      30.2089     -95.7514
# 47                       Lorelei Brewing             520        NAS DRIVE BUILDING BL002        CORPUS CHRISTI    TX         Brewery   11/26/2018          Open             1      249178                  Lorelei Brewing Company          41        Corpus Christi            TX      27.6743     -97.2793
# 48                  Martin House Brewing             220     S SYLVANIA AVENUE SUITE 209            FORT WORTH    TX         Brewery    11/8/2012          Open             1       27621             Martin House Brewing Company         447            Fort Worth            TX      32.7637     -97.3098
# 49                  New Republic Brewing           11405           N DOWLING ROAD UNIT C       COLLEGE STATION    TX         Brewery    3/16/2011          Open             1        8767             New Republic Brewing Company         119       College Station            TX      30.5650     -96.3501
# 50                     Oak Cliff Brewing            1300         S POLK STREET SUITE 222                DALLAS    TX         Brewery     4/4/2018          Open             1      269352                     Oak Cliff Brewing Co          31                Dallas            TX      32.7327     -96.8389
# 51                  Oak Highlands Brewery          10484                  BROCKWOOD ROAD                DALLAS    TX         Brewery    5/18/2015          Open             1       65272                    Oak Highlands Brewery         110                Dallas            TX      32.8901     -96.7046
# 52                     Old Town Brewhouse            146                  WHATLEY AVENUE            LEWISVILLE    TX         Brewery    11/4/2013          Open             1       71438                       Old Town BrewHouse          41            Lewisville            TX      33.0437     -96.9932
# 53                            Orf Brewing           4700            BURLESON ROAD UNIT F                AUSTIN    TX         Brewery     1/6/2016          Open             1       16504                              Orf Brewing          17                Austin            TX      30.2619     -97.7268
# 54                   Pegasus City Brewery           2222                  VANTAGE STREET                DALLAS    TX         Brewery    1/24/2017          Open             1      336618                     Pegasus City Brewery          28                Dallas            TX      32.7993     -96.8339
# 55                     Peticolas Brewing            2026               FARRINGTON STREET                DALLAS    TX         Brewery    8/25/2011          Open             1       13688                Peticolas Brewing Company          37                Dallas            TX      32.7964     -96.8285
# 56                 Rabble-Rouser Brewing             301     E CEDAR AVENUE BUILDING 100               MCALLEN    TX         Brewery    9/28/2015          Open             1      270055                 Rabble-Rouser Brewing Co          62               McAllen            TX      26.2034     -98.2300
# 57                    Rahr   Sons Brewing            701                GALVESTON AVENUE            FORT WORTH    TX         Brewery    7/20/2004          Open             1        1038              Rahr & Sons Brewing Company          34            Fort Worth            TX      32.7366     -97.3274
# 58      Ranger Creek Brewing   Distilling           4834       WHIRLWIND DRIVE SUITE 102           SAN ANTONIO    TX         Brewery    8/13/2010          Open             1        2922        Ranger Creek Brewing & Distilling         100           San Antonio            TX      29.5295     -98.3969
# 59                      Real Ale Brewing             231                  SAN SABA COURT                BLANCO    TX         Brewery    4/13/1999          Open             1        1044                 Real Ale Brewing Company         280                Blanco            TX      30.1133     -98.4128
# 60                       Red Gap Brewing             712                   CONRAD HILTON                 CISCO    TX         Brewery     5/2/2017          Open             1      345151                         Red Gap  Brewing          25                 Cisco            TX      32.3881     -98.9797
# 61                       Revolver Brewing           5650                    MATLOCK ROAD              GRANBURY    TX         Brewery   12/13/2017          Open             1       30341                         Revolver Brewing          61              Granbury            TX      32.4189     -97.6699
# 62                                   Ruba           3310            BUTTERCUP STREET '1'               HOUSTON    TX         Brewery    4/21/2008          Open             3      197161                             Ruba Brewing           2               Houston            TX      29.7604     -95.3698
# 63                  Saint Arnold Brewing            2000     LYONS AVENUE INCLUDING 2104               HOUSTON    TX         Brewery    4/22/1994          Open             1        2940             Saint Arnold Brewing Company         138               Houston            TX      29.7714     -95.3486
# 64                 Southern Star Brewing            3525                N FRAZIER STREET                CONROE    TX         Brewery    1/29/2009          Open             1        1172            Southern Star Brewing Company          87                Conroe            TX      30.3473     -95.4349
# 65                       Spoetzl Brewery             603                E BREWERY STREET                SHINER    TX         Brewery     1/3/2000          Open             1        1179                          Spoetzl Brewery          76                Shiner            TX      29.4291     -97.1705
# 66                      Texas Ale Project           1001                    N RIVERFRONT                DALLAS    TX         Brewery    3/28/2014          Open             1      134551                        Texas Ale Project         103                Dallas            TX      32.7862     -96.8175
# 67                     The Plains Brew Co            515                    FM 179 NORTH               LUBBOCK    TX         Brewery     2/5/2016          Open             1      317018                       The Plains Brew Co           5               Lubbock            TX      33.6061    -102.0100
# 68                    Thirsty Bro Brewing            141                   E MAIN STREET            ROYSE CITY    TX         Brewery    9/23/2016          Open             1      320254                      Thirsty Bro Brewing          24            Royse City            TX      32.9751     -96.3313
# 69                Thirsty Planet Brewing            8201               S CONGRESS AVENUE                AUSTIN    TX         Brewery    1/29/2010          Open             1        3587           Thirsty Planet Brewing Company         123                Austin            TX      30.2258     -97.9522
# 70                     True Vine Brewing            2453                   EARL CAMPBELL                 TYLER    TX         Brewery    4/16/2018          Open             1       98683                True Vine Brewing Company         106                 Tyler            TX      32.3276     -95.3249
# 71                          Tupps Brewery            721                        ANDERSON              MCKINNEY    TX         Brewery    2/13/2015          Open             1      196598                            TUPPS Brewery          66              McKinney            TX      33.1972     -96.6398
# 72                     Twisted X Brewing           23455                     RR 150 WEST      DRIPPING SPRINGS    TX         Brewery     2/2/2011          Open             1       11299                Twisted X Brewing Company          28      Dripping Springs            TX      30.1651     -98.0847
# 73                  Uncle Billy's Brewery           1530             BARTON SPRINGS ROAD                AUSTIN    TX         Brewery    5/26/2017          Open             1        3118                    Uncle Billy's Brewery          95                Austin            TX      30.2621     -97.7613
# 74                        Uncultured Ales          12307              ROXIE DR SUITE 206                AUSTIN    TX         Brewery     2/7/2017          Open             1      389634                          Uncultured Ales           8                Austin            TX      30.4460     -97.7803
# 75                Under The Radar Brewery           1506                 TRUXILLO STREET               HOUSTON    TX         Brewery    11/6/2015          Open             1      272370                  Under The Radar Brewery         105               Houston            TX      29.7342     -95.3759
# 76                     Wild Acre Brewing            1734      E EL PASO STREET SUITE 190            FORT WORTH    TX         Brewery   10/22/2015          Open             1      254782                Wild Acre Brewing Company          61            Fort Worth            TX      32.7439     -97.3094
# 77                  Wild Bunch Brewing Co           1764               TAYLORSVILLE ROAD              RED ROCK    TX         Brewery    4/17/2013          Open             1       75934               Wild Bunch Brewing Company          18              Red Rock            TX      29.8694     -97.4454
# 78                     Woodcreek Brewing            1400                  IH 30E SUITE A              ROCKWALL    TX         Brewery    3/23/2015          Open             1      217818                Woodcreek Brewing Company          17              Rockwall            TX      32.9133     -96.4413
# 79                        Zilker Brewing            1701                    E 6TH STREET                AUSTIN    TX         Brewery    1/22/2015          Open             1      194786                   Zilker Brewing Company         107                Austin            TX      30.2621     -97.7245
# 80                      11 Below Brewing            6820                  BOURGEOIS ROAD               HOUSTON    TX         Brewpub    5/31/2017          Open             1      149514                         11 Below Brewing          61               Houston            TX      29.9526     -95.5189
# 81                         12 Fox Beer Co           4700                 W FITZHUGH ROAD      DRIPPING SPRINGS    TX         Brewpub    9/27/2018          Open             1      431694                      12 Fox Beer Company          21      Dripping Springs            TX      30.2581     -98.1443
# 82                            4J Brewing            1348                  CEDARPOST LANE               HOUSTON    TX         Brewpub   11/16/2015          Open             1      386621                       4J Brewing Company          12               Houston            TX      29.7947     -95.5241
# 83               5 Stones Artisan Brewery          11335                         FM 1863         NEW BRAUNFELS    TX         Brewpub   11/13/2017          Open             1       61531                 5 Stones Artisan Brewery         106         New Braunfels            TX      29.7099     -98.2645
# 84                         5X5 Brewing Co            801          N BRYAN ROAD SUITE 174               MISSION    TX         Brewpub    9/12/2017          Open             1      329524                          5x5 Brewing Co.          17               Mission            TX      26.2121     -98.3114
# 85                            903 Brewers           1720                    S ELM STREET               SHERMAN    TX         Brewpub     2/3/2017          Open             1       45007                              903 Brewers         102               Sherman            TX      33.6179     -96.6069
# 86                         Acopon Brewing            211                   MERCER STREET      DRIPPING SPRINGS    TX         Brewpub     4/7/2017          Open             1      353307                   Acopon Brewing Company          44      Dripping Springs            TX      30.1925     -98.0891
# 87                     Adelbert's Brewery           2314         RUTLAND DRIVE SUITE 100                AUSTIN    TX         Brewpub     3/8/2016          Open             1       20007                       Adelbert's Brewery         141                Austin            TX      30.3827     -97.7202
# 88                               Altstadt           6120                    HWY 290 EAST        FREDERICKSBURG    TX         Brewpub    5/12/2016          Open             9      331732                         Altstadt Brewery          30        Fredericksburg            TX      30.2252     -98.7949
# 89                      Angelina Brewing             118                    S 1ST STREET                LUFKIN    TX         Brewpub    4/29/2019          Open             1      432645                 Angelina Brewing Company          33                Lufkin            TX      31.3385     -94.7294
# 90                          Anvil Brewing            115                        COMPRESS             PITTSBURG    TX         Brewpub    6/23/2017          Open             3      350129                            Anvil Brewing          32             Pittsburg            TX      32.9971     -94.9671
# 91                               Aquabrew            150                     S LBJ DRIVE            SAN MARCOS    TX         Brewpub   11/17/2016          Open             1      286708                                 Aquabrew          28            San Marcos            TX      29.8812     -97.9402
# 92                         Astral Brewing           4816        N SHEPHERD DRIVE SUITE A               HOUSTON    TX         Brewpub    10/2/2018          Open             2      423344                           Astral Brewing          35               Houston            TX      29.8354     -95.4102
# 93                              Aurelia's           1620                    N RESLER 'C'               EL PASO    TX         Brewpub    11/3/2017          Open             2      429904       Aurellia's Bottle Shop & Brewhouse          48               El Paso            TX      31.8834    -106.5710
# 94                          B-52 Brewing           12470                     MILROY LANE                CONROE    TX         Brewpub    3/13/2014          Open             1       60207                          B52 Brewing Co.         529                Conroe            TX      30.3394     -95.5513
# 95                      Baa Baa Brewhouse            539                  FM 359 SUITE 7            BROOKSHIRE    TX         Brewpub     7/7/2015          Open             1      269031                        Baa Baa Brewhouse         118            Brookshire            TX      29.7730     -95.9506
# 96                      Back Pew Brewing           26452                    SORTERS ROAD                PORTER    TX         Brewpub    2/13/2018          Open             1      209430                 Back Pew Brewing Company          83                Porter            TX      30.0645     -95.2647
# 97               Back Unturned Brewing Co            516                 BROOKLYN AVENUE           SAN ANTONIO    TX         Brewpub    3/22/2019  In the works             1      370015                 Back Unturned Brewing Co           5                Boerne            TX      29.7947     -98.7320
# 98                    Bandera Ale Project           3540                HWY 16S SUITE 2A               BANDERA    TX         Brewpub    7/11/2017          Open             1      368670                      Bandera Ale Project          74               Bandera            TX      29.7412     -99.0282
# 99                    Bankhead Brewing Co           3840                     MAIN STREET               ROWLETT    TX         Brewpub    2/11/2016          Open             1      293554                     Bankhead Brewing Co.          44               Rowlett            TX      32.9027     -96.5656
# 100                       Bar D Brewhouse            213                   N HIGH STREET              SAN SABA    TX         Brewpub    9/16/2011          Open             1       79142                          Bar D Brewhouse          11              San Saba            TX      31.1967     -98.7184
# 101                     Bare Arms Brewing           2515                  LASALLE AVENUE                  WACO    TX         Brewpub    3/13/2015          Open             1      207020                        Bare Arms Brewing          78                  Waco            TX      31.5251     -97.1311
# 102                       Barrow Brewing             108                    ROYAL STREET                SALADO    TX         Brewpub     4/2/2015          Open             1      260725                           Barrow Brewing          47                Salado            TX      30.9428     -97.5360
# 103             Basement Brewers Of Texas            521                     CLAY STREET             KERRVILLE    TX         Brewpub    8/17/2017          Open             1      372643                Basement Brewers Of Texas         109             Kerrville            TX      30.0505     -99.1386
# 104           Batch Craft Beer   Kolaches           3220                      MANOR ROAD                AUSTIN    TX         Brewpub    11/8/2016          Open             1      388953              Batch Craft Beer & Kolaches          10                Austin            TX      30.2872     -97.7031
# 105                    Battlehops Brewing           6801                   HWY BOULEVARD                  KATY    TX         Brewpub     3/1/2018          Open             1      433670                       Battlehops Brewing          14                  Katy            TX      29.7855     -95.8376
# 106                  Bearded Fox Brewing           11729     SPRING CYPRESS ROAD SUITE R               TOMBALL    TX         Brewpub    8/22/2018          Open             1      181217              Bearded Fox Brewing Company          18               Tomball            TX      30.0123     -95.6031
# 107                    Beerfoot Beach Bar           2816                       AVE R 1/2             GALVESTON    TX         Brewpub     8/9/2005          Open             1       46947                       Beerfoot Beach Bar         154             Galveston            TX      29.2859     -94.7942
# 108                     Big River Brewery            505                        W NOLANA                 PHARR    TX         Brewpub    4/10/2017          Open             2      335433                        Big River Brewery          34                 Pharr            TX      26.2339     -98.1832
# 109                 Big Texan Steak Ranch           7701                      IH 40 EAST              AMARILLO    TX         Brewpub     7/9/1997          Open             1       13187                        Big Texan Brewery          29              Amarillo            TX      35.1935    -101.7550
# 110              Blackwater Draw Brewing             701                   N MAIN STREET                 BRYAN    TX         Brewpub    8/19/2015          Open             1       67349          Blackwater Draw Brewing Company         136                 Bryan            TX      30.6795     -96.3723
# 111                  Blazing Tree Brewery          11426                 ROJAS SPACE A13               EL PASO    TX         Brewpub    7/12/2017          Open             1      352567                     Blazing Tree Brewery          61               El Paso            TX      31.7392    -106.3180
# 112                      Blue Owl Brewing           2400           E CESAR CHAVEZ STREET                AUSTIN    TX         Brewpub    5/29/2014          Open             1      165600                         Blue Owl Brewing         128                Austin            TX      30.2549     -97.7177
# 113                    Blue Star Brewing            1414               S ALAMO SUITE 105           SAN ANTONIO    TX         Brewpub    5/13/1996          Open             1        3062                Blue Star Brewing Company          31           San Antonio            TX      29.4101     -98.4956
# 114                        Boerne Brewery              9                  HILL VIEW LANE                BOERNE    TX         Brewpub   12/16/2016          Open             1      105991                           Boerne Brewery           9                Boerne            TX      29.8068     -98.7340
# 115                Bold Republic Brewing             206               N PENELOPE STREET                BELTON    TX         Brewpub   10/27/2017          Open             1       32500  Old Republic Brewing Company (Homebrew)          25         Copperas Cove            TX       0.0000       0.0000
# 116                     Braindead Brewing           2625                     MAIN STREET                DALLAS    TX         Brewpub    2/11/2015          Open             1      185850                        BrainDead Brewing         227                Dallas            TX      32.7838     -96.7854
# 117                                 Brash            510                  W CROSSTIMBERS               HOUSTON    TX         Brewpub    2/24/2014          Open             5       34146                    Brash Brewing Company          49               Houston            TX      29.8281     -95.4061
# 118                     Bray's Smokehouse           1500              S BRAHMA BOULEVARD            KINGSVILLE    TX         Brewpub    9/17/2018  In the works             1      438226                       Bray’s Smoksehouse           5            Kingsville            TX      27.5028     -97.8555
# 119                Brazos Valley Brewing             201                    W 1ST STREET               BRENHAM    TX         Brewpub    5/12/2015          Open             1        9508                    Brazos Valley Brewing          79               Brenham            TX      30.1647     -96.3987
# 120                        Brewer's Table           4715                    E 5TH STREET                AUSTIN    TX         Brewpub     9/6/2017          Open             1      354788               The Brewer's Table (Texas)          21                Austin            TX      30.2528     -97.7022
# 121                        Brews Brothers           2404                          STRAND             GALVESTON    TX         Brewpub    5/16/2013          Open            25       52797                           Brews Brothers          17             Galveston            TX      29.3070     -94.7959
# 122                              Brewsome           1303                   N 10TH STREET               MCALLEN    TX         Brewpub   11/19/2018          Open             3      424047                         Brewsome Brewery          15               McAllen            TX      26.2154     -98.2282
# 123             Brick Vault Brewery   BBQ            100                    N 1ST STREET              MARATHON    TX         Brewpub     6/4/2018          Open             1      386390              Brick Vault Brewery And BBQ          32              Marathon            TX      30.2052    -103.2450
# 124                      Brutal Beerworks           8447                    BOULEVARD 26  NORTH RICHLAND HILLS    TX         Brewpub    2/28/2019          Open             1      178427                         Brutal Beerworks          59  North Richland Hills            TX      32.8343     -97.2289
# 125                            BS Brewing           1408                OLD LEHMANN ROAD                SEGUIN    TX         Brewpub     2/6/2015          Open            25       68349                               BS Brewing          44                Seguin            TX      29.6882     -97.9021
# 126                            BS Brewing           1408                OLD LEHMANN ROAD                SEGUIN    TX         Brewpub     2/6/2015          Open            25      426310               Two Bs Brewing  (Homebrew)           3                Austin            TX      30.2672     -97.7431
# 127                Busted Sandal Brewing            7114                   OAKLAWN DRIVE           SAN ANTONIO    TX         Brewpub   10/17/2016          Open             1       69502                    Busted Sandal Brewing          93           San Antonio            TX      29.4997     -98.5558
# 128                  By The Horns Brewing            109                   S MAIN STREET             MANSFIELD    TX         Brewpub   10/31/2017          Open             2      420484                     By The Horns Brewing          14             Mansfield            TX      32.5626     -97.1415
# 129                  Cactus Land Brewing             368                         CRD 325                ADKINS    TX         Brewpub     6/3/2016          Open             1      167945                  Cactus Land Brewing Co.          88                Adkins            TX      29.2896     -98.2543
# 130                     Caracara Brewing             100         E MARKET STREET SUITE A              LOCKHART    TX         Brewpub    7/26/2017          Open             1      381243                Caracara Brewing Company           16              Lockhart            TX      29.8836     -97.6720
# 131                  Cedar Creek Brewery             336           E CEDAR CREEK PARKWAY          SEVEN POINTS    TX         Brewpub    6/12/2014          Open             1       10537                      Cedar Creek Brewery          33          Seven Points            TX      32.3230     -96.2068
# 132                   Celestial Beerworks           2530                   BUTLER STREET                DALLAS    TX         Brewpub     7/6/2018          Open             1      360425                      Celestial Beerworks          86                Dallas            TX      32.8200     -96.8331
# 133             Cellarman's Pub   Brewery           2130                  TEXOMA PARKWAY               SHERMAN    TX         Brewpub    4/25/2017          Open             1      381643                Cellarman’s Pub & Brewery          21               Sherman            TX      33.6619     -96.5995
# 134              Central District Brewing            417                RED RIVER STREET                AUSTIN    TX         Brewpub    11/9/2018          Open             1      148155                 Central District Brewing          24                Austin            TX      30.2651     -97.7373
# 135               Cibolo Creek Brewing Co            448                          S MAIN                BOERNE    TX         Brewpub    9/14/2015          Open             2      145843                 Cibolo Creek Brewing Co.         159                Boerne            TX      29.7897     -98.7297
# 136               Cibolo Creek Brewing Co            448                          S MAIN                BOERNE    TX         Brewpub    9/14/2015          Open             2      131905  Cibolo Creek Brewing Company (Homebrew)           7                Cibolo            TX       0.0000       0.0000
# 137                       Circle Brewing            2340           W BRAKER LANE SUITE B                AUSTIN    TX         Brewpub    4/24/2018          Open             5        7620                       Circle Brewing Co.          32                Austin            TX      30.3911     -97.7159
# 138                     City Acre Brewing           3418                  TOPPING STREET               HOUSTON    TX         Brewpub     3/1/2013          Open             1       17811                        City Acre Brewing         116               Houston            TX      29.8570     -95.3351
# 139                      Compadre Brewing          16920     JOE BARBEE DRIVE BUILDING 1          PFLUGERVILLE    TX         Brewpub    11/9/2018          Open             1      429867                         Compadre Brewing          18          Pflugerville            TX      30.4700     -97.6646
# 140                    Copperhead Brewery            822                N FRAZIER STREET                CONROE    TX         Brewpub    7/12/2018          Open             4      162786                       Copperhead Brewery          41                Conroe            TX      30.3167     -95.4633
# 141                      Cowtown Brewing            1301                E BELKNAP STREET            FORT WORTH    TX         Brewpub    9/17/2018          Open             1      305104                      Cowtown Brewing Co.          23            Fort Worth            TX      32.7620     -97.3240
# 142            Cranky Britches Brewing Co           1675        DICKINSON AVENUE SUITE C             DICKINSON    TX         Brewpub    1/11/2018          Open             1       74833              Cranky Britches Brewing Co.          42             Dickinson            TX      29.4855     -95.0471
# 143                       Cyclers Brewing          17105                     OSBORN ROAD            MONTGOMERY    TX         Brewpub    7/30/2018          Open             1       42771                         Cycler's Brewing          35            Montgomery            TX      30.3642     -95.6964
# 144                    Dead Beach Brewery            406                         DURANGO               EL PASO    TX         Brewpub    9/11/2014          Open             1      234073                        DeadBeach Brewery         151               El Paso            TX      31.7554    -106.4920
# 145                Denton County Brewing             200               E MCKINNEY STREET                DENTON    TX         Brewpub    4/21/2016          Open             1      178455            Denton County Brewing Company         103                Denton            TX      33.2148     -97.1331
# 146                      Division Brewing            506                   E MAIN STREET             ARLINGTON    TX         Brewpub    8/10/2015          Open             7      198462                         Division Brewing         159             Arlington            TX      32.7363     -97.1022
# 147                  Double Horn Brewing             208                           AVE H          MARBLE FALLS    TX         Brewpub    4/13/2011          Open             1       13415              Double Horn Brewing Company          65          Marble Falls            TX      30.5711     -98.2767
# 148                    El Paso Brewing Co            810               TEXAS AVE SUITE B               EL PASO    TX         Brewpub    5/16/2016          Open             1      298229                  El Paso Brewing Company          29               El Paso            TX      31.7622    -106.4810
# 149                Eola School Restaurant          12119                          FM 381                  EOLA    TX         Brewpub     8/9/2013          Open             1       10231         Eola School Brewery & Restaurant          25                  Eola            TX      31.3976    -100.0900
# 150                        ETX Brewing Co            221               S BROADWAY AVENUE                 TYLER    TX         Brewpub    9/24/2018          Open             1      288657                      ETX Brewing Company          82                 Tyler            TX      32.3487     -95.3010
# 151                 Family Business Beer           19510              HAMILTON POOL ROAD      DRIPPING SPRINGS    TX         Brewpub   10/15/2018          Open             1      378401             Family Business Beer Company          44      Dripping Springs            TX      30.2922     -98.0778
# 152                  Fetching Lab Brewery           1578                 CRD 423 SUITE B                 ALGOA    TX         Brewpub    12/2/2016          Open             1      204685                     Fetching Lab Brewery          54            Texas City            TX      29.3869     -94.9029
# 153                        Flix Brewhouse           1660                          FM 423            LITTLE ELM    TX         Brewpub     4/3/2018          Open             2       15976                           Flix Brewhouse         369            Round Rock            TX      30.4886     -97.6795
# 154                        Flix Brewhouse           2200                 IH 35S SUITE B1            ROUND ROCK    TX         Brewpub     8/4/2011          Open             2       15976                           Flix Brewhouse         369            Round Rock            TX      30.4886     -97.6795
# 155                   Flying Man Brewing            2400      PATTERSON INDUSTRIAL DRIVE                AUSTIN    TX         Brewpub    12/6/2016          Open             1      362120                       Flying Man Brewing          36                Austin            TX      30.4021     -97.6284
# 156                          Fort Brewery           1001               W MAGNOLIA AVENUE            FORT WORTH    TX         Brewpub    7/23/2018          Open            25       58169                   Fort Brewery and Pizza         118            Fort Worth            TX      32.7304     -97.3352
# 157                    Fortress Beerworks           2606             SPRING CYPRESS ROAD                SPRING    TX         Brewpub   12/17/2018          Open             1      425065                       Fortress BeerWorks          11                Spring            TX      30.0674     -95.4586
# ...
# 236             Save The World Brewing Co           1510                RESOURCE PARKWAY          MARBLE FALLS    TX         Brewpub    9/29/2017          Open             1      130116           Save The World Brewing Company          31          Marble Falls            TX      30.6168     -98.2640
# 237                        Sean Patrick's            202         E SAN ANTONIO SUITE 119            SAN MARCOS    TX         Brewpub    10/4/2010          Open             1      193131                 Sean Patrick's Irish Pub          63            San Marcos            TX      29.8820     -97.9396
# 238                       Seguin Brewing             111               W GONZALES STREET                SEGUIN    TX         Brewpub     8/1/2016          Open             1      172572                   Seguin Brewing Company          24                Seguin            TX      29.5654     -97.8928
# 239                      Shannon Brewing             818                   N MAIN STREET                KELLER    TX         Brewpub    3/30/2016          Open             1       88806                 Shannon Brewing Company           85                Keller            TX      32.9470     -97.2537
# 240                        Sigma Brewing            3118      HARRISBURG BOULEVARD '108'               HOUSTON    TX         Brewpub     6/5/2017          Open             2      297663                        Sigma Brewing Co.          76               Houston            TX      29.7492     -95.3435
# 241                 Six Car Pub   Brewery            625                   S POLK STREET              AMARILLO    TX         Brewpub    8/22/2017          Open             1      397107                    Six Car Pub & Brewery          45              Amarillo            TX      35.2069    -101.8370
# 242                         Small Brewpub            333           W JEFFERSON BOULEVARD                DALLAS    TX         Brewpub    9/24/2014          Open             1       97132                            Small Brewpub          97                Dallas            TX      32.7434     -96.8269
# 243                  Sockdolager Brewing             720                    CHINA STREET               ABILENE    TX         Brewpub     9/1/2016          Open             1      330005                      Sockdolager Brewing          63               Abilene            TX      32.4412     -99.7270
# 244                         Soco Taphouse            113         E CONCHO AVENUE SUITE L            SAN ANGELO    TX         Brewpub    3/10/2015          Open             1      198470                 SoCo Taphouse & Brew Co.          27            San Angelo            TX      31.4604    -100.4330
# 245                    Soul Fire Brewing             206            N OAK STREET SUITE A               ROANOKE    TX         Brewpub   10/11/2018  In the works             2      386749                     Soul Fire Brewing Co          14               Roanoke            TX      33.0001     -97.2280
# 246              Southern Heights Brewing           6014             TECHNI CENTER DRIVE                AUSTIN    TX         Brewpub     9/1/2017          Open             1      367119                 Southern Heights Brewing          18                Austin            TX      30.2767     -97.6695
# 247             Southern Roots Brewing Co            219                    N 8TH STREET                  WACO    TX         Brewpub     2/7/2019  In the works             1      434622           Southern Roots Brewing Company           8                  Waco            TX      31.5493     -97.1467
# 248                 Southern Yankee Beer             930                 FM 1960 SUITE G               HOUSTON    TX         Brewpub    8/14/2018          Open             1      409351             Southern Yankee Beer Company          36               Houston            TX      30.0242     -95.4154
# 249                  Spindle Tap Brewery           10622          HIRSCH ROAD BUILDING B               HOUSTON    TX         Brewpub    4/14/2016          Open             1      226007                       SpindleTap Brewery          62               Houston            TX      29.8682     -95.3144
# 250                      St Elmo Brewing             440      E SAINT ELMO ROAD SUITE G2                AUSTIN    TX         Brewpub    4/22/2016          Open             1      306224                  St Elmo Brewing Company         116                Austin            TX      30.2164     -97.7620
# 251                 Steam Theory Brewing             340   SINGLETON BOULEVARD SUITE 100                DALLAS    TX         Brewpub    2/28/2018          Open             1      130762             Steam Theory Brewing Company          25                Dallas            TX      32.7784     -96.8296
# 252              Struggle Street Brewing            2140                   CALDER AVENUE              BEAUMONT    TX         Brewpub    4/15/2019           NaN             1      421813          Struggle Street Brewing Company          45              Beaumont            TX      30.0861     -94.1174
# 253                  Suds Monkey Brewing            1032               CANYON BEND DRIVE      DRIPPING SPRINGS    TX         Brewpub    5/13/2016          Open             1      329990              Suds Monkey Brewing Company          23      Dripping Springs            TX      30.1944     -98.0240
# 254                          Sun Brewing             101                   LA UNION ROAD             CANUTILLO    TX         Brewpub    4/23/2014          Open             9      195771                      Sun Brewing Company          40             Canutillo            TX      31.9152    -106.6030
# 255                  Tall City Brewing Co           3303              W GOLF COURSE ROAD               MIDLAND    TX         Brewpub   11/27/2018          Open             1      333663                     Tall City Brewing Co           8               Midland            TX      32.0047    -102.1210
# 256                           Texas Beer            1331                    W 2ND STREET                TAYLOR    TX         Brewpub     8/7/2017          Open             1      269009                       Texas Beer Company          44                Taylor            TX      30.5689     -97.4100
# 257                Texas Leaguer Brewing           13503             PIKE ROAD SUITE 100         MISSOURI CITY    TX         Brewpub    8/18/2017          Open             1      124287            Texas Leaguer Brewing Company         105         Missouri City            TX      29.6277     -95.5478
# 258                        The Blue Onion            423       S INTERNATIONAL BOULEVARD               WESLACO    TX         Brewpub     4/3/2007          Open             1      112281                           The Blue Onion          32               Weslaco            TX      26.1603     -97.9585
# 259                           The Brewery            429                N ALISTER STREET          PORT ARANSAS    TX         Brewpub   12/17/2015          Open            25       47425                        Lone Pint Brewery          45              Magnolia            TX      30.2089     -95.7514
# 260                       The Brewery Lbk           1204                        BROADWAY               LUBBOCK    TX         Brewpub   10/20/2014          Open             1      390798                          The Brewery LBK          18               Lubbock            TX      33.5848    -101.8480
# 261                        The Brewtorium           6015          DILLARD CIRCLE SUITE A                AUSTIN    TX         Brewpub     4/3/2017          Open             1      294449       The Brewtorium - Brewery & Kitchen          43                Austin            TX      30.3260     -97.7167
# 262        The Collective Brewing Project            112                 ST LOUIS AVENUE            FORT WORTH    TX         Brewpub    8/14/2014          Open             1       75899           The Collective Brewing Project         162            Fort Worth            TX      32.7431     -97.3291
# 263             The Dodging Duck Brewhaus            402                      RIVER ROAD                BOERNE    TX         Brewpub     2/5/2002          Open             1        7514                    Dodging Duck Brewhaus         146                Boerne            TX      29.7899     -98.7259
# 264             The Phoenix On Westheimer           1915                 WESTHEIMER ROAD               HOUSTON    TX         Brewpub    1/11/2007          Open             1      195408                The Phoenix on Westheimer          29               Houston            TX      29.7425     -95.4077
# 265                         TKO Libations           2520     KING ARTHUR BOULEVARD '109'            LEWISVILLE    TX         Brewpub    2/14/2017          Open             1      367118                            TKO Libations         100            Lewisville            TX      33.0342     -96.8987
# 266                 True Anomaly Brewing            2012                   DALLAS STREET               HOUSTON    TX         Brewpub   10/16/2018          Open             1       10575                     True Anomaly Brewing          30               Houston            TX      29.7498     -95.3572
# 267                    Turning Point Beer           1307                     BROWN TRAIL               BEDFORD    TX         Brewpub    1/12/2018          Open             1      313044                       Turning Point Beer          91               Bedford            TX      32.8350     -97.1626
# 268                     Tusculum Brewing             236                   S MAIN STREET                BOERNE    TX         Brewpub    8/13/2018          Open             1      413407                 Tusculum Brewing Company          11                Boerne            TX      29.7920     -98.7311
# 269                            Twin Peaks           1500                    MARKET PLACE                IRVING    TX         Brewpub    3/19/2013          Open             4       78569                  Twin Peaks Brewing Co.           15                Irving            TX      32.9187     -96.9677
# 270                  Twisted Acre Brewery          16103              GRANT ROAD SPACE J               CYPRESS    TX         Brewpub     2/8/2018          Open             1      295983                     Twisted Acre Brewery          17               Cypress            TX      29.9717     -95.6938
# 271                    Two Wheel Brewing             535                    LOOP 4 SOUTH                  BUDA    TX         Brewpub   10/27/2016          Open             1      328713                Two Wheel Brewing Company          69                  Buda            TX      30.0730     -97.8445
# 272    Uncle Buck's Brewery   Steak House           2501        BASS PRO DRIVE SUITE 100             GRAPEVINE    TX         Brewpub    4/27/2007          Open             1        5027        Uncle Buck's Brewery & Steakhouse          22             Grapevine            TX      32.9571     -97.0431
# 273                            Union Bear           5880               HWY 121 SUITE 101                 PLANO    TX         Brewpub    7/28/2017          Open             2      371789               Union Bear Brewing Company          30                 Plano            TX      33.0908     -96.8215
# 274                            Union Bear           5880               HWY 121 SUITE 101                 PLANO    TX         Brewpub    7/28/2017          Open             2       37620                               Union Bear           0                Dallas            TX      32.8090     -96.7969
# 275             Unlawful Assembly Brewing           7800                 WINDROSE AVENUE                 PLANO    TX         Brewpub    9/22/2017          Open             1      343879        Unlawful Assembly Brewing Company          16                 Plano            TX      33.0831     -96.8252
# 276                   Vallensons Brewing            4081                 RICE DRIER ROAD              PEARLAND    TX         Brewpub    1/10/2017          Open             1      342490              Vallensons' Brewing Company          64              Pearland            TX      29.5757     -95.2873
# 277                         Vista Brewing          13551                     FM 150 WEST             DRIFTWOOD    TX         Brewpub     1/5/2018          Open            11      388757                            Vista Brewing          45             Driftwood            TX      30.1044     -98.0195
# 278                             Waco Ale             806                   AUSTIN AVENUE                  WACO    TX         Brewpub   12/12/2018  In the works             1      439925                         Waco Ale Company          13                  Waco            TX      31.5541     -97.1345
# 279               Walking Beam Brewing Co           1019                  HALSELL STREET            BRIDGEPORT    TX         Brewpub    11/6/2018          Open             1      421840                  Walking Beam Brewing Co          30            Bridgeport            TX      33.2106     -97.7572
# 280               Walking Stick Brewing              956                  JUDIWAY STREET               HOUSTON    TX         Brewpub   10/25/2016          Open             1      320994                Walking Stick Brewing Co.          17               Houston            TX      29.8210     -95.4234
# 281              Weathered Souls Brewing             606   EMBASSY OAKS SUITES 350 & 500           SAN ANTONIO    TX         Brewpub    5/17/2016          Open             1      264115              Weathered Souls Brewing Co.         318           San Antonio            TX      29.4876     -98.3974
# 282         White Rock Alehouse   Brewery           7331         GASTON AVENUE SUITE 100                DALLAS    TX         Brewpub        43048          Open             1      379699            White Rock Alehouse & Brewery          33                Dallas            TX      32.8128     -96.7299
# 283                    Whitestone Brewery            601          E WHITESTONE BOULEVARD            CEDAR PARK    TX         Brewpub        42151          Open             3      245366                       Whitestone Brewery          74            Cedar Park            TX      30.5235     -97.8243
# 284           Whole Foods Market Brewing            1700              POST OAK BOULEVARD               HOUSTON    TX         Brewpub        41779          Open             1      165604       Whole Foods Market Brewing Company         435               Houston            TX      29.7502     -95.4614
# 285                Wichita Falls Brewing             701                  INDIANA AVENUE         WICHITA FALLS    TX         Brewpub        42801          Open             1      360183            Wichita Falls Brewing Company          37         Wichita Falls            TX      33.9136     -98.4913
# 286                  Wicked Boxer Brewing          16326             MUESCHKE SUITE E-10               CYPRESS    TX         Brewpub        42906          Open             1      374693                     Wicked Boxer Brewing          40               Cypress            TX      30.0112     -95.7243
# 287                    Wimberley Brewing            9595                   RR 12 SUITE 9             WIMBERLEY    TX         Brewpub        39517          Open             1       10008                Wimberley Brewing Company          19             Wimberley            TX      29.9435     -98.0925
# 288                    Zero One Ale House             20             W BEAUREGARD AVENUE            SAN ANGELO    TX         Brewpub        40941          Open             1      189606                       Zero One Ale House          41            San Angelo            TX      31.4625    -100.4380

# %%
import pickle
import numpy as np
import pandas as pd
import math
from IPython.display import clear_output

# Load data
with open ("../data/all_breweries.pkl", "rb") as fp:
    all_breweries = pickle.load(fp)

untappd = Untappd()

i = 0
for brewery in all_breweries:
    if "brewery_id" in brewery and "brewery_info" not in brewery:
        brewery_info, counter, response = untappd.breweryInfo(brewery["brewery_id"])

        brewery["brewery_info"] = brewery_info
        
        clear_output(wait=True)
        display(counter)
        if counter == 0:
            break
        
with open("../data/all_breweries.pkl", "wb") as fp:
    pickle.dump(all_breweries, fp)
    
print("Sample output")
display(all_breweries[1]["brewery_info"])

print("Completed on ", datetime.now())
# Out:
# 33
# Sample output
# {'brewery': {'brewery_id': 420745,
#   'brewery_name': 'Two Docs Brewing Co.',
#   'brewery_slug': 'two-docs-brewing',
#   'brewery_page_url': '/TwoDocsBrewingCo',
#   'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#   'brewery_label_hd': '',
#   'country_name': 'United States',
#   'brewery_in_production': 0,
#   'is_independent': 1,
#   'claimed_status': {'is_claimed': True,
#    'claimed_slug': 'TwoDocsBrewingCo',
#    'follow_status': False,
#    'follower_count': 72,
#    'uid': 6376655,
#    'mute_status': 'none'},
#   'beer_count': 22,
#   'contact': {'twitter': '',
#    'facebook': 'https://www.facebook.com/twodocsbrewing',
#    'instagram': 'twodocsbrewing',
#    'url': 'https://twodocsbrewing.com/'},
#   'brewery_type': 'Micro Brewery',
#   'brewery_type_id': 2,
#   'location': {'brewery_address': '502 Texas Ave',
#    'brewery_city': 'Lubbock',
#    'brewery_state': 'TX',
#    'brewery_lat': 33.5909,
#    'brewery_lng': -101.846},
#   'rating': {'count': 1943, 'rating_score': 3.791},
#   'brewery_description': 'We want to share our love of craft beer with West Texas. When you come into our taproom an expert staff will welcome you to a place where you can explore beer, expand your tastes, and have a great time.',
#   'stats': {'total_count': 2400,
#    'unique_count': 711,
#    'monthly_count': 153,
#    'weekly_count': 0,
#    'user_count': 0,
#    'age_on_service': 271.9091550925926},
#   'owners': {'count': 0, 'items': []},
#   'media': {'count': 15,
#    'items': [{'photo_id': 261142284,
#      'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_29/233f0ee846113f965095404c85eb37a2_200x200.jpg',
#       'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_29/233f0ee846113f965095404c85eb37a2_640x640.jpg',
#       'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_29/233f0ee846113f965095404c85eb37a2_1280x1280.jpg',
#       'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_29/233f0ee846113f965095404c85eb37a2_raw.jpg'},
#      'created_at': 'Tue, 29 Oct 2019 00:03:24 +0000',
#      'checkin_id': 823141672,
#      'beer': {'bid': 3408493,
#       'beer_name': 'Hayes-E Baby IPA',
#       'beer_abv': 7.1,
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'IPA - New England'},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'user': {'uid': 1129994,
#       'user_name': 'Mikegib',
#       'first_name': 'Michael',
#       'last_name': 'G',
#       'user_avatar': 'https://untappd.akamaized.net/profile/8e268bea2010265abea610af88cbdbe7_100x100.jpg',
#       'is_private': 0},
#      'venue': {'venue_id': 9090786,
#       'venue_name': 'Growler USA - Lubbock',
#       'venue_slug': 'growler-usa-lubbock',
#       'primary_category': 'Food',
#       'parent_category_id': '4d4b7105d754a06374d81259',
#       'categories': {'count': 1,
#        'items': [{'category_key': 'restaurant',
#          'category_name': 'Restaurant',
#          'category_id': '4bf58dd8d48988d1c4941735',
#          'is_primary': True}]},
#       'location': {'venue_address': '6030 Marsha Sharp Fwy, Suite 200',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'lat': 33.5485,
#        'lng': -101.95},
#       'contact': {'twitter': '@GrowlerLubbock',
#        'venue_url': 'Growlerusa.com/Lubbock'},
#       'foursquare': {'foursquare_id': '5d10ed17de944500235ea31d',
#        'foursquare_url': 'https://4sq.com/2LcGU91'},
#       'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_9090786_674f03d3_bg_64.png',
#        'md': 'https://untappd.akamaized.net/venuelogos/venue_9090786_674f03d3_bg_88.png',
#        'lg': 'https://untappd.akamaized.net/venuelogos/venue_9090786_674f03d3_bg_176.png?v=1'},
#       'is_verified': 1}},
#     {'photo_id': 261057600,
#      'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_28/568310a2ebafd3160a91198fea23db06_200x200.jpg',
#       'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_28/568310a2ebafd3160a91198fea23db06_640x640.jpg',
#       'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_28/568310a2ebafd3160a91198fea23db06_1280x1280.jpg',
#       'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_28/568310a2ebafd3160a91198fea23db06_raw.jpg'},
#      'created_at': 'Mon, 28 Oct 2019 00:20:38 +0000',
#      'checkin_id': 822940561,
#      'beer': {'bid': 3408493,
#       'beer_name': 'Hayes-E Baby IPA',
#       'beer_abv': 7.1,
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'IPA - New England'},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'user': {'uid': 3203713,
#       'user_name': 'gpkennedy',
#       'first_name': 'Gabriel',
#       'last_name': 'K',
#       'user_avatar': 'https://untappd.akamaized.net/profile/02337b9a1b7b3852c11c8922b8b3d13a_100x100.jpg',
#       'is_private': 0},
#      'venue': {'venue_id': 8707470,
#       'venue_name': 'Two Docs Brewing Co.',
#       'venue_slug': 'two-docs-brewing-co',
#       'primary_category': 'Nightlife Spot',
#       'parent_category_id': '4d4b7105d754a06376d81259',
#       'categories': {'count': 1,
#        'items': [{'category_key': 'brewery',
#          'category_name': 'Brewery',
#          'category_id': '50327c8591d4c4b30a586d5d',
#          'is_primary': True}]},
#       'location': {'venue_address': '502 Texas Ave',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#       'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#        'foursquare_url': 'https://4sq.com/2IJTFbR'},
#       'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#        'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#        'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#       'is_verified': 1}},
#     {'photo_id': 261031935,
#      'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photo/2019_10_27/84cd98d68bd9eed8e7c0f1abd3f9b6ed_c_822872119_200x200.jpg',
#       'photo_img_md': 'https://untappd.akamaized.net/photo/2019_10_27/84cd98d68bd9eed8e7c0f1abd3f9b6ed_c_822872119_640x640.jpg',
#       'photo_img_lg': 'https://untappd.akamaized.net/photo/2019_10_27/84cd98d68bd9eed8e7c0f1abd3f9b6ed_c_822872119_1280x1280.jpg',
#       'photo_img_og': 'https://untappd.akamaized.net/photo/2019_10_27/84cd98d68bd9eed8e7c0f1abd3f9b6ed_c_822872119_raw.jpg'},
#      'created_at': 'Sun, 27 Oct 2019 21:52:57 +0000',
#      'checkin_id': 822872119,
#      'beer': {'bid': 3440110,
#       'beer_name': 'Doktoberfest',
#       'beer_abv': 6.1,
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'Festbier'},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'user': {'uid': 1242913,
#       'user_name': 'fthames',
#       'first_name': 'Frank',
#       'last_name': 'T',
#       'user_avatar': 'https://untappd.akamaized.net/profile/493c1601aacb58f0a4b764b93d780b51_100x100.jpg',
#       'is_private': 0},
#      'venue': {'venue_id': 8707470,
#       'venue_name': 'Two Docs Brewing Co.',
#       'venue_slug': 'two-docs-brewing-co',
#       'primary_category': 'Nightlife Spot',
#       'parent_category_id': '4d4b7105d754a06376d81259',
#       'categories': {'count': 1,
#        'items': [{'category_key': 'brewery',
#          'category_name': 'Brewery',
#          'category_id': '50327c8591d4c4b30a586d5d',
#          'is_primary': True}]},
#       'location': {'venue_address': '502 Texas Ave',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#       'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#        'foursquare_url': 'https://4sq.com/2IJTFbR'},
#       'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#        'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#        'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#       'is_verified': 1}},
#     {'photo_id': 260736276,
#      'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_26/36a735bfcb51f5b43464a2407f6e6f4a_200x200.jpg',
#       'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_26/36a735bfcb51f5b43464a2407f6e6f4a_640x640.jpg',
#       'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_26/36a735bfcb51f5b43464a2407f6e6f4a_1280x1280.jpg',
#       'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_26/36a735bfcb51f5b43464a2407f6e6f4a_raw.jpg'},
#      'created_at': 'Sat, 26 Oct 2019 19:22:30 +0000',
#      'checkin_id': 822145054,
#      'beer': {'bid': 3209433,
#       'beer_name': 'Dos Doctores',
#       'beer_abv': 5.4,
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'Lager - Vienna'},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'user': {'uid': 2109800,
#       'user_name': 'Jdlbk',
#       'first_name': 'Jess',
#       'last_name': 'W',
#       'user_avatar': 'https://gravatar.com/avatar/26951d2bdb4acfcb18b10ab0b2a7ea4a?size=100&d=https%3A%2F%2Funtappd.akamaized.net%2Fsite%2Fassets%2Fimages%2Fdefault_avatar_v3_gravatar.jpg%3Fv%3D2',
#       'is_private': 0},
#      'venue': {'venue_id': 8707470,
#       'venue_name': 'Two Docs Brewing Co.',
#       'venue_slug': 'two-docs-brewing-co',
#       'primary_category': 'Nightlife Spot',
#       'parent_category_id': '4d4b7105d754a06376d81259',
#       'categories': {'count': 1,
#        'items': [{'category_key': 'brewery',
#          'category_name': 'Brewery',
#          'category_id': '50327c8591d4c4b30a586d5d',
#          'is_primary': True}]},
#       'location': {'venue_address': '502 Texas Ave',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#       'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#        'foursquare_url': 'https://4sq.com/2IJTFbR'},
#       'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#        'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#        'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#       'is_verified': 1}},
#     {'photo_id': 260725438,
#      'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_26/d1f0ceddf29f2ac76a93a31d5e16f173_200x200.jpg',
#       'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_26/d1f0ceddf29f2ac76a93a31d5e16f173_640x640.jpg',
#       'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_26/d1f0ceddf29f2ac76a93a31d5e16f173_1280x1280.jpg',
#       'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_26/d1f0ceddf29f2ac76a93a31d5e16f173_raw.jpg'},
#      'created_at': 'Sat, 26 Oct 2019 19:00:20 +0000',
#      'checkin_id': 822119811,
#      'beer': {'bid': 3063015,
#       'beer_name': 'Prairie Dawg Porter',
#       'beer_abv': 5.9,
#       'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-3063015_38cdd_sm.jpeg',
#       'beer_style': 'Porter - American'},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'user': {'uid': 2109800,
#       'user_name': 'Jdlbk',
#       'first_name': 'Jess',
#       'last_name': 'W',
#       'user_avatar': 'https://gravatar.com/avatar/26951d2bdb4acfcb18b10ab0b2a7ea4a?size=100&d=https%3A%2F%2Funtappd.akamaized.net%2Fsite%2Fassets%2Fimages%2Fdefault_avatar_v3_gravatar.jpg%3Fv%3D2',
#       'is_private': 0},
#      'venue': {'venue_id': 8707470,
#       'venue_name': 'Two Docs Brewing Co.',
#       'venue_slug': 'two-docs-brewing-co',
#       'primary_category': 'Nightlife Spot',
#       'parent_category_id': '4d4b7105d754a06376d81259',
#       'categories': {'count': 1,
#        'items': [{'category_key': 'brewery',
#          'category_name': 'Brewery',
#          'category_id': '50327c8591d4c4b30a586d5d',
#          'is_primary': True}]},
#       'location': {'venue_address': '502 Texas Ave',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#       'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#        'foursquare_url': 'https://4sq.com/2IJTFbR'},
#       'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#        'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#        'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#       'is_verified': 1}},
#     {'photo_id': 260582371,
#      'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_26/d597f0ce32b3c872525eb9102e92ea20_200x200.jpg',
#       'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_26/d597f0ce32b3c872525eb9102e92ea20_640x640.jpg',
#       'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_26/d597f0ce32b3c872525eb9102e92ea20_1280x1280.jpg',
#       'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_26/d597f0ce32b3c872525eb9102e92ea20_raw.jpg'},
#      'created_at': 'Sat, 26 Oct 2019 04:19:47 +0000',
#      'checkin_id': 821803598,
#      'beer': {'bid': 3500094,
#       'beer_name': 'Prairie Dog Porter - Mexican Cocoa',
#       'beer_abv': 0,
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'Porter - Other'},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'user': {'uid': 1429511,
#       'user_name': 'dcsfoyle',
#       'first_name': 'Eric',
#       'last_name': 'R',
#       'user_avatar': 'https://untappd.akamaized.net/profile/a313cb1054443db78d8e914c4780daa4_100x100.jpg',
#       'is_private': 0},
#      'venue': {'venue_id': 8707470,
#       'venue_name': 'Two Docs Brewing Co.',
#       'venue_slug': 'two-docs-brewing-co',
#       'primary_category': 'Nightlife Spot',
#       'parent_category_id': '4d4b7105d754a06376d81259',
#       'categories': {'count': 1,
#        'items': [{'category_key': 'brewery',
#          'category_name': 'Brewery',
#          'category_id': '50327c8591d4c4b30a586d5d',
#          'is_primary': True}]},
#       'location': {'venue_address': '502 Texas Ave',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#       'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#        'foursquare_url': 'https://4sq.com/2IJTFbR'},
#       'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#        'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#        'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#       'is_verified': 1}},
#     {'photo_id': 260581452,
#      'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_26/9b2232b8a81c4408e643552cb57c7351_200x200.jpg',
#       'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_26/9b2232b8a81c4408e643552cb57c7351_640x640.jpg',
#       'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_26/9b2232b8a81c4408e643552cb57c7351_1280x1280.jpg',
#       'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_26/9b2232b8a81c4408e643552cb57c7351_raw.jpg'},
#      'created_at': 'Sat, 26 Oct 2019 04:09:49 +0000',
#      'checkin_id': 821802229,
#      'beer': {'bid': 3440110,
#       'beer_name': 'Doktoberfest',
#       'beer_abv': 6.1,
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'Festbier'},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'user': {'uid': 1017530,
#       'user_name': 'johnnyreina',
#       'first_name': 'Satan',
#       'last_name': '',
#       'user_avatar': 'https://untappd.akamaized.net/profile/e7291361ca25ff19c5944aea3e01e530_100x100.jpg',
#       'is_private': 0},
#      'venue': {'venue_id': 8707470,
#       'venue_name': 'Two Docs Brewing Co.',
#       'venue_slug': 'two-docs-brewing-co',
#       'primary_category': 'Nightlife Spot',
#       'parent_category_id': '4d4b7105d754a06376d81259',
#       'categories': {'count': 1,
#        'items': [{'category_key': 'brewery',
#          'category_name': 'Brewery',
#          'category_id': '50327c8591d4c4b30a586d5d',
#          'is_primary': True}]},
#       'location': {'venue_address': '502 Texas Ave',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#       'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#        'foursquare_url': 'https://4sq.com/2IJTFbR'},
#       'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#        'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#        'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#       'is_verified': 1}},
#     {'photo_id': 260578609,
#      'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_26/89e576a05a08f64a2906a74f2f78ba51_200x200.jpg',
#       'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_26/89e576a05a08f64a2906a74f2f78ba51_640x640.jpg',
#       'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_26/89e576a05a08f64a2906a74f2f78ba51_1280x1280.jpg',
#       'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_26/89e576a05a08f64a2906a74f2f78ba51_raw.jpg'},
#      'created_at': 'Sat, 26 Oct 2019 03:42:42 +0000',
#      'checkin_id': 821794344,
#      'beer': {'bid': 3408493,
#       'beer_name': 'Hayes-E Baby IPA',
#       'beer_abv': 7.1,
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'IPA - New England'},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'user': {'uid': 1017530,
#       'user_name': 'johnnyreina',
#       'first_name': 'Satan',
#       'last_name': '',
#       'user_avatar': 'https://untappd.akamaized.net/profile/e7291361ca25ff19c5944aea3e01e530_100x100.jpg',
#       'is_private': 0},
#      'venue': {'venue_id': 8707470,
#       'venue_name': 'Two Docs Brewing Co.',
#       'venue_slug': 'two-docs-brewing-co',
#       'primary_category': 'Nightlife Spot',
#       'parent_category_id': '4d4b7105d754a06376d81259',
#       'categories': {'count': 1,
#        'items': [{'category_key': 'brewery',
#          'category_name': 'Brewery',
#          'category_id': '50327c8591d4c4b30a586d5d',
#          'is_primary': True}]},
#       'location': {'venue_address': '502 Texas Ave',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#       'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#        'foursquare_url': 'https://4sq.com/2IJTFbR'},
#       'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#        'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#        'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#       'is_verified': 1}},
#     {'photo_id': 260577499,
#      'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_26/0cec2d2c63d8195ea71e09037d2650b9_200x200.jpg',
#       'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_26/0cec2d2c63d8195ea71e09037d2650b9_640x640.jpg',
#       'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_26/0cec2d2c63d8195ea71e09037d2650b9_1280x1280.jpg',
#       'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_26/0cec2d2c63d8195ea71e09037d2650b9_raw.jpg'},
#      'created_at': 'Sat, 26 Oct 2019 03:33:34 +0000',
#      'checkin_id': 821791136,
#      'beer': {'bid': 3408493,
#       'beer_name': 'Hayes-E Baby IPA',
#       'beer_abv': 7.1,
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'IPA - New England'},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'user': {'uid': 1017530,
#       'user_name': 'johnnyreina',
#       'first_name': 'Satan',
#       'last_name': '',
#       'user_avatar': 'https://untappd.akamaized.net/profile/e7291361ca25ff19c5944aea3e01e530_100x100.jpg',
#       'is_private': 0},
#      'venue': {'venue_id': 8707470,
#       'venue_name': 'Two Docs Brewing Co.',
#       'venue_slug': 'two-docs-brewing-co',
#       'primary_category': 'Nightlife Spot',
#       'parent_category_id': '4d4b7105d754a06376d81259',
#       'categories': {'count': 1,
#        'items': [{'category_key': 'brewery',
#          'category_name': 'Brewery',
#          'category_id': '50327c8591d4c4b30a586d5d',
#          'is_primary': True}]},
#       'location': {'venue_address': '502 Texas Ave',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#       'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#        'foursquare_url': 'https://4sq.com/2IJTFbR'},
#       'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#        'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#        'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#       'is_verified': 1}},
#     {'photo_id': 260552871,
#      'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_26/952e03e92a6d47a8af5381e91cf136db_200x200.jpg',
#       'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_26/952e03e92a6d47a8af5381e91cf136db_640x640.jpg',
#       'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_26/952e03e92a6d47a8af5381e91cf136db_1280x1280.jpg',
#       'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_26/952e03e92a6d47a8af5381e91cf136db_raw.jpg'},
#      'created_at': 'Sat, 26 Oct 2019 01:20:44 +0000',
#      'checkin_id': 821721707,
#      'beer': {'bid': 3063015,
#       'beer_name': 'Prairie Dawg Porter',
#       'beer_abv': 5.9,
#       'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-3063015_38cdd_sm.jpeg',
#       'beer_style': 'Porter - American'},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'user': {'uid': 5298782,
#       'user_name': 'redlacedoxfords',
#       'first_name': 'Kelsey',
#       'last_name': 'S',
#       'user_avatar': 'https://untappd.akamaized.net/profile/56835bf4a415ef8dbb681ba00e7e7b5d_100x100.jpg',
#       'is_private': 0},
#      'venue': []},
#     {'photo_id': 260293102,
#      'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_24/9e3175a4e87a3954c8cd40fa72a9270b_200x200.jpg',
#       'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_24/9e3175a4e87a3954c8cd40fa72a9270b_640x640.jpg',
#       'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_24/9e3175a4e87a3954c8cd40fa72a9270b_1280x1280.jpg',
#       'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_24/9e3175a4e87a3954c8cd40fa72a9270b_raw.jpg'},
#      'created_at': 'Thu, 24 Oct 2019 22:43:27 +0000',
#      'checkin_id': 821113091,
#      'beer': {'bid': 3440110,
#       'beer_name': 'Doktoberfest',
#       'beer_abv': 6.1,
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'Festbier'},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'user': {'uid': 3414905,
#       'user_name': 'dpftex',
#       'first_name': 'Danny',
#       'last_name': 'F',
#       'user_avatar': 'https://untappd.akamaized.net/profile/2d871269d7f4e088e418dfe2793e064d_100x100.jpeg',
#       'is_private': 0},
#      'venue': {'venue_id': 3408071,
#       'venue_name': 'Flippers Tavern',
#       'venue_slug': 'flippers-tavern',
#       'primary_category': 'Food',
#       'parent_category_id': '4d4b7105d754a06374d81259',
#       'categories': {'count': 3,
#        'items': [{'category_key': 'hot_dog_joint',
#          'category_name': 'Hot Dog Joint',
#          'category_id': '4bf58dd8d48988d16f941735',
#          'is_primary': True},
#         {'category_key': 'arcade',
#          'category_name': 'Arcade',
#          'category_id': '4bf58dd8d48988d1e1931735',
#          'is_primary': False},
#         {'category_key': 'bar',
#          'category_name': 'Bar',
#          'category_id': '4bf58dd8d48988d116941735',
#          'is_primary': False}]},
#       'location': {'venue_address': '1406 Avenue Q',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'lat': 33.5824,
#        'lng': -101.855},
#       'contact': {'twitter': '', 'venue_url': ''},
#       'foursquare': {'foursquare_id': '55caaa5a498e79b3b94477a7',
#        'foursquare_url': 'http://4sq.com/1N1TItL'},
#       'venue_icon': {'sm': 'https://ss3.4sqi.net/img/categories_v2/food/hotdog_bg_64.png',
#        'md': 'https://ss3.4sqi.net/img/categories_v2/food/hotdog_bg_88.png',
#        'lg': 'https://ss3.4sqi.net/img/categories_v2/food/hotdog_bg_512.png'},
#       'is_verified': 0}},
#     {'photo_id': 260166345,
#      'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_23/b86e4251d6569cf2edf0a1068aeff541_200x200.jpg',
#       'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_23/b86e4251d6569cf2edf0a1068aeff541_640x640.jpg',
#       'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_23/b86e4251d6569cf2edf0a1068aeff541_1280x1280.jpg',
#       'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_23/b86e4251d6569cf2edf0a1068aeff541_raw.jpg'},
#      'created_at': 'Wed, 23 Oct 2019 23:02:43 +0000',
#      'checkin_id': 820818891,
#      'beer': {'bid': 3062868,
#       'beer_name': 'Buddy Hoppy IPA',
#       'beer_abv': 8.2,
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'IPA - American'},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'user': {'uid': 661191,
#       'user_name': 'Jgthomp',
#       'first_name': 'Jason',
#       'last_name': 'T',
#       'user_avatar': 'https://untappd.akamaized.net/profile/72eb38d3243cfba9b57035294292226e_100x100.jpg',
#       'is_private': 0},
#      'venue': {'venue_id': 8707470,
#       'venue_name': 'Two Docs Brewing Co.',
#       'venue_slug': 'two-docs-brewing-co',
#       'primary_category': 'Nightlife Spot',
#       'parent_category_id': '4d4b7105d754a06376d81259',
#       'categories': {'count': 1,
#        'items': [{'category_key': 'brewery',
#          'category_name': 'Brewery',
#          'category_id': '50327c8591d4c4b30a586d5d',
#          'is_primary': True}]},
#       'location': {'venue_address': '502 Texas Ave',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#       'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#        'foursquare_url': 'https://4sq.com/2IJTFbR'},
#       'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#        'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#        'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#       'is_verified': 1}},
#     {'photo_id': 260059867,
#      'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_22/1b87a5ec23cf1196e413e032e6e0bae1_200x200.jpg',
#       'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_22/1b87a5ec23cf1196e413e032e6e0bae1_640x640.jpg',
#       'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_22/1b87a5ec23cf1196e413e032e6e0bae1_1280x1280.jpg',
#       'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_22/1b87a5ec23cf1196e413e032e6e0bae1_raw.jpg'},
#      'created_at': 'Tue, 22 Oct 2019 23:32:43 +0000',
#      'checkin_id': 820573344,
#      'beer': {'bid': 3440110,
#       'beer_name': 'Doktoberfest',
#       'beer_abv': 6.1,
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'Festbier'},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'user': {'uid': 184852,
#       'user_name': 'MarkTTU',
#       'first_name': 'Mark',
#       'last_name': '',
#       'user_avatar': 'https://untappd.akamaized.net/profile/4b6c6af4442c4021c99069ddb3c2648d_100x100.jpg',
#       'is_private': 0},
#      'venue': {'venue_id': 8707470,
#       'venue_name': 'Two Docs Brewing Co.',
#       'venue_slug': 'two-docs-brewing-co',
#       'primary_category': 'Nightlife Spot',
#       'parent_category_id': '4d4b7105d754a06376d81259',
#       'categories': {'count': 1,
#        'items': [{'category_key': 'brewery',
#          'category_name': 'Brewery',
#          'category_id': '50327c8591d4c4b30a586d5d',
#          'is_primary': True}]},
#       'location': {'venue_address': '502 Texas Ave',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#       'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#        'foursquare_url': 'https://4sq.com/2IJTFbR'},
#       'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#        'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#        'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#       'is_verified': 1}},
#     {'photo_id': 259817533,
#      'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_20/a457d5e9ec3377b0d1bea8553990d879_200x200.jpg',
#       'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_20/a457d5e9ec3377b0d1bea8553990d879_640x640.jpg',
#       'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_20/a457d5e9ec3377b0d1bea8553990d879_1280x1280.jpg',
#       'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_20/a457d5e9ec3377b0d1bea8553990d879_raw.jpg'},
#      'created_at': 'Sun, 20 Oct 2019 19:23:51 +0000',
#      'checkin_id': 819991411,
#      'beer': {'bid': 3408493,
#       'beer_name': 'Hayes-E Baby IPA',
#       'beer_abv': 7.1,
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'IPA - New England'},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'user': {'uid': 1847754,
#       'user_name': 'Nobandsland1',
#       'first_name': 'Dirk',
#       'last_name': 'D',
#       'user_avatar': 'https://untappd.akamaized.net/profile/25a524f8bc4cf1a6b70877258bf9906f_100x100.jpg',
#       'is_private': 0},
#      'venue': {'venue_id': 8707470,
#       'venue_name': 'Two Docs Brewing Co.',
#       'venue_slug': 'two-docs-brewing-co',
#       'primary_category': 'Nightlife Spot',
#       'parent_category_id': '4d4b7105d754a06376d81259',
#       'categories': {'count': 1,
#        'items': [{'category_key': 'brewery',
#          'category_name': 'Brewery',
#          'category_id': '50327c8591d4c4b30a586d5d',
#          'is_primary': True}]},
#       'location': {'venue_address': '502 Texas Ave',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#       'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#        'foursquare_url': 'https://4sq.com/2IJTFbR'},
#       'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#        'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#        'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#       'is_verified': 1}},
#     {'photo_id': 259817000,
#      'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_20/27f53e0838d906a53ac265e1ef6acabb_200x200.jpg',
#       'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_20/27f53e0838d906a53ac265e1ef6acabb_640x640.jpg',
#       'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_20/27f53e0838d906a53ac265e1ef6acabb_1280x1280.jpg',
#       'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_20/27f53e0838d906a53ac265e1ef6acabb_raw.jpg'},
#      'created_at': 'Sun, 20 Oct 2019 19:21:56 +0000',
#      'checkin_id': 819990171,
#      'beer': {'bid': 3440110,
#       'beer_name': 'Doktoberfest',
#       'beer_abv': 6.1,
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'Festbier'},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'user': {'uid': 1847754,
#       'user_name': 'Nobandsland1',
#       'first_name': 'Dirk',
#       'last_name': 'D',
#       'user_avatar': 'https://untappd.akamaized.net/profile/25a524f8bc4cf1a6b70877258bf9906f_100x100.jpg',
#       'is_private': 0},
#      'venue': {'venue_id': 8707470,
#       'venue_name': 'Two Docs Brewing Co.',
#       'venue_slug': 'two-docs-brewing-co',
#       'primary_category': 'Nightlife Spot',
#       'parent_category_id': '4d4b7105d754a06376d81259',
#       'categories': {'count': 1,
#        'items': [{'category_key': 'brewery',
#          'category_name': 'Brewery',
#          'category_id': '50327c8591d4c4b30a586d5d',
#          'is_primary': True}]},
#       'location': {'venue_address': '502 Texas Ave',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#       'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#        'foursquare_url': 'https://4sq.com/2IJTFbR'},
#       'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#        'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#        'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#       'is_verified': 1}}]},
#   'checkins': {'count': 15,
#    'items': [{'checkin_id': 823627778,
#      'created_at': 'Thu, 31 Oct 2019 01:19:13 +0000',
#      'checkin_comment': '',
#      'rating_score': 0,
#      'user': {'uid': 2328105,
#       'user_name': 'Sdugger1',
#       'first_name': 'Scott',
#       'last_name': 'D.',
#       'location': '',
#       'url': '',
#       'is_supporter': 0,
#       'bio': '',
#       'relationship': None,
#       'user_avatar': 'https://gravatar.com/avatar/03a310a2ae08be9acdec8c93722cec44?size=100&d=https%3A%2F%2Funtappd.akamaized.net%2Fsite%2Fassets%2Fimages%2Fdefault_avatar_v3_gravatar.jpg%3Fv%3D2',
#       'is_private': 0},
#      'beer': {'bid': 3104744,
#       'beer_name': 'Lubbock Light',
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_abv': 4,
#       'beer_ibu': 9,
#       'beer_slug': 'two-docs-brewing-co-lubbock-light',
#       'beer_description': 'An All-American Light beer. Think golf, tailgates, poolside or really anytime you are thirsty and need a beer... or 4.',
#       'beer_style': 'Lager - Helles',
#       'has_had': False,
#       'beer_active': 1},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'venue': {'venue_id': 9090786,
#       'venue_name': 'Growler USA - Lubbock',
#       'venue_slug': 'growler-usa-lubbock',
#       'primary_category_key': 'Food',
#       'primary_category': 'Food',
#       'parent_category_id': '4d4b7105d754a06374d81259',
#       'categories': {'count': 1,
#        'items': [{'category_key': 'restaurant',
#          'category_name': 'Restaurant',
#          'category_id': '4bf58dd8d48988d1c4941735',
#          'is_primary': True}]},
#       'location': {'venue_address': '6030 Marsha Sharp Fwy, Suite 200',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'venue_country': 'United States',
#        'lat': 33.5485,
#        'lng': -101.95},
#       'contact': {'twitter': '@GrowlerLubbock',
#        'venue_url': 'Growlerusa.com/Lubbock'},
#       'foursquare': {'foursquare_id': '5d10ed17de944500235ea31d',
#        'foursquare_url': 'https://4sq.com/2LcGU91'},
#       'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_9090786_674f03d3_bg_64.png',
#        'md': 'https://untappd.akamaized.net/venuelogos/venue_9090786_674f03d3_bg_88.png',
#        'lg': 'https://untappd.akamaized.net/venuelogos/venue_9090786_674f03d3_bg_176.png?v=1'},
#       'is_verified': True},
#      'comments': {'total_count': 0, 'count': 0, 'items': []},
#      'toasts': {'total_count': 1,
#       'count': 1,
#       'auth_toast': None,
#       'items': [{'uid': 6376655,
#         'user': {'uid': 6376655,
#          'user_name': 'TwoDocsBrewingCo',
#          'first_name': 'Two Docs Brewing Co.',
#          'last_name': '',
#          'bio': '',
#          'location': '',
#          'relationship': 'none',
#          'user_avatar': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#          'account_type': 'brewery',
#          'venue_details': [],
#          'brewery_details': {'brewery_id': 420745},
#          'user_link': 'https://untappd.com/brewery/420745'},
#         'like_id': 735888294,
#         'like_owner': False,
#         'created_at': 'Thu, 31 Oct 2019 15:51:57 +0000'}]},
#      'media': {'count': 0, 'items': []},
#      'source': {'app_name': 'Untappd for iPhone - (V2)',
#       'app_website': 'http://untpd.it/iphoneapp'},
#      'badges': {'count': 0, 'items': []}},
#     {'checkin_id': 823623699,
#      'created_at': 'Thu, 31 Oct 2019 01:08:11 +0000',
#      'checkin_comment': '',
#      'rating_score': 3.25,
#      'user': {'uid': 1520691,
#       'user_name': 'MotleyBrue67',
#       'first_name': 'Drew',
#       'last_name': 'C.',
#       'location': '',
#       'url': '',
#       'is_supporter': 0,
#       'bio': '',
#       'relationship': None,
# ...
#     {'total_user_count': 0,
#      'has_had': None,
#      'total_count': 82,
#      'beer': {'bid': 3063015,
#       'beer_name': 'Prairie Dawg Porter',
#       'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-3063015_38cdd_sm.jpeg',
#       'beer_style': 'Porter - American',
#       'beer_abv': 5.9,
#       'beer_ibu': 32,
#       'beer_slug': 'two-docs-brewing-co-prairie-dawg-porter',
#       'beer_description': 'Big notes of chocolate and coffee are balanced out with a late kick of hops. This is our salute to the original inhabitants of the South Plains. If you need something to snuggle up to when the temperature drops, this brew, much like Lubbock’s mascot, will have you feeling all warm and fuzzy.',
#       'is_in_production': 1,
#       'created_at': 'Sat, 02 Feb 2019 01:54:03 +0000',
#       'user_rating_score': 0,
#       'rating_score': 3.788,
#       'rating_count': 72,
#       'on_list': False,
#       'auth_rating': 0,
#       'wish_list': False},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'friends': {'items': [], 'count': 0}},
#     {'total_user_count': 0,
#      'has_had': None,
#      'total_count': 78,
#      'beer': {'bid': 3104757,
#       'beer_name': 'Easy Blonde',
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'Blonde Ale',
#       'beer_abv': 4,
#       'beer_ibu': 16,
#       'beer_slug': 'two-docs-brewing-co-easy-blonde',
#       'beer_description': 'Light, crisp and refreshing with a little kiss of Amarillo hops at the end. This blonde is hard to resist and keeps you coming back for more.',
#       'is_in_production': 1,
#       'created_at': 'Fri, 01 Mar 2019 20:52:50 +0000',
#       'user_rating_score': 0,
#       'rating_score': 3.664,
#       'rating_count': 67,
#       'on_list': False,
#       'auth_rating': 0,
#       'wish_list': False},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'friends': {'items': [], 'count': 0}},
#     {'total_user_count': 0,
#      'has_had': None,
#      'total_count': 71,
#      'beer': {'bid': 3104736,
#       'beer_name': 'Steampunk Ale',
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'California Common',
#       'beer_abv': 4.4,
#       'beer_ibu': 33,
#       'beer_slug': 'two-docs-brewing-co-steampunk-ale',
#       'beer_description': 'Smooth drinking amber colored ale brewed with lager yeast. Bay Area inspired, High Plains crafted.',
#       'is_in_production': 1,
#       'created_at': 'Fri, 01 Mar 2019 20:45:17 +0000',
#       'user_rating_score': 0,
#       'rating_score': 3.68,
#       'rating_count': 64,
#       'on_list': False,
#       'auth_rating': 0,
#       'wish_list': False},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'friends': {'items': [], 'count': 0}},
#     {'total_user_count': 0,
#      'has_had': None,
#      'total_count': 18,
#      'beer': {'bid': 3376550,
#       'beer_name': 'Watermelon Gose',
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'Shandy / Radler',
#       'beer_abv': 3.64,
#       'beer_ibu': 0,
#       'beer_slug': 'two-docs-brewing-co-watermelon-gose',
#       'beer_description': 'Needing a cool down? For a limited time, enjoy our newly crafted Watermelon Gose for a nice time on the patio. ',
#       'is_in_production': 1,
#       'created_at': 'Sat, 10 Aug 2019 15:47:59 +0000',
#       'user_rating_score': 0,
#       'rating_score': 3.8,
#       'rating_count': 15,
#       'on_list': False,
#       'auth_rating': 0,
#       'wish_list': False},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'friends': {'items': [], 'count': 0}},
#     {'total_user_count': 0,
#      'has_had': None,
#      'total_count': 10,
#      'beer': {'bid': 3466636,
#       'beer_name': 'Pickle Gose',
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'Sour - Other',
#       'beer_abv': 4.5,
#       'beer_ibu': 8,
#       'beer_slug': 'two-docs-brewing-co-pickle-gose',
#       'beer_description': '',
#       'is_in_production': 1,
#       'created_at': 'Sat, 05 Oct 2019 13:57:57 +0000',
#       'user_rating_score': 0,
#       'rating_score': 3.825,
#       'rating_count': 10,
#       'on_list': False,
#       'auth_rating': 0,
#       'wish_list': False},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'friends': {'items': [], 'count': 0}},
#     {'total_user_count': 0,
#      'has_had': None,
#      'total_count': 10,
#      'beer': {'bid': 3488043,
#       'beer_name': 'Brunch Bock',
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'Bock - Single / Traditional',
#       'beer_abv': 5.4,
#       'beer_ibu': 19,
#       'beer_slug': 'two-docs-brewing-co-brunch-bock',
#       'beer_description': '',
#       'is_in_production': 1,
#       'created_at': 'Fri, 18 Oct 2019 23:05:45 +0000',
#       'user_rating_score': 0,
#       'rating_score': 0,
#       'rating_count': 7,
#       'on_list': False,
#       'auth_rating': 0,
#       'wish_list': False},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'friends': {'items': [], 'count': 0}},
#     {'total_user_count': 0,
#      'has_had': None,
#      'total_count': 4,
#      'beer': {'bid': 3432355,
#       'beer_name': 'Ruby Red Grapefruit Shandy',
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'Shandy / Radler',
#       'beer_abv': 4,
#       'beer_ibu': 0,
#       'beer_slug': 'two-docs-brewing-co-ruby-red-grapefruit-shandy',
#       'beer_description': '',
#       'is_in_production': 1,
#       'created_at': 'Sat, 14 Sep 2019 13:52:35 +0000',
#       'user_rating_score': 0,
#       'rating_score': 0,
#       'rating_count': 4,
#       'on_list': False,
#       'auth_rating': 0,
#       'wish_list': False},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'friends': {'items': [], 'count': 0}},
#     {'total_user_count': 0,
#      'has_had': None,
#      'total_count': 3,
#      'beer': {'bid': 3412130,
#       'beer_name': 'Game Day IPA',
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'IPA - American',
#       'beer_abv': 0,
#       'beer_ibu': 0,
#       'beer_slug': 'two-docs-brewing-co-game-day-ipa',
#       'beer_description': '',
#       'is_in_production': 1,
#       'created_at': 'Sat, 31 Aug 2019 23:28:45 +0000',
#       'user_rating_score': 0,
#       'rating_score': 0,
#       'rating_count': 3,
#       'on_list': False,
#       'auth_rating': 0,
#       'wish_list': False},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'friends': {'items': [], 'count': 0}},
#     {'total_user_count': 0,
#      'has_had': None,
#      'total_count': 3,
#      'beer': {'bid': 3453729,
#       'beer_name': 'BlackBerry Gose',
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'Sour - Gose - Fruited',
#       'beer_abv': 4.5,
#       'beer_ibu': 8,
#       'beer_slug': 'two-docs-brewing-co-blackberry-gose',
#       'beer_description': '',
#       'is_in_production': 1,
#       'created_at': 'Fri, 27 Sep 2019 21:42:07 +0000',
#       'user_rating_score': 0,
#       'rating_score': 0,
#       'rating_count': 2,
#       'on_list': False,
#       'auth_rating': 0,
#       'wish_list': False},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'friends': {'items': [], 'count': 0}},
#     {'total_user_count': 0,
#      'has_had': None,
#      'total_count': 1,
#      'beer': {'bid': 3500094,
#       'beer_name': 'Prairie Dog Porter - Mexican Cocoa',
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'Porter - Other',
#       'beer_abv': 0,
#       'beer_ibu': 0,
#       'beer_slug': 'two-docs-brewing-co-prairie-dog-porter-mexican-cocoa',
#       'beer_description': 'Two Docs Prairie Dog Porter infused with Mexican Cocoa. Extremely limited release. Oct. 25, 2019',
#       'is_in_production': 1,
#       'created_at': 'Sat, 26 Oct 2019 04:12:03 +0000',
#       'user_rating_score': 0,
#       'rating_score': 0,
#       'rating_count': 1,
#       'on_list': False,
#       'auth_rating': 0,
#       'wish_list': False},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'friends': {'items': [], 'count': 0}}],
#    'collaborations': {'count': 0, 'items': []},
#    'sort_name': 'Most Popular',
#    'sort_key': 'most_popular'},
#   'locations': {'count': 1,
#    'items': [{'venue': {'venue_id': 8707470,
#       'venue_name': 'Two Docs Brewing Co.',
#       'venue_slug': 'two-docs-brewing-co',
#       'primary_category_key': 'Nightlife Spot',
#       'primary_category': 'Nightlife Spot',
#       'parent_category_id': '4d4b7105d754a06376d81259',
#       'categories': {'count': 1,
#        'items': [{'category_key': 'brewery',
#          'category_name': 'Brewery',
#          'category_id': '50327c8591d4c4b30a586d5d',
#          'is_primary': True}]},
#       'location': {'venue_address': '502 Texas Ave',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'venue_country': 'United States',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#       'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#        'foursquare_url': 'https://4sq.com/2IJTFbR'},
#       'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#        'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#        'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#       'is_verified': True}}]}}}
# Completed on  2019-11-09 17:50:29.236932

# %% [markdown]
# Flatten data

# %%
import pickle
import numpy as np
import pandas as pd
import math
from IPython.display import clear_output

# Load data
with open ("../data/all_breweries.pkl", "rb") as fp:
    all_breweries = pickle.load(fp)

for brewery in all_breweries:
    if "brewery_id" in brewery:
        brewery["brewery_name"] = brewery["brewery_info"]["brewery"]["brewery_name"]
        brewery["brewery_address"] = brewery["brewery_info"]["brewery"]["location"]["brewery_address"]
        brewery["brewery_city"] = brewery["brewery_info"]["brewery"]["location"]["brewery_city"]
        brewery["brewery_state"] = brewery["brewery_info"]["brewery"]["location"]["brewery_state"]
        brewery["brewery_lat"] = brewery["brewery_info"]["brewery"]["location"]["brewery_lat"]
        brewery["brewery_lng"] = brewery["brewery_info"]["brewery"]["location"]["brewery_lng"]
        brewery["beer_count"] = brewery["brewery_info"]["brewery"]["beer_count"]
        brewery["rating_count"] = brewery["brewery_info"]["brewery"]["rating"]["count"]
        brewery["rating_score"] = brewery["brewery_info"]["brewery"]["rating"]["rating_score"]
        brewery["checkins_total_count"] = brewery["brewery_info"]["brewery"]["stats"]["total_count"]
        brewery["checkins_unique_count"] = brewery["brewery_info"]["brewery"]["stats"]["unique_count"]
        brewery["checkins_monthly_count"] = brewery["brewery_info"]["brewery"]["stats"]["monthly_count"]
        brewery["checkins_weekly_count"] = brewery["brewery_info"]["brewery"]["stats"]["weekly_count"]
        brewery["age_on_service"] = brewery["brewery_info"]["brewery"]["stats"]["age_on_service"]
        brewery["brewery_in_production"] = brewery["brewery_info"]["brewery"]["brewery_in_production"]
        
        
pd.set_option('max_columns', 100)
display(pd.DataFrame(all_breweries).head())
pd.reset_option('max_columns')
                
with open("../data/all_breweries.pkl", "wb") as fp:
    pickle.dump(all_breweries, fp)
# Out:
#                 Name Street Address                    Road            City State Brewery License License Date        Status                                                                                                                                                                                                                                                                                                                                                                                                                                  untappd  brewery_id  \
# 0        111 Brewing            111         S FANNIN AVENUE         DENISON    TX         Brewery    4/10/2019  In the works  [{'brewery': {'brewery_id': 66888, 'beer_count': 65, 'brewery_name': 'Milepost 111 Brewing Company', 'brewery_slug': 'milepost-111-brewing-company', 'brewery_page_url': '/milepostbeer', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-Milepost111_66888_590e6.jpeg', 'country_name': 'United States', 'location': {'brewery_city': 'Cashmere', 'brewery_state': 'WA', 'lat': 47.5244, 'lng': -120.47}}}]         NaN
# 1  2 Docs Brewing Co            502            TEXAS AVENUE         LUBBOCK    TX         Brewery    10/5/2018          Open                         [{'brewery': {'brewery_id': 420745, 'beer_count': 22, 'brewery_name': 'Two Docs Brewing Co.', 'brewery_slug': 'two-docs-brewing-co', 'brewery_page_url': '/TwoDocsBrewingCo', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg', 'country_name': 'United States', 'location': {'brewery_city': 'Lubbock', 'brewery_state': 'TX', 'lat': 33.5909, 'lng': -101.846}}}]    420745.0
# 2  3 Nations Brewing           2405  SQUIRE PLACE SUITE 200  FARMERS BRANCH    TX         Brewery     5/6/2015          Open                         [{'brewery': {'brewery_id': 205645, 'beer_count': 43, 'brewery_name': '3 Nations Brewing', 'brewery_slug': '3-nations-brewing', 'brewery_page_url': '/3NationsBrewing', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-205645_ed87a.jpeg', 'country_name': 'United States', 'location': {'brewery_city': 'Farmers Branch', 'brewery_state': 'TX', 'lat': 32.931, 'lng': -96.8983}}}]    205645.0
# 3   4th Tap Brewing           10615        METRIC BOULEVARD          AUSTIN    TX         Brewery    4/13/2015          Open                                  [{'brewery': {'brewery_id': 229660, 'beer_count': 90, 'brewery_name': '4th Tap Brewing Co-Op', 'brewery_slug': '4th-tap-brewing-coop', 'brewery_page_url': '/4thTap', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-229660_351c0.jpeg', 'country_name': 'United States', 'location': {'brewery_city': 'Austin', 'brewery_state': 'TX', 'lat': 30.3852, 'lng': -97.7119}}}]    229660.0
# 4       512 Brewing             407       RADAM LANE 'F200'          AUSTIN    TX         Brewery    5/20/2008          Open                                        [{'brewery': {'brewery_id': 1, 'beer_count': 156, 'brewery_name': '(512) Brewing Company', 'brewery_slug': '512-brewing-company', 'brewery_page_url': '/512Brewing', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-1_8ccec.jpeg', 'country_name': 'United States', 'location': {'brewery_city': 'Austin', 'brewery_state': 'TX', 'lat': 30.2236, 'lng': -97.7697}}}]         1.0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               brewery_info  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      NaN
# 1  {'brewery': {'brewery_id': 420745, 'brewery_name': 'Two Docs Brewing Co.', 'brewery_slug': 'two-docs-brewing', 'brewery_page_url': '/TwoDocsBrewingCo', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg', 'brewery_label_hd': '', 'country_name': 'United States', 'brewery_in_production': 0, 'is_independent': 1, 'claimed_status': {'is_claimed': True, 'claimed_slug': 'TwoDocsBrewingCo', 'follow_status': False, 'follower_count': 72, 'uid': 6376655, 'mute_status': 'none'}, 'beer_count': 22, 'contact': {'twitter': '', 'facebook': 'https://www.facebook.com/twodocsbrewing', 'instagram': 'twodocsbrewing', 'url': 'https://twodocsbrewing.com/'}, 'brewery_type': 'Micro Brewery', 'brewery_type_id': 2, 'location': {'brewery_address': '502 Texas Ave', 'brewery_city': 'Lubbock', 'brewery_state': 'TX', 'brewery_lat': 33.5909, 'brewery_lng': -101.846}, 'rating': {'count': 1943, 'rating_score': 3.791}, 'brewery_description': 'We want to share our love of craft...
# 2  {'brewery': {'brewery_id': 205645, 'brewery_name': '3 Nations Brewing', 'brewery_slug': '3-nations-brewing', 'brewery_page_url': '/3NationsBrewing', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-205645_ed87a.jpeg', 'brewery_label_hd': '', 'country_name': 'United States', 'brewery_in_production': 0, 'is_independent': 1, 'claimed_status': {'is_claimed': True, 'claimed_slug': '3NationsBrewing', 'follow_status': False, 'follower_count': 1536, 'uid': 2671573, 'mute_status': 'none'}, 'beer_count': 44, 'contact': {'twitter': '3NationsBrewing', 'facebook': 'https://www.facebook.com/threenationsbrewing', 'instagram': '3nationsbrewing', 'url': 'https://3nationsbrewing.com/'}, 'brewery_type': 'Micro Brewery', 'brewery_type_id': 2, 'location': {'brewery_address': '2405 Squire Place, Suite 200', 'brewery_city': 'Farmers Branch', 'brewery_state': 'TX', 'brewery_lat': 32.931, 'brewery_lng': -96.8983}, 'rating': {'count': 67380, 'rating_score': 3.782}, 'brewery_descrip...
# 3  {'brewery': {'brewery_id': 229660, 'brewery_name': '4th Tap Brewing Co-Op', 'brewery_slug': '4th-tap-brewing-co-op', 'brewery_page_url': '/4thTap', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-229660_351c0.jpeg', 'brewery_label_hd': 'https://untappd.akamaized.net/site/brewery_logos_hd/brewery-229660_1463a_hd.jpeg', 'country_name': 'United States', 'brewery_in_production': 0, 'is_independent': 1, 'claimed_status': {'is_claimed': True, 'claimed_slug': '4thTap', 'follow_status': False, 'follower_count': 1279, 'uid': 3013876, 'mute_status': 'none'}, 'beer_count': 90, 'contact': {'twitter': '4thtap', 'facebook': 'http://facebook.com/4thtap', 'instagram': '4thtap', 'url': 'http://4thtap.coop/'}, 'brewery_type': 'Micro Brewery', 'brewery_type_id': 2, 'location': {'brewery_address': '10615 Metric Blvd', 'brewery_city': 'Austin', 'brewery_state': 'TX', 'brewery_lat': 30.3852, 'brewery_lng': -97.7119}, 'rating': {'count': 38805, 'rating_score': 3.65}, 'brewery_d...
# 4  {'brewery': {'brewery_id': 1, 'brewery_name': '(512) Brewing Company', 'brewery_slug': '512-brewing-company', 'brewery_page_url': '/512Brewing', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-1_8ccec.jpeg', 'brewery_label_hd': '', 'country_name': 'United States', 'brewery_in_production': 0, 'is_independent': 1, 'claimed_status': {'is_claimed': True, 'claimed_slug': '512Brewing', 'follow_status': False, 'follower_count': 9552, 'uid': 348761, 'mute_status': 'none'}, 'beer_count': 157, 'contact': {'twitter': '512brewing', 'facebook': 'https://www.facebook.com/512brewing', 'instagram': '512brewing', 'url': 'http://512brewing.com'}, 'brewery_type': 'Micro Brewery', 'brewery_type_id': 2, 'location': {'brewery_address': '407 Radam Ln', 'brewery_city': 'Austin', 'brewery_state': 'TX', 'brewery_lat': 30.2236, 'brewery_lng': -97.7697}, 'rating': {'count': 160944, 'rating_score': 3.814}, 'brewery_description': 'The original practice of consuming fresh draft beer at...
#
#             brewery_name               brewery_address    brewery_city brewery_state  brewery_lat  brewery_lng  beer_count  rating_count  rating_score  chekcins_total_count  chekcins_unique_count  chekcins_monthly_count  chekcins_weekly_count  age_on_service  brewery_in_production
# 0                    NaN                           NaN             NaN           NaN          NaN          NaN         NaN           NaN           NaN                   NaN                    NaN                     NaN                    NaN             NaN                    NaN
# 1   Two Docs Brewing Co.                 502 Texas Ave         Lubbock            TX      33.5909    -101.8460        22.0        1943.0         3.791                2400.0                  711.0                   153.0                    0.0      271.909155                    0.0
# 2      3 Nations Brewing  2405 Squire Place, Suite 200  Farmers Branch            TX      32.9310     -96.8983        44.0       67380.0         3.782               88009.0                30528.0                  1376.0                   44.0     1600.819954                    0.0
# 3  4th Tap Brewing Co-Op             10615 Metric Blvd          Austin            TX      30.3852     -97.7119        90.0       38805.0         3.650               49945.0                17321.0                   829.0                  102.0     1493.087407                    0.0
# 4  (512) Brewing Company                  407 Radam Ln          Austin            TX      30.2236     -97.7697       157.0      160944.0         3.814              246464.0                84027.0                  1254.0                   42.0     3308.740081                    0.0

# %% [markdown]
# Let's research missing!

# %%
import pandas as pd
import pickle

# Load data
with open ("../data/all_breweries.pkl", "rb") as fp:
    all_breweries = pickle.load(fp)

df = pd.DataFrame(all_breweries)

pd.set_option('display.max_colwidth', 1000)
pd.set_option('display.max_rows', 200)
idx_filter = ( pd.isnull(df.brewery_id) ) & ( df.Status == "Open" )
print("Total need to research", sum( idx_filter))
display(df.loc[idx_filter,["Name","License Date","Brewery License","Status","untappd"]])
# pd.reset_option('display.width')
pd.reset_option('display.max_rows')
# Out:
# Total need to research 49
#                                       Name License Date Brewery License Status  \
# 7                 Allen's Landing Brewing     1/16/2015         Brewery   Open
# 13                               BCS-Zoigl    12/1/2016         Brewery   Open
# 19                          Braman Brewery     5/4/2015         Brewery   Open
# 24                            City Orchard    6/18/2018         Brewery   Open
# 25                         Comfort Brewing    8/29/2016         Brewery   Open
# 30                          Deep Ellum FTW     9/5/2018         Brewery   Open
# 31                 Dej Buh Stesti Brewing      1/8/2016         Brewery   Open
# 39             Friends And Allies Brewing     5/26/2016         Brewery   Open
# 55   Lake Austin Ales (Operating in Celis)     5/4/2015         Brewery   Open
# 61                 Long Wood Spoon Brewing    6/23/2015         Brewery   Open
# 66                    Nine Band Brewing Co    1/26/2018         Brewery   Open
# 67                         NLand Surf Park     8/7/2017         Brewery   Open
# 72                     Oskar Blues Brewery    1/27/2016         Brewery   Open
# 77                       Railport Brewing     1/30/2018         Brewery   Open
# 81                      Rentschler Brewing     4/6/2015         Brewery   Open
# 89                       Symbolic Brewing    10/19/2018         Brewery   Open
# 95                           Toddy Brewery    9/15/2016         Brewery   Open
# 96       Treaty Oak Brewing And Distilling    3/22/2016         Brewery   Open
# 123                 B   J Pizza Restaurant    4/23/2007         Brewpub   Open
# 128                      Baileson Brewing      1/4/2017         Brewpub   Open
# 129                     Bakfish Brewing Co   12/21/2015         Brewpub   Open
# 143                         BJ's Brewhouse    1/29/2015         Brewpub   Open
# 158           Brick Oven Pizza Of Abilene     5/23/2005         Brewpub   Open
# 175                       Coalfox Brewing    12/22/2017         Brewpub   Open
# 184             Devil And The Deep Brewery   10/27/2017         Brewpub   Open
# 185                 Distant State Brewing     3/23/2015         Brewpub   Open
# 192                Eureka Heights Brewing      4/4/2016         Brewpub   Open
# 195                       Fire Ant Brewpub   10/24/2017         Brewpub   Open
# 210                             GL Brewing    6/25/2018         Brewpub   Open
# 218                  Hook   Ladder Brewpub    3/12/2018         Brewpub   Open
# 226                 Humperdink's Arlington   10/31/2006         Brewpub   Open
# 231       Intrinsic Smokehouse And Brewery    8/21/2015         Brewpub   Open
# 245                       Lt Mesquite Brew     3/1/2018         Brewpub   Open
# 249                       Malai Restaurant   11/24/2010         Brewpub   Open
# 270                  On Rotation Brewhouse    12/1/2014         Brewpub   Open
# 272                         Outfit Brewery    5/21/2018         Brewpub   Open
# 273                     Outlaw's Bar B Que     2/7/2019         Brewpub   Open
# 305                   Six Brothers Brewing    4/24/2019         Brewpub   Open
# 307                 Skull Mechanix Brewing    1/12/2017         Brewpub   Open
# 312     Southerleigh Fine Food And Brewery    11/3/2014         Brewpub   Open
# 322                      Symposium Brewpub    1/15/2019         Brewpub   Open
# 325                    Texas Beer Refinery     9/5/2014         Brewpub   Open
# 327        The Austin Beer Garden Brewing      4/4/2013         Brewpub   Open
# 328                      The Black Star-Op    11/9/2017         Brewpub   Open
# 335                  The Draught House Pub     4/6/1999         Brewpub   Open
# 336              The Faust Hotel   Brewing    1/14/2015         Brewpub   Open
# 337                     The Moon Tower Inn    8/19/2010         Brewpub   Open
# 339        The Shade Tree Saloon And Grill    7/26/2016         Brewpub   Open
# 340       The Triple J Chophouse   Brew Co     8/4/2006         Brewpub   Open
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      untappd
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [{'no_results': True}]
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [{'no_results': True}]
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [{'brewery': {'brewery_id': 48985, 'beer_count': 1, 'brewery_name': 'Bratman Brewery (Homebrew)', 'brewery_slug': 'bratman-brewery', 'brewery_page_url': '/w/bratman-brewery/48985', 'brewery_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-brewery-default.png', 'country_name': 'United States', 'location': {'brewery_city': '', 'brewery_state': '', 'lat': 0, 'lng': 0}}}]
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'brewery': {'brewery_id': 364659, 'beer_count': 1, 'brewery_name': 'Orchard City Brewing (Homebrew)', 'brewery_slug': 'orchard-city-brewing', 'brewery_page_url': '/w/orchard-city-brewing/364659', 'brewery_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-brewery-default.png', 'country_name': 'United States', 'location': {'brewery_city': '', 'brewery_state': '', 'lat': 0, 'lng': 0}}}]
# 25   [{'brewery': {'brewery_id': 209165, 'beer_count': 24, 'brewery_name': 'Cold Comfort Brewing (Homebrew)', 'brewery_slug': 'cold-comfort-brewing', 'brewery_page_url': '/ColdComfortBrewing', 'brewery_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-brewery-default.png', 'country_name': 'United States', 'location': {'brewery_city': '', 'brewery_state': '', 'lat': 0, 'lng': 0}}}, {'brewery': {'brewery_id': 124177, 'beer_count': 7, 'brewery_name': 'Comfort Brewing Co. (Homebrew)', 'brewery_slug': 'comfort-brewing-co', 'brewery_page_url': '/w/comfort-brewing-co/124177', 'brewery_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-brewery-default.png', 'country_name': 'United States', 'location': {'brewery_city': '', 'brewery_state': '', 'lat': 0, 'lng': 0}}}, {'brewery': {'brewery_id': 321023, 'beer_count': 3, 'brewery_name': 'Cold Comfort Brewing (Homebrew)', 'brewery_slug': 'cold-comfort-brewing', 'brewery_page_url': '/w/cold-comfort-brewing/321023',...
# 30                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [{'no_results': True}]
# 31                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [{'no_results': True}]
# 39                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [{'no_results': True}]
# 55                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [{'no_results': True}]
# 61                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [{'no_results': True}]
# 66   [{'brewery': {'brewery_id': 435311, 'beer_count': 1, 'brewery_name': 'Dragan Brewing & Wine Company', 'brewery_slug': 'dragan-brewing-and-wine-company', 'brewery_page_url': '/w/dragan-brewing-wine-company/435311', 'brewery_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-brewery-default.png', 'country_name': 'Canada', 'location': {'brewery_city': '', 'brewery_state': '', 'lat': 0, 'lng': 0}}}, {'brewery': {'brewery_id': 393699, 'beer_count': 7, 'brewery_name': 'Tumbleweed Brewing & Wine Co', 'brewery_slug': 'tumbleweed-brewing-and-wine-co', 'brewery_page_url': '/w/tumbleweed-brewing-wine-co/393699', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-393699_40ea6.jpeg', 'country_name': 'United States', 'location': {'brewery_city': 'Yuma', 'brewery_state': 'CO', 'lat': 40.1245, 'lng': -102.724}}}, {'brewery': {'brewery_id': 151825, 'beer_count': 0, 'brewery_name': 'Cottonwood Wine and Brewing', 'brewery_slug': 'cottonwood-wine-and-brewing',...
# 67                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [{'no_results': True}]
# 72                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [{'brewery': {'brewery_id': 956, 'beer_count': 822, 'brewery_name': 'Oskar Blues Brewery', 'brewery_slug': 'oskar-blues-brewery', 'brewery_page_url': '/oskarblues', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-956_a912c.jpeg', 'country_name': 'United States', 'location': {'brewery_city': 'Longmont', 'brewery_state': 'CO', 'lat': 40.1391, 'lng': -105.122}}}]
# 77                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [{'brewery': {'brewery_id': 34762, 'beer_count': 128, 'brewery_name': 'Fairport Brewing Company', 'brewery_slug': 'fairport-brewing-company', 'brewery_page_url': '/FairportBrewingCompany', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-34762_b02b8.jpeg', 'country_name': 'United States', 'location': {'brewery_city': 'Fairport', 'brewery_state': 'NY', 'lat': 43.0954, 'lng': -77.4311}}}]
# 81                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [{'no_results': True}]
# 89                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [{'brewery': {'brewery_id': 67788, 'beer_count': 7, 'brewery_name': 'Systolic Brewing (Homebrew)', 'brewery_slug': 'systolic-brewing', 'brewery_page_url': '/w/systolic-brewing/67788', 'brewery_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-brewery-default.png', 'country_name': 'United States', 'location': {'brewery_city': '', 'brewery_state': '', 'lat': 0, 'lng': 0}}}]
# 95   [{'brewery': {'brewery_id': 254664, 'beer_count': 2, 'brewery_name': 'Todd Merritt Brewery', 'brewery_slug': 'todd-merritt-brewery', 'brewery_page_url': '/w/todd-merritt-brewery/254664', 'brewery_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-brewery-default.png', 'country_name': 'United States', 'location': {'brewery_city': '', 'brewery_state': '', 'lat': 0, 'lng': 0}}}, {'brewery': {'brewery_id': 177898, 'beer_count': 11, 'brewery_name': 'Todd Rush Home Brewery (Homebrew)', 'brewery_slug': 'todd-rush-home-brewery', 'brewery_page_url': '/w/todd-rush-home-brewery/177898', 'brewery_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-brewery-default.png', 'country_name': 'United States', 'location': {'brewery_city': '', 'brewery_state': '', 'lat': 0, 'lng': 0}}}, {'brewery': {'brewery_id': 181755, 'beer_count': 1, 'brewery_name': 'Bill And Todd's Excellent Brewery (Homebrew)', 'brewery_slug': 'bill-and-todds-excellent-brewery', 'brewery_page_url...
# 96                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [{'no_results': True}]
# 123                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'no_results': True}]
# 128                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [{'brewery': {'brewery_id': 129492, 'beer_count': 9, 'brewery_name': 'Baildon Brewing Company', 'brewery_slug': 'baildon-brewing-company', 'brewery_page_url': '/BaildonBreweryCompany', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-129492_0ffab.jpeg', 'country_name': 'England', 'location': {'brewery_city': 'Baildon', 'brewery_state': 'West Yorkshire', 'lat': 53.8448, 'lng': -1.75627}}}]
# 129                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'brewery': {'brewery_id': 358788, 'beer_count': 17, 'brewery_name': 'BadFish Brewing Company', 'brewery_slug': 'badfish-brewing-company', 'brewery_page_url': '/BadFishBrewery', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-358788_8d116.jpeg', 'country_name': 'Switzerland', 'location': {'brewery_city': 'Saint-Prex', 'brewery_state': 'Vaud', 'lat': 46.4943, 'lng': 6.4693}}}]
# 143  [{'brewery': {'brewery_id': 7132, 'beer_count': 337, 'brewery_name': 'BJ's Restaurant & Brewhouse', 'brewery_slug': 'bjs-restaurant-and-brewhouse', 'brewery_page_url': '/BJs_Brewhouse', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-7132_141a1.jpeg', 'country_name': 'United States', 'location': {'brewery_city': 'Huntington Beach', 'brewery_state': 'CA', 'lat': 33.7348, 'lng': -117.995}}}, {'brewery': {'brewery_id': 446527, 'beer_count': 3, 'brewery_name': 'Bj's Restaurant & Brewhouse - Boulder', 'brewery_slug': 'bjs-restaurant-and-brewhouse-boulder', 'brewery_page_url': '/w/bj-s-restaurant-brewhouse-boulder/446527', 'brewery_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-brewery-default.png', 'country_name': 'United States', 'location': {'brewery_city': '', 'brewery_state': '', 'lat': 0, 'lng': 0}}}, {'brewery': {'brewery_id': 290627, 'beer_count': 16, 'brewery_name': 'BJs Brewhouse (Homebrew)', 'brewery_slug': 'bjs-brewhouse', 'bre...
# 158                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'no_results': True}]
# 175                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'no_results': True}]
# 184                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'no_results': True}]
# 185                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'no_results': True}]
# 192                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'no_results': True}]
# 195                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'no_results': True}]
# 210  [{'brewery': {'brewery_id': 352522, 'beer_count': 16, 'brewery_name': 'GL Heritage Brewing Co.', 'brewery_slug': 'gl-heritage-brewing-co', 'brewery_page_url': '/GLHeritageBrewingCo', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-352522_f7b94.jpeg', 'country_name': 'Canada', 'location': {'brewery_city': 'Amherstburg', 'brewery_state': 'ON', 'lat': 42.0608, 'lng': -83.0053}}}, {'brewery': {'brewery_id': 426147, 'beer_count': 1, 'brewery_name': 'GL Brewing', 'brewery_slug': 'gl-brewing', 'brewery_page_url': '/w/gl-brewing/426147', 'brewery_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-brewery-default.png', 'country_name': 'United States', 'location': {'brewery_city': '', 'brewery_state': '', 'lat': 0, 'lng': 0}}}, {'brewery': {'brewery_id': 289939, 'beer_count': 12, 'brewery_name': 'Jetta GL Brewing Co. (Homebrew)', 'brewery_slug': 'jetta-gl-brewing-co', 'brewery_page_url': '/w/jetta-gl-brewing-co/289939', 'brewery_label': 'https://u...
# 218                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'no_results': True}]
# 226                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'no_results': True}]
# 231                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'no_results': True}]
# 245                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'no_results': True}]
# 249                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'no_results': True}]
# 270                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'no_results': True}]
# 272                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'no_results': True}]
# 273                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'no_results': True}]
# 305                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'no_results': True}]
# 307                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'no_results': True}]
# 312                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'no_results': True}]
# 322                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [{'brewery': {'brewery_id': 441673, 'beer_count': 3, 'brewery_name': 'Symposium Brewpub', 'brewery_slug': 'symposium-brewpub', 'brewery_page_url': '/Symposium_Brewpub', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-441673_31b6b.jpeg', 'country_name': 'United States', 'location': {'brewery_city': '', 'brewery_state': '', 'lat': 0, 'lng': 0}}}]
# 325                                                                                                                                                                                                              [{'brewery': {'brewery_id': 117329, 'beer_count': 205, 'brewery_name': 'Texas Beer Refinery', 'brewery_slug': 'texas-beer-refinery', 'brewery_page_url': '/TexasBeerRefinery', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-117329_60cc9.jpeg', 'country_name': 'United States', 'location': {'brewery_city': 'Dickinson', 'brewery_state': 'Tx', 'lat': 29.476, 'lng': -95.0463}}}, {'brewery': {'brewery_id': 433305, 'beer_count': 1, 'brewery_name': 'Texas Beer Refinery', 'brewery_slug': 'texas-beer-refinery', 'brewery_page_url': '/w/texas-beer-refinery/433305', 'brewery_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-brewery-default.png', 'country_name': 'United States', 'location': {'brewery_city': '', 'brewery_state': '', 'lat': 0, 'lng': 0}}}]
# 327                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'no_results': True}]
# 328                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'no_results': True}]
# 335                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'no_results': True}]
# 336                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'no_results': True}]
# 337                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'no_results': True}]
# 339                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'no_results': True}]
# 340                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [{'brewery': {'brewery_id': 407283, 'beer_count': 2, 'brewery_name': 'The Triple J Chophouse & Brew Co.', 'brewery_slug': 'the-triple-j-chophouse-and-brew-co', 'brewery_page_url': '/w/the-triple-j-chophouse-brew-co/407283', 'brewery_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-brewery-default.png', 'country_name': 'United States', 'location': {'brewery_city': '', 'brewery_state': '', 'lat': 0, 'lng': 0}}}]

# %% [markdown]
# Removed names to help with search and start over

# %%
# Load data
with open ("../data/all_breweries.pkl", "rb") as fp:
    all_breweries = pickle.load(fp)
  

names_to_be_removed = [
    "Inc"
#     "Arlington",
#     "/ Austin Java",
#     "Northwest Highway",
#     "Co-Op",
#     " Co",
#     "Llc"
]
for brewery in all_breweries:
#     any(x in str for x in a)

    if any(x in brewery["Name"] for x in names_to_be_removed):
#         
        for w in names_to_be_removed:
            brewery["Name"] = brewery["Name"].replace(w,"")
        
        del brewery["untappd"]
        print(brewery["Name"])
        

    
# with open("../data/all_breweries.pkl", "wb") as fp:
#     pickle.dump(all_breweries, fp)
# Out:
# Spoetzl Brewery
# Brick Oven Pizza Of Abilene
# Fredericksburg Brewing
# Padre Island Brewing
# San Gabriel River Brewery
# Walking Stick Brewing

# %% [markdown]
# Check for Duplicates and do something with them

# %%
import pickle

with open ("../data/all_breweries.pkl", "rb") as fp:
    all_breweries = pickle.load(fp)
    
#remove duplicates
brewery_count = pd.DataFrame(all_breweries).groupby(["Name","brewery_city"])["Status"].count()
dups = brewery_count.loc[ brewery_count > 1].reset_index()
dups = dups["Name"].to_list()
print("Duplicates to be removed", dups)
all_breweries = [ brewery for brewery in all_breweries if brewery["Name"] not in dups ]

with open("../data/all_breweries.pkl", "wb") as fp:
    pickle.dump(all_breweries, fp)
# Out:
# Duplicates to be removed ['Flix Brewhouse', 'Freetail Brewing Co', 'Hops And Grain', 'Malai Kitchen', 'Pinthouse Pizza']

# %% [markdown]
# Get the Zip Code

# %%
import pickle
from uszipcode import SearchEngine

with open ("../data/all_breweries.pkl", "rb") as fp:
    all_breweries = pickle.load(fp)

for brewery in all_breweries:
    if "brewery_id" in brewery and abs(brewery["brewery_lat"]) > 0 and abs(brewery["brewery_lng"]) > 0:
        search = SearchEngine(simple_zipcode=False)
        result = search.by_coordinates(brewery["brewery_lat"],brewery["brewery_lng"], radius=30, returns=6)
        first_zip = result[0].to_dict()
        brewery["brewery_zipcode"] = first_zip["zipcode"]
        neighboring_zips = [zip.to_dict()["zipcode"] for zip in result[1:3]]
        brewery["neighboring_zips"] = neighboring_zips

print( all_breweries[1] )

with open("../data/all_breweries.pkl", "wb") as fp:
    pickle.dump(all_breweries, fp)
# Out:
# {'Name': '2 Docs Brewing Co', 'Street Address': 502, 'Road': 'TEXAS AVENUE', 'City': 'LUBBOCK', 'State': 'TX', 'Brewery License': 'Brewery', 'License Date': '10/5/2018', 'Status': 'Open', 'untappd': [{'brewery': {'brewery_id': 420745, 'beer_count': 22, 'brewery_name': 'Two Docs Brewing Co.', 'brewery_slug': 'two-docs-brewing-co', 'brewery_page_url': '/TwoDocsBrewingCo', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg', 'country_name': 'United States', 'location': {'brewery_city': 'Lubbock', 'brewery_state': 'TX', 'lat': 33.5909, 'lng': -101.846}}}], 'brewery_id': 420745, 'brewery_info': {'brewery': {'brewery_id': 420745, 'brewery_name': 'Two Docs Brewing Co.', 'brewery_slug': 'two-docs-brewing', 'brewery_page_url': '/TwoDocsBrewingCo', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg', 'brewery_label_hd': '', 'country_name': 'United States', 'brewery_in_production': 0, 'is_independent': 1, 'claimed_status': {'is_claimed': True, 'claimed_slug': 'TwoDocsBrewingCo', 'follow_status': False, 'follower_count': 72, 'uid': 6376655, 'mute_status': 'none'}, 'beer_count': 22, 'contact': {'twitter': '', 'facebook': 'https://www.facebook.com/twodocsbrewing', 'instagram': 'twodocsbrewing', 'url': 'https://twodocsbrewing.com/'}, 'brewery_type': 'Micro Brewery', 'brewery_type_id': 2, 'location': {'brewery_address': '502 Texas Ave', 'brewery_city': 'Lubbock', 'brewery_state': 'TX', 'brewery_lat': 33.5909, 'brewery_lng': -101.846}, 'rating': {'count': 1943, 'rating_score': 3.791}, 'brewery_description': 'We want to share our love of craft beer with West Texas. When you come into our taproom an expert staff will welcome you to a place where you can explore beer, expand your tastes, and have a great time.', 'stats': {'total_count': 2400, 'unique_count': 711, 'monthly_count': 153, 'weekly_count': 0, 'user_count': 0, 'age_on_service': 271.9091550925926}, 'owners': {'count': 0, 'items': []}, 'media': {'count': 15, 'items': [{'photo_id': 261142284, 'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_29/233f0ee846113f965095404c85eb37a2_200x200.jpg', 'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_29/233f0ee846113f965095404c85eb37a2_640x640.jpg', 'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_29/233f0ee846113f965095404c85eb37a2_1280x1280.jpg', 'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_29/233f0ee846113f965095404c85eb37a2_raw.jpg'}, 'created_at': 'Tue, 29 Oct 2019 00:03:24 +0000', 'checkin_id': 823141672, 'beer': {'bid': 3408493, 'beer_name': 'Hayes-E Baby IPA', 'beer_abv': 7.1, 'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png', 'beer_style': 'IPA - New England'}, 'brewery': {'brewery_id': 420745, 'brewery_name': 'Two Docs Brewing Co.', 'brewery_slug': 'two-docs-brewing', 'brewery_page_url': '/TwoDocsBrewingCo', 'brewery_type': 'Micro Brewery', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg', 'country_name': 'United States', 'contact': {'twitter': '', 'facebook': 'https://www.facebook.com/twodocsbrewing', 'instagram': 'twodocsbrewing', 'url': 'https://twodocsbrewing.com/'}, 'location': {'brewery_city': 'Lubbock', 'brewery_state': 'TX', 'lat': 33.5909, 'lng': -101.846}, 'brewery_active': 1}, 'user': {'uid': 1129994, 'user_name': 'Mikegib', 'first_name': 'Michael', 'last_name': 'G', 'user_avatar': 'https://untappd.akamaized.net/profile/8e268bea2010265abea610af88cbdbe7_100x100.jpg', 'is_private': 0}, 'venue': {'venue_id': 9090786, 'venue_name': 'Growler USA - Lubbock', 'venue_slug': 'growler-usa-lubbock', 'primary_category': 'Food', 'parent_category_id': '4d4b7105d754a06374d81259', 'categories': {'count': 1, 'items': [{'category_key': 'restaurant', 'category_name': 'Restaurant', 'category_id': '4bf58dd8d48988d1c4941735', 'is_primary': True}]}, 'location': {'venue_address': '6030 Marsha Sharp Fwy, Suite 200', 'venue ...

# %%
columns = [
    "brewery_name",
    "Brewery License",
    "License Date",
    "Status",
    "brewery_in_production",
    "brewery_id",
    "brewery_address",
    "brewery_city",
    "brewery_state",
    "brewery_lat",
    "brewery_lng",
    "beer_count",
    "rating_count",
    "rating_score",
    "age_on_service",
    "brewery_zipcode",
    "neighboring_zips",
    "checkins_total_count",
    "checkins_unique_count",
    "checkins_monthly_count",
    "checkins_weekly_count"
]

breweries = pd.DataFrame(all_breweries)

# %%
# Out:
# {'Name': '2 Docs Brewing Co', 'Street Address': 502, 'Road': 'TEXAS AVENUE', 'City': 'LUBBOCK', 'State': 'TX', 'Brewery License': 'Brewery', 'License Date': '10/5/2018', 'Status': 'Open', 'untappd': [{'brewery': {'brewery_id': 420745, 'beer_count': 22, 'brewery_name': 'Two Docs Brewing Co.', 'brewery_slug': 'two-docs-brewing-co', 'brewery_page_url': '/TwoDocsBrewingCo', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg', 'country_name': 'United States', 'location': {'brewery_city': 'Lubbock', 'brewery_state': 'TX', 'lat': 33.5909, 'lng': -101.846}}}], 'brewery_id': 420745, 'brewery_info': {'brewery': {'brewery_id': 420745, 'brewery_name': 'Two Docs Brewing Co.', 'brewery_slug': 'two-docs-brewing', 'brewery_page_url': '/TwoDocsBrewingCo', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg', 'brewery_label_hd': '', 'country_name': 'United States', 'brewery_in_production': 0, 'is_independent': 1, 'claimed_status': {'is_claimed': True, 'claimed_slug': 'TwoDocsBrewingCo', 'follow_status': False, 'follower_count': 72, 'uid': 6376655, 'mute_status': 'none'}, 'beer_count': 22, 'contact': {'twitter': '', 'facebook': 'https://www.facebook.com/twodocsbrewing', 'instagram': 'twodocsbrewing', 'url': 'https://twodocsbrewing.com/'}, 'brewery_type': 'Micro Brewery', 'brewery_type_id': 2, 'location': {'brewery_address': '502 Texas Ave', 'brewery_city': 'Lubbock', 'brewery_state': 'TX', 'brewery_lat': 33.5909, 'brewery_lng': -101.846}, 'rating': {'count': 1943, 'rating_score': 3.791}, 'brewery_description': 'We want to share our love of craft beer with West Texas. When you come into our taproom an expert staff will welcome you to a place where you can explore beer, expand your tastes, and have a great time.', 'stats': {'total_count': 2400, 'unique_count': 711, 'monthly_count': 153, 'weekly_count': 0, 'user_count': 0, 'age_on_service': 271.9091550925926}, 'owners': {'count': 0, 'items': []}, 'media': {'count': 15, 'items': [{'photo_id': 261142284, 'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_29/233f0ee846113f965095404c85eb37a2_200x200.jpg', 'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_29/233f0ee846113f965095404c85eb37a2_640x640.jpg', 'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_29/233f0ee846113f965095404c85eb37a2_1280x1280.jpg', 'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_29/233f0ee846113f965095404c85eb37a2_raw.jpg'}, 'created_at': 'Tue, 29 Oct 2019 00:03:24 +0000', 'checkin_id': 823141672, 'beer': {'bid': 3408493, 'beer_name': 'Hayes-E Baby IPA', 'beer_abv': 7.1, 'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png', 'beer_style': 'IPA - New England'}, 'brewery': {'brewery_id': 420745, 'brewery_name': 'Two Docs Brewing Co.', 'brewery_slug': 'two-docs-brewing', 'brewery_page_url': '/TwoDocsBrewingCo', 'brewery_type': 'Micro Brewery', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg', 'country_name': 'United States', 'contact': {'twitter': '', 'facebook': 'https://www.facebook.com/twodocsbrewing', 'instagram': 'twodocsbrewing', 'url': 'https://twodocsbrewing.com/'}, 'location': {'brewery_city': 'Lubbock', 'brewery_state': 'TX', 'lat': 33.5909, 'lng': -101.846}, 'brewery_active': 1}, 'user': {'uid': 1129994, 'user_name': 'Mikegib', 'first_name': 'Michael', 'last_name': 'G', 'user_avatar': 'https://untappd.akamaized.net/profile/8e268bea2010265abea610af88cbdbe7_100x100.jpg', 'is_private': 0}, 'venue': {'venue_id': 9090786, 'venue_name': 'Growler USA - Lubbock', 'venue_slug': 'growler-usa-lubbock', 'primary_category': 'Food', 'parent_category_id': '4d4b7105d754a06374d81259', 'categories': {'count': 1, 'items': [{'category_key': 'restaurant', 'category_name': 'Restaurant', 'category_id': '4bf58dd8d48988d1c4941735', 'is_primary': True}]}, 'location': {'venue_address': '6030 Marsha Sharp Fwy, Suite 200', 'venue ...
