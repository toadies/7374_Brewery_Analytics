# %%
from dotenv import load_dotenv
import urllib.parse as urlparse
import requests
import json
import os
from datetime import datetime

class Untappd:

    def __init__(self, clientId = "", clientSecret = ""):
        load_dotenv(dotenv_path="../.env")
        self._clientId = os.getenv("CLIENT_ID_ALT")
        self._clientSecret = os.getenv("CLIENT_SECRET_ALT")
        self._baseUrl = "https://api.untappd.com/v4/"


    def keys(self):
        return {
            "client_id": self._clientId,
            "client_secret": self._clientSecret
        }

    def findBrewery(self, brewery="", writeFile=False):
        methodUrl = self._baseUrl + "search/brewery"
        params = {
            "q": brewery
        }
        requestUrl = methodUrl + "?" + urlparse.urlencode({**params, **self.keys()})
        response = requests.get(requestUrl)
        
        headers = response.headers
        counter = int(headers["X-Ratelimit-Remaining"])
        breweries = [] 
        
        if response.status_code == 200:
            content = response.json()
            
            
            if content["response"]["found"] > 0:
                breweries = content["response"]["brewery"]["items"]
        
        return breweries, counter, response
    
    def breweryInfo(self, breweryId="", writeFile=False):
        methodUrl = self._baseUrl + "brewery/info/"
        requestUrl = methodUrl + str(breweryId) + "?" + urlparse.urlencode(self.keys())
        response = requests.get(requestUrl)
        
        headers = response.headers
        counter = int(headers["X-Ratelimit-Remaining"])
        
        if response.status_code == 200:
            content = response.json()

        return content["response"], counter, response

# %% [markdown]
# ### Create a brewery dataset

# %%
import numpy as np
import pandas as pd
import pickle

try:
    with open ("../data/all_breweries.pkl", "rb") as fp:
        all_breweries = pickle.load(fp)
except:
    print( "No file existed, creating one!" )
    breweries = pd.read_csv("../data/Texas Breweries.csv")
    brewpubs = pd.read_csv("../data/Texas Brewpubs.csv")
    brewery_list = list(breweries.T.to_dict().values())
    all_breweries = brewery_list + list( brewpubs.T.to_dict().values() )

    
    
    with open('../data/all_breweries.pkl', 'wb') as fp:
        pickle.dump(all_breweries, fp)
        
display( all_breweries[0:2] )
# Out:
# [{'Name': '111 Brewing',
#   'Street Address': 111,
#   'Road': 'S FANNIN AVENUE',
#   'City': 'DENISON',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '4/10/2019',
#   'Status': 'In the works'},
#  {'Name': '2 Docs Brewing Co',
#   'Street Address': 502,
#   'Road': 'TEXAS AVENUE',
#   'City': 'LUBBOCK',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '10/5/2018',
#   'Status': 'Open'}]

# %% [markdown]
# Due to untappd's 100 requests an hour, i'll need to run this over a couple of hours.  Thus saving results for future reference.

# %%
import pickle
import numpy as np
import pandas as pd
from IPython.display import clear_output

# Load data
with open ("../data/all_breweries.pkl", "rb") as fp:
    all_breweries = pickle.load(fp)

untappd = Untappd()
 
for brewery in all_breweries:
    if "untappd" not in brewery:
        brewery_result, counter, response = untappd.findBrewery(brewery["Name"])
        
        if len( brewery_result ) > 0:
            brewery["untappd"] = brewery_result
        else:
            brewery["untappd"] = [{"no_results":True}]

        clear_output(wait=True)
        display(counter)
        if counter == 0:
            break
        
#         break
#Save results
with open("../data/all_breweries.pkl", "wb") as fp:
    pickle.dump(all_breweries, fp)

print( "sample output" )
print( all_breweries[0] )
# Out:
# 82
# sample output
# {'Name': '111 Brewing', 'Street Address': 111, 'Road': 'S FANNIN AVENUE', 'City': 'DENISON', 'State': 'TX', 'Brewery License': 'Brewery', 'License Date': '4/10/2019', 'Status': 'In the works', 'untappd': [{'brewery': {'brewery_id': 66888, 'beer_count': 65, 'brewery_name': 'Milepost 111 Brewing Company', 'brewery_slug': 'milepost-111-brewing-company', 'brewery_page_url': '/milepostbeer', 'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-Milepost111_66888_590e6.jpeg', 'country_name': 'United States', 'location': {'brewery_city': 'Cashmere', 'brewery_state': 'WA', 'lat': 47.5244, 'lng': -120.47}}}]}

# %%
import pickle
import pandas as pd
from IPython.display import clear_output

# Load data
with open ("../data/all_breweries.pkl", "rb") as fp:
    all_breweries = pickle.load(fp)
 
# Normalized the results
brewery_parsed = []
i = 0
for brewery in all_breweries:
    clear_output(wait=True)
    display(i)
    i+=1
    for entries in brewery["untappd"]:
        if "no_results" not in entries:
            brewery_parsed.append({
                "Name":brewery["Name"],
                "Street Address":brewery["Street Address"],
                "Road":brewery["Road"],
                "City":brewery["City"],
                "State":brewery["State"],
                "Brewery License":brewery["Brewery License"],
                "License Date":brewery["License Date"],
                "Status":brewery["Status"],
                "search_count":len(brewery["untappd"]),
                "brewery_id":entries["brewery"]["brewery_id"],
                "brewery_name":entries["brewery"]["brewery_name"],
                "beer_count":entries["brewery"]["beer_count"],
                "brewery_city":entries["brewery"]["location"]["brewery_city"],
                "brewery_state":entries["brewery"]["location"]["brewery_state"],
                "brewery_lat":entries["brewery"]["location"]["lat"],
                "brewery_lng":entries["brewery"]["location"]["lng"]
            })
        

# Remove results where not in texas
brewery_parsed = [ brewery for brewery in brewery_parsed if "TX" in brewery["brewery_state"]]
# Must have 10 beers!
brewery_parsed = [ brewery for brewery in brewery_parsed if brewery["beer_count"] > 9 ]

#remove duplicates
brewery_count = pd.DataFrame(brewery_parsed).groupby(["Name"])["Status"].count()
dups = brewery_count.loc[ brewery_count > 1].reset_index()
dups = dups["Name"].to_list()
print("Duplicates to be removed", dups)
brewery_parsed = [ brewery for brewery in brewery_parsed if brewery["Name"] not in dups ]

#Add Brewery ID back in to primary data
for brewery in all_breweries:
    for b in brewery_parsed:
        if brewery["Name"] in b["Name"]:
            brewery["brewery_id"] = b["brewery_id"]
            
#Save results
with open("../data/all_breweries.pkl", "wb") as fp:
    pickle.dump(all_breweries, fp)
# #Convert to Pandas and save it
# # brewery_parsed = pd.DataFrame( brewery_parsed )
# # brewery_parsed.to_csv("../data/brewery_search.csv")
pd.options.display.max_rows = 999
display( pd.DataFrame( brewery_parsed ) )
pd.options.display.max_rows = 15
# Out:
# 365
# Duplicates to be removed ['Flix Brewhouse', 'Freetail Brewing Co.', 'Hops And Grain', 'Malai Kitchen', 'Pinthouse Pizza']
#                                       Name Street Address  \
# 0                        2 Docs Brewing Co            502
# 1                        3 Nations Brewing           2405
# 2                      512 Brewing Company            407
# 3                       8th Wonder Brewery           2202
# 4                               Alamo Beer            415
# 5                      Armadillo Ale Works            221
# 6                   Athens Brewing Company            101
# 7                         Austin Beerworks           3009
# 8                       Backstory  Brewery            211
# 9                Bear King Brewing Company            207
# 10          Bitter Sisters Brewing Company          15103
# 11                 Bluebonnet Beer Company           1700
# 12                     Brotherwell Brewing            400
# 13                      Bull Creek Brewing           7100
# 14                           Celis Brewery          10001
# 15                  Community Beer Company           1530
# 16             Cypress Creek Southern Ales            200
# 17              Deep Ellum Brewing Company           2823
# 18                       Dirty Job Brewing            117
# 19               Eccentric Brewing Company           1402
# 20                  Edgewise Eight Brewing           6488
# 21                    Four Bullets Brewery            640
# 22                Four Corners Brewing Co.           1311
# 23               Franconia Brewing Company            495
# 24                      Fulbrook Ale Works           1125
# 25              Galveston Bay Beer Company          12900
# 26                  Goliad Brewing Company            252
# 27                       Highwheel Brewing           1902
# 28                          Holler Brewing           2206
# 29           Hop And Sting Brewing Company            906
# 30                     Hopfusion Ale Works            200
# 31                Independence Brewing Co.           3913
# 32                       Ivanhoe Ale Works            220
# 33                Lakewood Brewing Company           2302
# 34                    Legal Draft Beer Co.            500
# 35                Live Oak Brewing Company           1615
# 36                       Lone Pint Brewery            507
# 37                 Lorelei Brewing Company            520
# 38            Martin House Brewing Company            220
# 39            New Republic Brewing Company          11405
# 40                   Oak Highlands Brewery          10484
# 41                      Old Town Brewhouse            146
# 42                             Orf Brewing           4700
# 43                    Pegasus City Brewery           2222
# 44               Peticolas Brewing Company           2026
# 45                     Rahr & Sons Brewing            701
# 46       Ranger Creek Brewing & Distilling           4834
# 47                Real Ale Brewing Company            231
# 48                        Revolver Brewing           5650
# 49            Saint Arnold Brewing Company           2000
# 50           Southern Star Brewing Company           3525
# 51                       Texas Ale Project           1001
# 52          Thirsty Planet Brewing Company           8201
# 53               True Vine Brewing Company           2453
# 54                           Tupps Brewery            721
# 55               Twisted X Brewing Company          23455
# 56                   Uncle Billy's Brewery           1530
# 57                 Under The Radar Brewery           1506
# 58               Wild Acre Brewing Company           1734
# 59                  Wild Bunch Brewing Co.           1764
# 60               Woodcreek Brewing Company           1400
# 61                  Zilker Brewing Company           1701
# 62                          12 Fox Beer Co           4700
# 63                      4J Brewing Company           1348
# 64                5 Stones Artisan Brewery          11335
# 65                         5X5 Brewing Co.            801
# 66                             903 Brewers           1720
# 67                          Acopon Brewing            211
# 68                      Adelbert's Brewery           2314
# 69                                Altstadt           6120
# 70                Angelina Brewing Company            118
# 71                           Anvil Brewing            115
# 72                                Aquabrew            150
# 73                          Astral Brewing           4816
# 74                               Aurelia's           1620
# 75                    B-52 Brewing Company          12470
# 76                       Baa Baa Brewhouse            539
# 77                Back Pew Brewing Company          26452
# 78                     Bandera Ale Project           3540
# 79                    Bankhead Brewing Co.           3840
# 80                         Bar D Brewhouse            213
# 81                       Bare Arms Brewing           2515
# 82                  Barrow Brewing Company            108
# 83               Basement Brewers Of Texas            521
# 84             Batch Craft Beer & Kolaches           3220
# 85                      Battlehops Brewing           6801
# 86             Bearded Fox Brewing Company          11729
# 87                      Beerfoot Beach Bar           2816
# 88                       Big River Brewery            505
# 89                   Big Texan Steak Ranch           7701
# 90         Blackwater Draw Brewing Company            701
# 91                    Blazing Tree Brewery          11426
# 92                        Blue Owl Brewing           2400
# 93               Blue Star Brewing Company           1414
# 94           Bold Republic Brewing Company            206
# 95                       Braindead Brewing           2625
# 96                                   Brash            510
# 97                          Brewer's Table           4715
# 98                          Brews Brothers           2404
# 99                                Brewsome           1303
# 100              Brick Vault Brewery & BBQ            100
# 101                       Brutal Beerworks           8447
# 102                             BS Brewing           1408
# 103                   By The Horns Brewing            109
# 104               Caracara Brewing Company            100
# 105                    Celestial Beerworks           2530
# 106              Cellarman's Pub & Brewery           2130
# 107               Central District Brewing            417
# 108               Cibolo Creek Brewing Co.            448
# 109                 Circle Brewing Company           2340
# 110                      City Acre Brewing           3418
# 111                       Compadre Brewing          16920
# 112                     Copperhead Brewery            822
# 113            Cranky Britches Brewing Co.           1675
# 114                        Cyclers Brewing          17105
# 115                     Dead Beach Brewery            406
# 116          Denton County Brewing Company            200
# 117                       Division Brewing            506
# 118            Double Horn Brewing Company            208
# 119                     El Paso Brewing Co            810
# 120                 Eola School Restaurant          12119
# 121                        ETX Brewing Co.            221
# 122           Family Business Beer Company          19510
# 123                   Fetching Lab Brewery           1578
# 124                           Fort Brewery           1001
# 125                     Fortress Beerworks           2606
# 126                       Fredonia Brewery            138
# 127            Funky Picnic Brewery & Cafe            401
# 128               Galveston Island Brewing           8423
# 129                   Gordon Street Tavern            114
# 130           Granger City Brewing Company            109
# 131          Great Heights Brewing Company            938
# 132              Guadalupe Brewing Company           1586
# 133                        Hi Sign Brewing           1201
# 134               Hitmaker Brewing Company          11160
# 135                       Hold Out Brewing           1208
# 136             Horny Toad Brewing Company            313
# 137                   Huff Brewing Company           9805
# 138               Infamous Brewing Company           4602
# 139              Ingenious Brewing Company           1986
# 140                    Jester King Brewery          13005
# 141              Kinematic Brewing Company          50140
# 142                  Klaus Brewing Company          10142
# 143                      Kuenstler Brewing            302
# 144             Last Stand Brewing Company          12345
# 145                Lazarus Brewing Company           1902
# 146                     Lazy Beach Brewing           7522
# 147                             Loco Meaux            302
# 148                 Mad Pecker Brewing Co.           6025
# 149                        Megaton Brewery            808
# 150                      Middleton Brewing            101
# 151                 Neches Brewing Company           1108
# 152          New Braunfels Brewing Company            180
# 153                   New Main Brewing Co.           3533
# 154                    No Label Brewing Co           5351
# 155              Noble Rey Brewing Company           2636
# 156                            Nocona Beer            915
# 157                      Nomadic Beerworks           3804
# 158                     North By Northwest          10010
# 159                 Nueces Brewing Company            401
# 160            Oasis Texas Brewing Company           6550
# 161                           Oddwood Ales           3108
# 162                            Ode Brewing           3233
# 163                   Oil Horse Brewing Co            101
# 164         Oneil And Sons Brewing Company            206
# 165                 Panther Island Brewing            501
# 166                Pappy Slokum Brewing Co            409
# 167          Parker County Brewing Company            225
# 168                Pecan Point Brewing Co.            213
# 169                   Pecan Street Brewing            106
# 170                      Platypus  Brewing           1902
# 171                  Pondaseta Brewing Co.           7500
# 172                    Rabbit Hole Brewing            608
# 173               Railroad Seafood Station           1214
# 174                  Rebel Toad Brewing Co            425
# 175                 Red Bone Magic Brewing           1304
# 176  Red Horn Coffee House And Brewing Co.          13010
# 177                        Roadmap Brewing            723
# 178                       Root Cellar Cafe            215
# 179                  Rough Diamond Brewery            101
# 180                     Roughhouse Brewing            612
# 181                    Saloon Door Brewing            105
# 182             Save The World Brewing Co.           1510
# 183                         Sean Patrick's            202
# 184                 Seguin Brewing Company            111
# 185                Shannon Brewing Company            818
# 186                  Six Car Pub & Brewery            625
# 187                          Small Brewpub            333
# 188                          Soco Taphouse            113
# 189           Southern Yankee Beer Company            930
# 190                St Elmo Brewing Company            440
# 191           Steam Theory Brewing Company            340
# 192        Struggle Street Brewing Company           2140
# 193            Suds Monkey Brewing Company           1032
# 194                    Sun Brewing Company            101
# 195                     Texas Beer Company           1331
# 196          Texas Leaguer Brewing Company          13503
# 197                         The Blue Onion            423
# 198                            The Brewery            429
# 199                        The Brewery Lbk           1204
# 200                         The Brewtorium           6015
# 201         The Collective Brewing Project            112
# 202              The Dodging Duck Brewhaus            402
# 203              The Phoenix On Westheimer           1915
# 204                          TKO Libations           2520
# 205                     Turning Point Beer           1307
# 206               Tusculum Brewing Company            236
# 207                             Twin Peaks           1500
# 208                   Twisted Acre Brewery          16103
# 209              Two Wheel Brewing Company            535
# 210     Uncle Buck's Brewery & Steak House           2501
# 211                             Union Bear           5880
# 212              Unlawful Assembly Brewing           7800
# 213             Vallensons Brewing Company           4081
# 214                          Vista Brewing          13551
# 215                       Waco Ale Company            806
# 216               Walking Beam Brewing Co.           1019
# 217        Weathered Souls Brewing Company            606
# 218          White Rock Alehouse & Brewery           7331
# 219                     Whitestone Brewery            601
# 220     Whole Foods Market Brewing Company           1700
# 221          Wichita Falls Brewing Company            701
# 222                   Wicked Boxer Brewing          16326
# 223              Wimberley Brewing Company           9595
# 224                     Zero One Ale House             20
#
#                               Road                  City State  \
# 0                     TEXAS AVENUE               LUBBOCK    TX
# 1           SQUIRE PLACE SUITE 200        FARMERS BRANCH    TX
# 2                RADAM LANE 'F200'                AUSTIN    TX
# 3                    DALLAS STREET               HOUSTON    TX
# 4                    BURNET STREET           SAN ANTONIO    TX
# 5                    S BELL AVENUE                DENTON    TX
# 6                   E TYLER STREET                ATHENS    TX
# 7     INDUSTRIAL TERRACE SUITE 150                AUSTIN    TX
# 8                  MAGNOLIA STREET       SULPHUR SPRINGS    TX
# 9                            AVE G          MARBLE FALLS    TX
# 10              SURVEYOR BOULEVARD               ADDISON    TX
# 11           BRYANT DRIVE UNIT 107            ROUND ROCK    TX
# 12                 E BRIDGE STREET                  WACO    TX
# 13              FM 3405 BUILDING 1          LIBERTY HILL    TX
# 14                METRIC BOULEVARD                AUSTIN    TX
# 15     INSPIRATION DRIVE SUITE 200                DALLAS    TX
# 16               E CARNEGIE STREET             WINNSBORO    TX
# 17              SAINT LOUIS STREET                DALLAS    TX
# 18                   N MAIN STREET             MANSFIELD    TX
# 19                COTTON FLAT ROAD               MIDLAND    TX
# 20                          FM 920           WEATHERFORD    TX
# 21             N INTERURBAN STREET            RICHARDSON    TX
# 22                         S ERVAY                DALLAS    TX
# 23                MCKINNEY PARKWAY              MCKINNEY    TX
# 24                          FM 359              RICHMOND    TX
# 25                         FM 3436            TEXAS CITY    TX
# 26                    METTING ROAD                GOLIAD    TX
# 27                 S FLORES STREET           SAN ANTONIO    TX
# 28          EDWARDS STREET SUITE A               HOUSTON    TX
# 29                     JEAN STREET             GRAPEVINE    TX
# 30               E BROADWAY AVENUE            FORT WORTH    TX
# 31                    TODD LN #607                AUSTIN    TX
# 32                   W MAIN STREET               DENISON    TX
# 33                 EXECUTIVE DRIVE               GARLAND    TX
# 34               E DIVISION STREET             ARLINGTON    TX
# 35                    CROZIER LANE                AUSTIN    TX
# 36                 COMMERCE STREET              MAGNOLIA    TX
# 37        NAS DRIVE BUILDING BL002        CORPUS CHRISTI    TX
# 38     S SYLVANIA AVENUE SUITE 209            FORT WORTH    TX
# 39           N DOWLING ROAD UNIT C       COLLEGE STATION    TX
# 40                  BROCKWOOD ROAD                DALLAS    TX
# 41                  WHATLEY AVENUE            LEWISVILLE    TX
# 42            BURLESON ROAD UNIT F                AUSTIN    TX
# 43                  VANTAGE STREET                DALLAS    TX
# 44               FARRINGTON STREET                DALLAS    TX
# 45                GALVESTON AVENUE            FORT WORTH    TX
# 46       WHIRLWIND DRIVE SUITE 102           SAN ANTONIO    TX
# 47                  SAN SABA COURT                BLANCO    TX
# 48                    MATLOCK ROAD              GRANBURY    TX
# 49     LYONS AVENUE INCLUDING 2104               HOUSTON    TX
# 50                N FRAZIER STREET                CONROE    TX
# 51                    N RIVERFRONT                DALLAS    TX
# 52               S CONGRESS AVENUE                AUSTIN    TX
# 53                   EARL CAMPBELL                 TYLER    TX
# 54                        ANDERSON              MCKINNEY    TX
# 55                     RR 150 WEST      DRIPPING SPRINGS    TX
# 56             BARTON SPRINGS ROAD                AUSTIN    TX
# 57                 TRUXILLO STREET               HOUSTON    TX
# 58      E EL PASO STREET SUITE 190            FORT WORTH    TX
# 59               TAYLORSVILLE ROAD              RED ROCK    TX
# 60                  IH 30E SUITE A              ROCKWALL    TX
# 61                    E 6TH STREET                AUSTIN    TX
# 62                 W FITZHUGH ROAD      DRIPPING SPRINGS    TX
# 63                  CEDARPOST LANE               HOUSTON    TX
# 64                         FM 1863         NEW BRAUNFELS    TX
# 65          N BRYAN ROAD SUITE 174               MISSION    TX
# 66                    S ELM STREET               SHERMAN    TX
# 67                   MERCER STREET      DRIPPING SPRINGS    TX
# 68         RUTLAND DRIVE SUITE 100                AUSTIN    TX
# 69                    HWY 290 EAST        FREDERICKSBURG    TX
# 70                    S 1ST STREET                LUFKIN    TX
# 71                        COMPRESS             PITTSBURG    TX
# 72                     S LBJ DRIVE            SAN MARCOS    TX
# 73        N SHEPHERD DRIVE SUITE A               HOUSTON    TX
# 74                    N RESLER 'C'               EL PASO    TX
# 75                     MILROY LANE                CONROE    TX
# 76                  FM 359 SUITE 7            BROOKSHIRE    TX
# 77                    SORTERS ROAD                PORTER    TX
# 78                HWY 16S SUITE 2A               BANDERA    TX
# 79                     MAIN STREET               ROWLETT    TX
# 80                   N HIGH STREET              SAN SABA    TX
# 81                  LASALLE AVENUE                  WACO    TX
# 82                    ROYAL STREET                SALADO    TX
# 83                     CLAY STREET             KERRVILLE    TX
# 84                      MANOR ROAD                AUSTIN    TX
# 85                   HWY BOULEVARD                  KATY    TX
# 86     SPRING CYPRESS ROAD SUITE R               TOMBALL    TX
# 87                       AVE R 1/2             GALVESTON    TX
# 88                        W NOLANA                 PHARR    TX
# 89                      IH 40 EAST              AMARILLO    TX
# 90                   N MAIN STREET                 BRYAN    TX
# 91                 ROJAS SPACE A13               EL PASO    TX
# 92           E CESAR CHAVEZ STREET                AUSTIN    TX
# 93               S ALAMO SUITE 105           SAN ANTONIO    TX
# 94               N PENELOPE STREET                BELTON    TX
# 95                     MAIN STREET                DALLAS    TX
# 96                  W CROSSTIMBERS               HOUSTON    TX
# 97                    E 5TH STREET                AUSTIN    TX
# 98                          STRAND             GALVESTON    TX
# 99                   N 10TH STREET               MCALLEN    TX
# 100                   N 1ST STREET              MARATHON    TX
# 101                   BOULEVARD 26  NORTH RICHLAND HILLS    TX
# 102               OLD LEHMANN ROAD                SEGUIN    TX
# 103                  S MAIN STREET             MANSFIELD    TX
# 104        E MARKET STREET SUITE A              LOCKHART    TX
# 105                  BUTLER STREET                DALLAS    TX
# 106                 TEXOMA PARKWAY               SHERMAN    TX
# 107               RED RIVER STREET                AUSTIN    TX
# 108                         S MAIN                BOERNE    TX
# 109          W BRAKER LANE SUITE B                AUSTIN    TX
# 110                 TOPPING STREET               HOUSTON    TX
# 111    JOE BARBEE DRIVE BUILDING 1          PFLUGERVILLE    TX
# 112               N FRAZIER STREET                CONROE    TX
# 113       DICKINSON AVENUE SUITE C             DICKINSON    TX
# 114                    OSBORN ROAD            MONTGOMERY    TX
# 115                        DURANGO               EL PASO    TX
# 116              E MCKINNEY STREET                DENTON    TX
# 117                  E MAIN STREET             ARLINGTON    TX
# 118                          AVE H          MARBLE FALLS    TX
# 119              TEXAS AVE SUITE B               EL PASO    TX
# 120                         FM 381                  EOLA    TX
# 121              S BROADWAY AVENUE                 TYLER    TX
# 122             HAMILTON POOL ROAD      DRIPPING SPRINGS    TX
# 123                CRD 423 SUITE B                 ALGOA    TX
# 124              W MAGNOLIA AVENUE            FORT WORTH    TX
# 125            SPRING CYPRESS ROAD                SPRING    TX
# 126                 N MOUND STREET           NACOGDOCHES    TX
# 127         BRYAN AVENUE SUITE 117            FORT WORTH    TX
# 128                   STEWART ROAD             GALVESTON    TX
# 129                N GORDON STREET                 ALVIN    TX
# 130               W DAVALIA STREET               GRANGER    TX
# 131                WAKEFIELD DRIVE               HOUSTON    TX
# 132                        WALD RD         NEW BRAUNFELS    TX
# 133         BASTROP HWY BUILDING A                AUSTIN    TX
# 134      CIRCLE DRIVE UNIT A AND B                AUSTIN    TX
# 135                   W 4TH STREET                AUSTIN    TX
# 136                  EDWARD STREET                ROWENA    TX
# 137                     KOEHN ROAD             BELLVILLE    TX
# 138    WELETKA DRIVE SUITE 100 200                AUSTIN    TX
# 139           SOUTH HOUSTON AVENUE                HUMBLE    TX
# 140           FITZHUGH ROAD UNIT B                AUSTIN    TX
# 141              HWY 10W SUITE 100               COMFORT    TX
# 142          JONES ROAD BUILDING A               HOUSTON    TX
# 143                  E LA CHAPELLE           SAN ANTONIO    TX
# 144  PAUL VALLEY ROAD UNIT I AND J                AUSTIN    TX
# 145    E 6TH STREET INCLUDING 1900                AUSTIN    TX
# 146                    BICHON #100        CORPUS CHRISTI    TX
# 147        E MAIN STREET SUITE 200               KILGORE    TX
# 148               TEZEL ROAD '122'           SAN ANTONIO    TX
# 149            RUSSELL PALMER ROAD              KINGWOOD    TX
# 150                   OAKWOOD LOOP            SAN MARCOS    TX
# 151             PORT NECHES AVENUE           PORT NECHES    TX
# 152        W MILL STREET SUITE 100         NEW BRAUNFELS    TX
# 153                MARATHON STREET               PANTEGO    TX
# 154                 1ST STREET 'B'                  KATY    TX
# 155              FARRINGTON STREET                DALLAS    TX
# 156                    HWY 82 EAST                NOCONA    TX
# 157         WOODBURY DRIVE SUITE A                AUSTIN    TX
# 158         N CAPITAL OF TEXAS HWY                AUSTIN    TX
# 159                 S WATER STREET        CORPUS CHRISTI    TX
# 160      COMANCHE TRAIL SUITE B301                AUSTIN    TX
# 161                     MANOR ROAD                AUSTIN    TX
# 162        N MESA STREET SUITE 301               EL PASO    TX
# 163                 W TYLER STREET              LONGVIEW    TX
# 164                     S COMMERCE           PORT LAVACA    TX
# 165                  N MAIN STREET            FORT WORTH    TX
# 166          S TREADAWAY BOULEVARD               ABILENE    TX
# 167                SHOPS BOULEVARD           WILLOW PARK    TX
# 168                    MAIN STREET             TEXARKANA    TX
# 169                  E PECAN DRIVE          JOHNSON CITY    TX
# 170      WASHINGTON AVENUE SUITE E               HOUSTON    TX
# 171                 SW 45TH AVENUE              AMARILLO    TX
# 172                  TOPEKA AVENUE                JUSTIN    TX
# 173             N CHAPARRAL STREET        CORPUS CHRISTI    TX
# 174                 WILLIAM STREET        CORPUS CHRISTI    TX
# 175                TEXAS BOULEVARD             TEXARKANA    TX
# 176        W PARMER LANE SUITE 800            CEDAR PARK    TX
# 177   N ALAMO STREET SUITES 102-04           SAN ANTONIO    TX
# 178                          N LBJ            SAN MARCOS    TX
# 179                KENDALIA CIRCLE         SPRING BRANCH    TX
# 180                   OAKWOOD LOOP            SAN MARCOS    TX
# 181        MAGELLAN CIRCLE SUITE A               WEBSTER    TX
# 182               RESOURCE PARKWAY          MARBLE FALLS    TX
# 183        E SAN ANTONIO SUITE 119            SAN MARCOS    TX
# 184              W GONZALES STREET                SEGUIN    TX
# 185                  N MAIN STREET                KELLER    TX
# 186                  S POLK STREET              AMARILLO    TX
# 187          W JEFFERSON BOULEVARD                DALLAS    TX
# 188        E CONCHO AVENUE SUITE L            SAN ANGELO    TX
# 189                FM 1960 SUITE G               HOUSTON    TX
# 190     E SAINT ELMO ROAD SUITE G2                AUSTIN    TX
# 191  SINGLETON BOULEVARD SUITE 100                DALLAS    TX
# 192                  CALDER AVENUE              BEAUMONT    TX
# 193              CANYON BEND DRIVE      DRIPPING SPRINGS    TX
# 194                  LA UNION ROAD             CANUTILLO    TX
# 195                   W 2ND STREET                TAYLOR    TX
# 196            PIKE ROAD SUITE 100         MISSOURI CITY    TX
# 197      S INTERNATIONAL BOULEVARD               WESLACO    TX
# 198               N ALISTER STREET          PORT ARANSAS    TX
# 199                       BROADWAY               LUBBOCK    TX
# 200         DILLARD CIRCLE SUITE A                AUSTIN    TX
# 201                ST LOUIS AVENUE            FORT WORTH    TX
# 202                     RIVER ROAD                BOERNE    TX
# 203                WESTHEIMER ROAD               HOUSTON    TX
# 204    KING ARTHUR BOULEVARD '109'            LEWISVILLE    TX
# 205                    BROWN TRAIL               BEDFORD    TX
# 206                  S MAIN STREET                BOERNE    TX
# 207                   MARKET PLACE                IRVING    TX
# 208             GRANT ROAD SPACE J               CYPRESS    TX
# 209                   LOOP 4 SOUTH                  BUDA    TX
# 210       BASS PRO DRIVE SUITE 100             GRAPEVINE    TX
# 211              HWY 121 SUITE 101                 PLANO    TX
# 212                WINDROSE AVENUE                 PLANO    TX
# 213                RICE DRIER ROAD              PEARLAND    TX
# 214                    FM 150 WEST             DRIFTWOOD    TX
# 215                  AUSTIN AVENUE                  WACO    TX
# 216                 HALSELL STREET            BRIDGEPORT    TX
# 217  EMBASSY OAKS SUITES 350 & 500           SAN ANTONIO    TX
# 218        GASTON AVENUE SUITE 100                DALLAS    TX
# 219         E WHITESTONE BOULEVARD            CEDAR PARK    TX
# 220             POST OAK BOULEVARD               HOUSTON    TX
# 221                 INDIANA AVENUE         WICHITA FALLS    TX
# 222            MUESCHKE SUITE E-10               CYPRESS    TX
# 223                  RR 12 SUITE 9             WIMBERLEY    TX
# 224            W BEAUREGARD AVENUE            SAN ANGELO    TX
#
#     Brewery License License Date        Status  search_count  brewery_id  \
# 0           Brewery    10/5/2018          Open             1      420745
# 1           Brewery     5/6/2015          Open             1      205645
# 2           Brewery    5/20/2008          Open             1           1
# 3           Brewery   12/29/2011          Open             1       45113
# 4           Brewery    9/29/2014          Open             1       43137
# 5           Brewery    2/19/2015          Open             1        9316
# 6           Brewery    4/18/2016          Open             1      267312
# 7           Brewery   12/30/2010          Open             1       11819
# 8           Brewery   10/31/2017          Open             1      393158
# 9           Brewery   11/28/2018          Open             1      421863
# 10          Brewery    8/22/2014          Open             1       72194
# 11          Brewery     4/1/2014          Open             1      168065
# 12          Brewery    11/9/2017          Open             2      385504
# 13          Brewery    3/12/2013          Open             1      208827
# 14          Brewery    5/15/2017          Open             1      305923
# 15          Brewery     2/1/2013          Open             2       48372
# 16          Brewery    8/18/2017          Open             1      340519
# 17          Brewery    3/17/2017          Open             1       11028
# 18          Brewery     5/4/2017          Open             1      226688
# 19          Brewery     5/4/2018          Open             1      399986
# 20          Brewery   10/17/2018          Open             1      358992
# 21          Brewery    10/7/2014          Open             1       48543
# 22          Brewery    5/15/2017          Open             1       29815
# 23          Brewery    1/23/2008          Open             1        7329
# 24          Brewery   11/17/2017          Open             1      375720
# 25          Brewery    8/12/2014          Open             1      173145
# 26          Brewery   12/10/2013          Open             1      113303
# 27          Brewery    9/24/2015          Open             2      292601
# 28          Brewery     9/8/2015          Open             3      270322
# 29          Brewery   10/24/2017          Open             1      330503
# 30          Brewery    1/29/2016          Open             1      197427
# 31          Brewery    9/22/2004          Open             1        2252
# 32          Brewery     1/2/2015          Open             1      204652
# 33          Brewery     5/1/2012          Open             1       11862
# 34          Brewery     4/1/2016          Open             1      235234
# 35          Brewery   10/20/2015          Open             1         797
# 36          Brewery    9/10/2012          Open             1       47425
# 37          Brewery   11/26/2018          Open             1      249178
# 38          Brewery    11/8/2012          Open             1       27621
# 39          Brewery    3/16/2011          Open             1        8767
# 40          Brewery    5/18/2015          Open             1       65272
# 41          Brewery    11/4/2013          Open             1       71438
# 42          Brewery     1/6/2016          Open             1       16504
# 43          Brewery    1/24/2017          Open             1      336618
# 44          Brewery    8/25/2011          Open             1       13688
# 45          Brewery    7/20/2004          Open             1        1038
# 46          Brewery    8/13/2010          Open             1        2922
# 47          Brewery    4/13/1999          Open             1        1044
# 48          Brewery   12/13/2017          Open             1       30341
# 49          Brewery    4/22/1994          Open             1        2940
# 50          Brewery    1/29/2009          Open             1        1172
# 51          Brewery    3/28/2014          Open             1      134551
# 52          Brewery    1/29/2010          Open             1        3587
# 53          Brewery    4/16/2018          Open             1       98683
# 54          Brewery    2/13/2015          Open             1      196598
# 55          Brewery     2/2/2011          Open             1       11299
# 56          Brewery    5/26/2017          Open             1        3118
# 57          Brewery    11/6/2015          Open             1      272370
# 58          Brewery   10/22/2015          Open             1      254782
# 59          Brewery    4/17/2013          Open             1       75934
# 60          Brewery    3/23/2015          Open             1      217818
# 61          Brewery    1/22/2015          Open             1      194786
# 62          Brewpub    9/27/2018          Open             1      431694
# 63          Brewpub   11/16/2015          Open             1      386621
# 64          Brewpub   11/13/2017          Open             1       61531
# 65          Brewpub    9/12/2017          Open             1      329524
# 66          Brewpub     2/3/2017          Open             1       45007
# 67          Brewpub     4/7/2017          Open             1      353307
# 68          Brewpub     3/8/2016          Open             1       20007
# 69          Brewpub    5/12/2016          Open             9      331732
# 70          Brewpub    4/29/2019          Open             1      432645
# 71          Brewpub    6/23/2017          Open             3      350129
# 72          Brewpub   11/17/2016          Open             1      286708
# 73          Brewpub    10/2/2018          Open             2      423344
# 74          Brewpub    11/3/2017          Open             2      429904
# 75          Brewpub    3/13/2014          Open             1       60207
# 76          Brewpub     7/7/2015          Open             1      269031
# 77          Brewpub    2/13/2018          Open             1      209430
# 78          Brewpub    7/11/2017          Open             1      368670
# 79          Brewpub    2/11/2016          Open             1      293554
# 80          Brewpub    9/16/2011          Open             1       79142
# 81          Brewpub    3/13/2015          Open             1      207020
# 82          Brewpub     4/2/2015          Open             1      260725
# 83          Brewpub    8/17/2017          Open             1      372643
# 84          Brewpub    11/8/2016          Open             1      388953
# 85          Brewpub     3/1/2018          Open             1      433670
# 86          Brewpub    8/22/2018          Open             1      181217
# 87          Brewpub     8/9/2005          Open             1       46947
# 88          Brewpub    4/10/2017          Open             2      335433
# 89          Brewpub     7/9/1997          Open             1       13187
# 90          Brewpub    8/19/2015          Open             1       67349
# 91          Brewpub    7/12/2017          Open             1      352567
# 92          Brewpub    5/29/2014          Open             1      165600
# 93          Brewpub    5/13/1996          Open             1        3062
# 94          Brewpub   10/27/2017          Open             1       32500
# 95          Brewpub    2/11/2015          Open             1      185850
# 96          Brewpub    2/24/2014          Open             5       34146
# 97          Brewpub     9/6/2017          Open             1      354788
# 98          Brewpub    5/16/2013          Open            25       52797
# 99          Brewpub   11/19/2018          Open             3      424047
# 100         Brewpub     6/4/2018          Open             1      386390
# 101         Brewpub    2/28/2019          Open             1      178427
# 102         Brewpub     2/6/2015          Open            25       68349
# 103         Brewpub   10/31/2017          Open             2      420484
# 104         Brewpub    7/26/2017          Open             1      381243
# 105         Brewpub     7/6/2018          Open             1      360425
# 106         Brewpub    4/25/2017          Open             1      381643
# 107         Brewpub    11/9/2018          Open             1      148155
# 108         Brewpub    9/14/2015          Open             2      145843
# 109         Brewpub    4/24/2018          Open             5        7620
# 110         Brewpub     3/1/2013          Open             1       17811
# 111         Brewpub    11/9/2018          Open             1      429867
# 112         Brewpub    7/12/2018          Open             4      162786
# 113         Brewpub    1/11/2018          Open             1       74833
# 114         Brewpub    7/30/2018          Open             1       42771
# 115         Brewpub    9/11/2014          Open             1      234073
# 116         Brewpub    4/21/2016          Open             1      178455
# 117         Brewpub    8/10/2015          Open             7      198462
# 118         Brewpub    4/13/2011          Open             1       13415
# 119         Brewpub    5/16/2016          Open             1      298229
# 120         Brewpub     8/9/2013          Open             1       10231
# 121         Brewpub    9/24/2018          Open             1      288657
# 122         Brewpub   10/15/2018          Open             1      378401
# 123         Brewpub    12/2/2016          Open             1      204685
# 124         Brewpub    7/23/2018          Open            25       58169
# 125         Brewpub   12/17/2018          Open             1      425065
# 126         Brewpub     2/4/2016          Open             1      328418
# 127         Brewpub     1/2/2019          Open             1      386590
# 128         Brewpub     3/7/2014          Open             1      104005
# 129         Brewpub   10/17/2013          Open             1      204792
# 130         Brewpub     6/5/2015          Open             1      350290
# 131         Brewpub    12/6/2016          Open             1      232167
# 132         Brewpub    1/11/2017          Open             1       24397
# 133         Brewpub    11/2/2017          Open             1      324542
# 134         Brewpub    10/2/2017          Open             1      392114
# 135         Brewpub   12/12/2018  In the works             1      405455
# 136         Brewpub     6/2/2014          Open             1       56319
# 137         Brewpub    5/12/2015          Open             2       53963
# 138         Brewpub     2/1/2017          Open             1       38839
# 139         Brewpub    7/24/2017          Open             1      325323
# 140         Brewpub    8/15/2013          Open             1        5291
# 141         Brewpub     9/8/2014          Open             1      220760
# 142         Brewpub    6/19/2018          Open             1      407109
# 143         Brewpub    10/7/2016          Open             1      101164
# 144         Brewpub    7/30/2014          Open             1      171164
# 145         Brewpub     6/9/2016          Open             1      315033
# 146         Brewpub     3/1/2016          Open             1      134532
# 147         Brewpub    6/22/2018  In the works             1      430173
# 148         Brewpub    6/18/2015          Open             1       23011
# 149         Brewpub   10/10/2017          Open             1      420164
# 150         Brewpub    7/15/2011          Open             6       15206
# 151         Brewpub     6/9/2016          Open             1      293693
# 152         Brewpub   10/23/2013          Open             2       27535
# 153         Brewpub   11/28/2017          Open             1      287138
# 154         Brewpub   10/17/2017          Open             1        7188
# 155         Brewpub    6/12/2015          Open             1       45011
# 156         Brewpub    1/17/2019          Open             1      382898
# 157         Brewpub    9/18/2018          Open             1      432017
# 158         Brewpub    8/27/1999          Open             1        3847
# 159         Brewpub    4/16/2019          Open             1      433595
# 160         Brewpub    3/19/2014          Open             1      128836
# 161         Brewpub     4/3/2017          Open             1      167467
# 162         Brewpub     2/5/2015          Open             2      227023
# 163         Brewpub   11/22/2017          Open             1      268478
# 164         Brewpub     6/3/2016          Open             1      217887
# 165         Brewpub    5/17/2018          Open             1       25578
# 166         Brewpub    1/27/2014          Open             1      139912
# 167         Brewpub   11/30/2017          Open             1      385579
# 168         Brewpub    5/16/2014          Open             1      166919
# 169         Brewpub   11/17/2016          Open             1       16100
# 170         Brewpub    1/15/2016          Open             4      286564
# 171         Brewpub    5/15/2018          Open             1      338509
# 172         Brewpub    6/21/2017          Open             2       45012
# 173         Brewpub    5/18/2006          Open             1      102174
# 174         Brewpub    3/17/2015          Open             1      244075
# 175         Brewpub    8/16/2018          Open             1      417950
# 176         Brewpub   10/27/2014          Open             1      196698
# 177         Brewpub    6/15/2018          Open             1      351603
# 178         Brewpub     5/1/2008          Open             1       46814
# 179         Brewpub    1/17/2018          Open             1      359316
# 180         Brewpub    9/27/2018          Open             1      358500
# 181         Brewpub    1/20/2016          Open             1      260660
# 182         Brewpub    9/29/2017          Open             1      130116
# 183         Brewpub    10/4/2010          Open             1      193131
# 184         Brewpub     8/1/2016          Open             1      172572
# 185         Brewpub    3/30/2016          Open             1       88806
# 186         Brewpub    8/22/2017          Open             1      397107
# 187         Brewpub    9/24/2014          Open             1       97132
# 188         Brewpub    3/10/2015          Open             1      198470
# 189         Brewpub    8/14/2018          Open             1      409351
# 190         Brewpub    4/22/2016          Open             1      306224
# 191         Brewpub    2/28/2018          Open             1      130762
# 192         Brewpub    4/15/2019           NaN             1      421813
# 193         Brewpub    5/13/2016          Open             1      329990
# 194         Brewpub    4/23/2014          Open             9      195771
# 195         Brewpub     8/7/2017          Open             1      269009
# 196         Brewpub    8/18/2017          Open             1      124287
# 197         Brewpub     4/3/2007          Open             1      112281
# 198         Brewpub   12/17/2015          Open            25       47425
# 199         Brewpub   10/20/2014          Open             1      390798
# 200         Brewpub     4/3/2017          Open             1      294449
# 201         Brewpub    8/14/2014          Open             1       75899
# 202         Brewpub     2/5/2002          Open             1        7514
# 203         Brewpub    1/11/2007          Open             1      195408
# 204         Brewpub    2/14/2017          Open             1      367118
# 205         Brewpub    1/12/2018          Open             1      313044
# 206         Brewpub    8/13/2018          Open             1      413407
# 207         Brewpub    3/19/2013          Open             4       78569
# 208         Brewpub     2/8/2018          Open             1      295983
# 209         Brewpub   10/27/2016          Open             1      328713
# 210         Brewpub    4/27/2007          Open             1        5027
# 211         Brewpub    7/28/2017          Open             2      371789
# 212         Brewpub    9/22/2017          Open             1      343879
# 213         Brewpub    1/10/2017          Open             1      342490
# 214         Brewpub     1/5/2018          Open            11      388757
# 215         Brewpub   12/12/2018  In the works             1      439925
# 216         Brewpub    11/6/2018          Open             1      421840
# 217         Brewpub    5/17/2016          Open             1      264115
# 218         Brewpub        43048          Open             1      379699
# 219         Brewpub        42151          Open             3      245366
# 220         Brewpub        41779          Open             1      165604
# 221         Brewpub        42801          Open             1      360183
# 222         Brewpub        42906          Open             1      374693
# 223         Brewpub        39517          Open             1       10008
# 224         Brewpub        40941          Open             1      189606
#
#                                 brewery_name  beer_count  \
# 0                       Two Docs Brewing Co.          22
# 1                          3 Nations Brewing          43
# 2                      (512) Brewing Company         156
# 3                         8th Wonder Brewery         157
# 4                         Alamo Beer Company          69
# 5                       Armadillo Ale Works™          28
# 6                     Athens Brewing Company          35
# 7                           Austin Beerworks         266
# 8                         BackStory Brewery           40
# 9                  Bear King Brewing Company          14
# 10            Bitter Sisters Brewing Company          41
# 11                   Bluebonnet Beer Company          51
# 12                       Brotherwell Brewing          14
# 13                       Bull Creek Brewing           32
# 14                             Celis Brewery          48
# 15                    Community Beer Company         213
# 16               Cypress Creek Southern Ales          47
# 17                Deep Ellum Brewing Company          65
# 18                         Dirty Job Brewing          51
# 19                 Eccentric Brewing Company          16
# 20                    Edgewise Eight Brewing          24
# 21                      Four Bullets Brewery          22
# 22              Four Corners Brewing Company         133
# 23                Franconia Brewing Company           79
# 24                        Fulbrook Ale Works          38
# 25                Galveston Bay Beer Company          90
# 26                    Goliad Brewing Company          18
# 27           Dorćol Distilling + Brewing Co.          27
# 28                        Holler Brewing Co.         114
# 29             Hop And Sting Brewing Company          44
# 30                       HopFusion Ale Works          91
# 31                  Independence Brewing Co.          25
# ...
# 215                         Waco Ale Company          13
# 216                  Walking Beam Brewing Co          30
# 217              Weathered Souls Brewing Co.         318
# 218            White Rock Alehouse & Brewery          33
# 219                       Whitestone Brewery          74
# 220       Whole Foods Market Brewing Company         435
# 221            Wichita Falls Brewing Company          37
# 222                     Wicked Boxer Brewing          40
# 223                Wimberley Brewing Company          19
# 224                       Zero One Ale House          41
#
#              brewery_city brewery_state  brewery_lat  brewery_lng
# 0                 Lubbock            TX      33.5909    -101.8460
# 1          Farmers Branch            TX      32.9310     -96.8983
# 2                  Austin            TX      30.2236     -97.7697
# 3                 Houston            TX      29.7492     -95.3558
# 4             San Antonio            TX      29.4295     -98.4773
# 5                  Denton            TX      33.2126     -97.1281
# 6                  Athens            TX      32.2054     -95.8538
# 7                  Austin            TX      30.3798     -97.7302
# 8         Sulphur Springs            TX      33.1348     -95.6048
# 9            Marble Falls            TX      30.5703     -98.2749
# 10                Addison            TX      32.9618     -96.8292
# 11             Round Rock            TX      30.4919     -97.6470
# 12                   Waco            TX      31.5645     -97.1243
# 13           Liberty Hill            TX      30.7052     -97.8702
# 14                 Austin            TX      30.3797     -97.7160
# 15                 Dallas            TX      32.7909     -96.8158
# 16              Winnsboro            TX      32.9558     -95.2895
# 17                 Dallas            TX      32.7808     -96.7817
# 18              Mansfield            TX      32.5643     -97.1422
# 19                Midland            TX      31.9803    -102.0950
# 20            Weatherford            TX      32.7593     -97.7973
# 21             Richardson            TX      32.9592     -96.7261
# 22                 Dallas            TX      32.7720     -96.7918
# 23               McKinney            TX      33.2134     -96.6091
# 24               Richmond            TX      29.6119     -95.7438
# 25              Dickinson            TX      29.4836     -95.0086
# 26                 Goliad            TX      28.6683     -97.3883
# 27            San Antonio            TX      29.4057     -98.5023
# 28                Houston            TX      29.7708     -95.3803
# 29              Grapevine            TX      32.9326     -97.0748
# 30             Fort Worth            TX      32.7416     -97.3247
# 31                 Austin            TX      30.2131     -97.7358
# 32                Denison            TX      33.7551     -96.5378
# 33                Garland            TX      32.8899     -96.6809
# 34              Arlington            TX      32.7382     -97.1025
# 35                 Austin            TX      30.2200     -97.6608
# 36               Magnolia            TX      30.2089     -95.7514
# 37         Corpus Christi            TX      27.6743     -97.2793
# 38             Fort Worth            TX      32.7637     -97.3098
# 39        College Station            TX      30.5650     -96.3501
# 40                 Dallas            TX      32.8901     -96.7046
# 41             Lewisville            TX      33.0437     -96.9932
# 42                 Austin            TX      30.2619     -97.7268
# 43                 Dallas            TX      32.7993     -96.8339
# 44                 Dallas            TX      32.7964     -96.8285
# 45             Fort Worth            TX      32.7366     -97.3274
# 46            San Antonio            TX      29.5295     -98.3969
# 47                 Blanco            TX      30.1133     -98.4128
# 48               Granbury            TX      32.4189     -97.6699
# 49                Houston            TX      29.7714     -95.3486
# 50                 Conroe            TX      30.3473     -95.4349
# 51                 Dallas            TX      32.7862     -96.8175
# 52                 Austin            TX      30.2258     -97.9522
# 53                  Tyler            TX      32.3276     -95.3249
# 54               McKinney            TX      33.1972     -96.6398
# 55       Dripping Springs            TX      30.1651     -98.0847
# 56                 Austin            TX      30.2621     -97.7613
# 57                Houston            TX      29.7342     -95.3759
# 58             Fort Worth            TX      32.7439     -97.3094
# 59               Red Rock            TX      29.8694     -97.4454
# 60               Rockwall            TX      32.9133     -96.4413
# 61                 Austin            TX      30.2621     -97.7245
# 62       Dripping Springs            TX      30.2581     -98.1443
# 63                Houston            TX      29.7947     -95.5241
# 64          New Braunfels            TX      29.7099     -98.2645
# 65                Mission            TX      26.2121     -98.3114
# 66                Sherman            TX      33.6179     -96.6069
# 67       Dripping Springs            TX      30.1925     -98.0891
# 68                 Austin            TX      30.3827     -97.7202
# 69         Fredericksburg            TX      30.2252     -98.7949
# 70                 Lufkin            TX      31.3385     -94.7294
# 71              Pittsburg            TX      32.9971     -94.9671
# 72             San Marcos            TX      29.8812     -97.9402
# 73                Houston            TX      29.8354     -95.4102
# 74                El Paso            TX      31.8834    -106.5710
# 75                 Conroe            TX      30.3394     -95.5513
# 76             Brookshire            TX      29.7730     -95.9506
# 77                 Porter            TX      30.0645     -95.2647
# 78                Bandera            TX      29.7412     -99.0282
# 79                Rowlett            TX      32.9027     -96.5656
# 80               San Saba            TX      31.1967     -98.7184
# 81                   Waco            TX      31.5251     -97.1311
# 82                 Salado            TX      30.9428     -97.5360
# 83              Kerrville            TX      30.0505     -99.1386
# 84                 Austin            TX      30.2872     -97.7031
# 85                   Katy            TX      29.7855     -95.8376
# 86                Tomball            TX      30.0123     -95.6031
# 87              Galveston            TX      29.2859     -94.7942
# 88                  Pharr            TX      26.2339     -98.1832
# 89               Amarillo            TX      35.1935    -101.7550
# 90                  Bryan            TX      30.6795     -96.3723
# 91                El Paso            TX      31.7392    -106.3180
# 92                 Austin            TX      30.2549     -97.7177
# 93            San Antonio            TX      29.4101     -98.4956
# 94          Copperas Cove            TX       0.0000       0.0000
# 95                 Dallas            TX      32.7838     -96.7854
# 96                Houston            TX      29.8281     -95.4061
# 97                 Austin            TX      30.2528     -97.7022
# 98              Galveston            TX      29.3070     -94.7959
# 99                McAllen            TX      26.2154     -98.2282
# 100              Marathon            TX      30.2052    -103.2450
# 101  North Richland Hills            TX      32.8343     -97.2289
# 102                Seguin            TX      29.6882     -97.9021
# 103             Mansfield            TX      32.5626     -97.1415
# 104              Lockhart            TX      29.8836     -97.6720
# 105                Dallas            TX      32.8200     -96.8331
# 106               Sherman            TX      33.6619     -96.5995
# 107                Austin            TX      30.2651     -97.7373
# 108                Boerne            TX      29.7897     -98.7297
# 109                Austin            TX      30.3911     -97.7159
# 110               Houston            TX      29.8570     -95.3351
# 111          Pflugerville            TX      30.4700     -97.6646
# 112                Conroe            TX      30.3167     -95.4633
# 113             Dickinson            TX      29.4855     -95.0471
# 114            Montgomery            TX      30.3642     -95.6964
# 115               El Paso            TX      31.7554    -106.4920
# 116                Denton            TX      33.2148     -97.1331
# 117             Arlington            TX      32.7363     -97.1022
# 118          Marble Falls            TX      30.5711     -98.2767
# 119               El Paso            TX      31.7622    -106.4810
# 120                  Eola            TX      31.3976    -100.0900
# 121                 Tyler            TX      32.3487     -95.3010
# 122      Dripping Springs            TX      30.2922     -98.0778
# 123            Texas City            TX      29.3869     -94.9029
# 124            Fort Worth            TX      32.7304     -97.3352
# 125                Spring            TX      30.0674     -95.4586
# 126           Nacogdoches            TX      31.6035     -94.6518
# 127            Fort Worth            TX      32.7403     -97.3247
# 128             Galveston            TX      29.2557     -94.8491
# 129                 Alvin            TX      29.4238     -95.2441
# 130               Granger            TX      30.7175     -97.4443
# 131               Houston            TX      29.8219     -95.4223
# 132         New Braunfels            TX      29.6848     -98.1633
# 133                Austin            TX      30.2268     -97.6802
# 134                Austin            TX      30.2248     -97.9530
# 135                Austin            TX      30.2714     -97.7589
# 136                Rowena            TX      31.6474    -100.0420
# 137             Bellville            TX      29.9502     -96.2572
# 138                Austin            TX      30.4068     -97.9259
# 139                Humble            TX      29.9754     -95.2619
# 140                Austin            TX      30.2323     -97.9998
# 141               Comfort            TX      29.9677     -98.9050
# 142               Houston            TX      29.9203     -95.5841
# 143           San Antonio            TX      29.4049     -98.5001
# 144                Austin            TX      30.1827     -97.7816
# 145                Austin            TX      30.2617     -97.7220
# 146        Corpus Christi            TX      27.6538     -97.3724
# 147               Kilgore            TX      32.3854     -94.8749
# 148           San Antonio            TX      29.4241     -98.4936
# 149              Kingwood            TX      30.0650     -95.2266
# 150            San Marcos            TX      29.9309     -98.0717
# 151           Port Neches            TX      29.9918     -93.9585
# 152         New Braunfels            TX      29.7030     -98.1266
# 153               Pantego            TX      32.7131     -97.1609
# 154                  Katy            TX      29.7866     -95.8146
# 155                Dallas            TX      32.8031     -96.8416
# 156                Nocona            TX      33.7889     -97.7153
# 157                Austin            TX      30.2244     -97.7606
# 158                Austin            TX      30.3912     -97.7383
# 159        Corpus Christi            TX      27.7887     -97.3957
# 160                Austin            TX      30.4059     -97.8740
# 161                Austin            TX      30.2672     -97.7431
# 162               El Paso            TX      31.7820    -106.5060
# 163              Longview            TX      32.4955     -94.7403
# 164           Port Lavaca            TX      28.6138     -96.6360
# 165            Fort Worth            TX      32.7639     -97.3378
# 166               Abilene            TX      32.4446     -99.7272
# 167           Willow Park            TX      32.7438     -97.6591
# 168             Texarkana            TX      33.4214     -94.0446
# 169          Johnson City            TX      30.2776     -98.4112
# 170               Houston            TX      29.7682     -95.3775
# 171              Amarillo            TX      35.1621    -101.9230
# 172                Justin            TX      33.0894     -97.2955
# 173        Corpus Christi            TX      27.8030     -97.3941
# 174        Corpus Christi            TX      27.7942     -97.3947
# 175             Texarkana            TX      33.4310     -94.0511
# 176            Cedar Park            TX      30.5336     -97.7810
# 177           San Antonio            TX      29.4319     -98.4823
# 178            San Marcos            TX      29.8837     -97.9404
# 179         Spring Branch            TX      29.9664     -98.4334
# 180            San Marcos            TX      29.9354     -98.0617
# 181               Webster            TX      29.5269     -95.1195
# 182          Marble Falls            TX      30.6168     -98.2640
# 183            San Marcos            TX      29.8820     -97.9396
# 184                Seguin            TX      29.5654     -97.8928
# 185                Keller            TX      32.9470     -97.2537
# 186              Amarillo            TX      35.2069    -101.8370
# 187                Dallas            TX      32.7434     -96.8269
# 188            San Angelo            TX      31.4604    -100.4330
# 189               Houston            TX      30.0242     -95.4154
# 190                Austin            TX      30.2164     -97.7620
# 191                Dallas            TX      32.7784     -96.8296
# 192              Beaumont            TX      30.0861     -94.1174
# 193      Dripping Springs            TX      30.1944     -98.0240
# 194             Canutillo            TX      31.9152    -106.6030
# 195                Taylor            TX      30.5689     -97.4100
# 196         Missouri City            TX      29.6277     -95.5478
# 197               Weslaco            TX      26.1603     -97.9585
# 198              Magnolia            TX      30.2089     -95.7514
# 199               Lubbock            TX      33.5848    -101.8480
# 200                Austin            TX      30.3260     -97.7167
# 201            Fort Worth            TX      32.7431     -97.3291
# 202                Boerne            TX      29.7899     -98.7259
# 203               Houston            TX      29.7425     -95.4077
# 204            Lewisville            TX      33.0342     -96.8987
# 205               Bedford            TX      32.8350     -97.1626
# 206                Boerne            TX      29.7920     -98.7311
# 207                Irving            TX      32.9187     -96.9677
# 208               Cypress            TX      29.9717     -95.6938
# 209                  Buda            TX      30.0730     -97.8445
# 210             Grapevine            TX      32.9571     -97.0431
# 211                 Plano            TX      33.0908     -96.8215
# 212                 Plano            TX      33.0831     -96.8252
# 213              Pearland            TX      29.5757     -95.2873
# 214             Driftwood            TX      30.1044     -98.0195
# 215                  Waco            TX      31.5541     -97.1345
# 216            Bridgeport            TX      33.2106     -97.7572
# 217           San Antonio            TX      29.4876     -98.3974
# 218                Dallas            TX      32.8128     -96.7299
# 219            Cedar Park            TX      30.5235     -97.8243
# 220               Houston            TX      29.7502     -95.4614
# 221         Wichita Falls            TX      33.9136     -98.4913
# 222               Cypress            TX      30.0112     -95.7243
# 223             Wimberley            TX      29.9435     -98.0925
# 224            San Angelo            TX      31.4625    -100.4380

# %%
import pickle
import numpy as np
import pandas as pd
import math
from IPython.display import clear_output

# Load data
with open ("../data/all_breweries.pkl", "rb") as fp:
    all_breweries = pickle.load(fp)

untappd = Untappd()

i = 0
for brewery in all_breweries:
    if "brewery_id" in brewery and "brewery_info" not in brewery:
        brewery_info, counter, response = untappd.breweryInfo(brewery["brewery_id"])

        brewery["brewery_info"] = brewery_info
        
        clear_output(wait=True)
        display(counter)
        if counter == 0:
            break
        
with open("../data/all_breweries.pkl", "wb") as fp:
    pickle.dump(all_breweries, fp)
    
print("Sample output")
display(all_breweries[1]["brewery_info"])

print("Completed on ", datetime.now())
# Out:
# 0
# Sample output
# {'brewery': {'brewery_id': 420745,
#   'brewery_name': 'Two Docs Brewing Co.',
#   'brewery_slug': 'two-docs-brewing',
#   'brewery_page_url': '/TwoDocsBrewingCo',
#   'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#   'brewery_label_hd': '',
#   'country_name': 'United States',
#   'brewery_in_production': 0,
#   'is_independent': 1,
#   'claimed_status': {'is_claimed': True,
#    'claimed_slug': 'TwoDocsBrewingCo',
#    'follow_status': False,
#    'follower_count': 72,
#    'uid': 6376655,
#    'mute_status': 'none'},
#   'beer_count': 22,
#   'contact': {'twitter': '',
#    'facebook': 'https://www.facebook.com/twodocsbrewing',
#    'instagram': 'twodocsbrewing',
#    'url': 'https://twodocsbrewing.com/'},
#   'brewery_type': 'Micro Brewery',
#   'brewery_type_id': 2,
#   'location': {'brewery_address': '502 Texas Ave',
#    'brewery_city': 'Lubbock',
#    'brewery_state': 'TX',
#    'brewery_lat': 33.5909,
#    'brewery_lng': -101.846},
#   'rating': {'count': 1943, 'rating_score': 3.791},
#   'brewery_description': 'We want to share our love of craft beer with West Texas. When you come into our taproom an expert staff will welcome you to a place where you can explore beer, expand your tastes, and have a great time.',
#   'stats': {'total_count': 2400,
#    'unique_count': 711,
#    'monthly_count': 153,
#    'weekly_count': 0,
#    'user_count': 0,
#    'age_on_service': 271.9091550925926},
#   'owners': {'count': 0, 'items': []},
#   'media': {'count': 15,
#    'items': [{'photo_id': 261142284,
#      'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_29/233f0ee846113f965095404c85eb37a2_200x200.jpg',
#       'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_29/233f0ee846113f965095404c85eb37a2_640x640.jpg',
#       'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_29/233f0ee846113f965095404c85eb37a2_1280x1280.jpg',
#       'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_29/233f0ee846113f965095404c85eb37a2_raw.jpg'},
#      'created_at': 'Tue, 29 Oct 2019 00:03:24 +0000',
#      'checkin_id': 823141672,
#      'beer': {'bid': 3408493,
#       'beer_name': 'Hayes-E Baby IPA',
#       'beer_abv': 7.1,
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'IPA - New England'},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'user': {'uid': 1129994,
#       'user_name': 'Mikegib',
#       'first_name': 'Michael',
#       'last_name': 'G',
#       'user_avatar': 'https://untappd.akamaized.net/profile/8e268bea2010265abea610af88cbdbe7_100x100.jpg',
#       'is_private': 0},
#      'venue': {'venue_id': 9090786,
#       'venue_name': 'Growler USA - Lubbock',
#       'venue_slug': 'growler-usa-lubbock',
#       'primary_category': 'Food',
#       'parent_category_id': '4d4b7105d754a06374d81259',
#       'categories': {'count': 1,
#        'items': [{'category_key': 'restaurant',
#          'category_name': 'Restaurant',
#          'category_id': '4bf58dd8d48988d1c4941735',
#          'is_primary': True}]},
#       'location': {'venue_address': '6030 Marsha Sharp Fwy, Suite 200',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'lat': 33.5485,
#        'lng': -101.95},
#       'contact': {'twitter': '@GrowlerLubbock',
#        'venue_url': 'Growlerusa.com/Lubbock'},
#       'foursquare': {'foursquare_id': '5d10ed17de944500235ea31d',
#        'foursquare_url': 'https://4sq.com/2LcGU91'},
#       'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_9090786_674f03d3_bg_64.png',
#        'md': 'https://untappd.akamaized.net/venuelogos/venue_9090786_674f03d3_bg_88.png',
#        'lg': 'https://untappd.akamaized.net/venuelogos/venue_9090786_674f03d3_bg_176.png?v=1'},
#       'is_verified': 1}},
#     {'photo_id': 261057600,
#      'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_28/568310a2ebafd3160a91198fea23db06_200x200.jpg',
#       'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_28/568310a2ebafd3160a91198fea23db06_640x640.jpg',
#       'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_28/568310a2ebafd3160a91198fea23db06_1280x1280.jpg',
#       'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_28/568310a2ebafd3160a91198fea23db06_raw.jpg'},
#      'created_at': 'Mon, 28 Oct 2019 00:20:38 +0000',
#      'checkin_id': 822940561,
#      'beer': {'bid': 3408493,
#       'beer_name': 'Hayes-E Baby IPA',
#       'beer_abv': 7.1,
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'IPA - New England'},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'user': {'uid': 3203713,
#       'user_name': 'gpkennedy',
#       'first_name': 'Gabriel',
#       'last_name': 'K',
#       'user_avatar': 'https://untappd.akamaized.net/profile/02337b9a1b7b3852c11c8922b8b3d13a_100x100.jpg',
#       'is_private': 0},
#      'venue': {'venue_id': 8707470,
#       'venue_name': 'Two Docs Brewing Co.',
#       'venue_slug': 'two-docs-brewing-co',
#       'primary_category': 'Nightlife Spot',
#       'parent_category_id': '4d4b7105d754a06376d81259',
#       'categories': {'count': 1,
#        'items': [{'category_key': 'brewery',
#          'category_name': 'Brewery',
#          'category_id': '50327c8591d4c4b30a586d5d',
#          'is_primary': True}]},
#       'location': {'venue_address': '502 Texas Ave',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#       'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#        'foursquare_url': 'https://4sq.com/2IJTFbR'},
#       'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#        'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#        'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#       'is_verified': 1}},
#     {'photo_id': 261031935,
#      'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photo/2019_10_27/84cd98d68bd9eed8e7c0f1abd3f9b6ed_c_822872119_200x200.jpg',
#       'photo_img_md': 'https://untappd.akamaized.net/photo/2019_10_27/84cd98d68bd9eed8e7c0f1abd3f9b6ed_c_822872119_640x640.jpg',
#       'photo_img_lg': 'https://untappd.akamaized.net/photo/2019_10_27/84cd98d68bd9eed8e7c0f1abd3f9b6ed_c_822872119_1280x1280.jpg',
#       'photo_img_og': 'https://untappd.akamaized.net/photo/2019_10_27/84cd98d68bd9eed8e7c0f1abd3f9b6ed_c_822872119_raw.jpg'},
#      'created_at': 'Sun, 27 Oct 2019 21:52:57 +0000',
#      'checkin_id': 822872119,
#      'beer': {'bid': 3440110,
#       'beer_name': 'Doktoberfest',
#       'beer_abv': 6.1,
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'Festbier'},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'user': {'uid': 1242913,
#       'user_name': 'fthames',
#       'first_name': 'Frank',
#       'last_name': 'T',
#       'user_avatar': 'https://untappd.akamaized.net/profile/493c1601aacb58f0a4b764b93d780b51_100x100.jpg',
#       'is_private': 0},
#      'venue': {'venue_id': 8707470,
#       'venue_name': 'Two Docs Brewing Co.',
#       'venue_slug': 'two-docs-brewing-co',
#       'primary_category': 'Nightlife Spot',
#       'parent_category_id': '4d4b7105d754a06376d81259',
#       'categories': {'count': 1,
#        'items': [{'category_key': 'brewery',
#          'category_name': 'Brewery',
#          'category_id': '50327c8591d4c4b30a586d5d',
#          'is_primary': True}]},
#       'location': {'venue_address': '502 Texas Ave',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#       'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#        'foursquare_url': 'https://4sq.com/2IJTFbR'},
#       'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#        'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#        'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#       'is_verified': 1}},
#     {'photo_id': 260736276,
#      'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_26/36a735bfcb51f5b43464a2407f6e6f4a_200x200.jpg',
#       'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_26/36a735bfcb51f5b43464a2407f6e6f4a_640x640.jpg',
#       'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_26/36a735bfcb51f5b43464a2407f6e6f4a_1280x1280.jpg',
#       'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_26/36a735bfcb51f5b43464a2407f6e6f4a_raw.jpg'},
#      'created_at': 'Sat, 26 Oct 2019 19:22:30 +0000',
#      'checkin_id': 822145054,
#      'beer': {'bid': 3209433,
#       'beer_name': 'Dos Doctores',
#       'beer_abv': 5.4,
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'Lager - Vienna'},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'user': {'uid': 2109800,
#       'user_name': 'Jdlbk',
#       'first_name': 'Jess',
#       'last_name': 'W',
#       'user_avatar': 'https://gravatar.com/avatar/26951d2bdb4acfcb18b10ab0b2a7ea4a?size=100&d=https%3A%2F%2Funtappd.akamaized.net%2Fsite%2Fassets%2Fimages%2Fdefault_avatar_v3_gravatar.jpg%3Fv%3D2',
#       'is_private': 0},
#      'venue': {'venue_id': 8707470,
#       'venue_name': 'Two Docs Brewing Co.',
#       'venue_slug': 'two-docs-brewing-co',
#       'primary_category': 'Nightlife Spot',
#       'parent_category_id': '4d4b7105d754a06376d81259',
#       'categories': {'count': 1,
#        'items': [{'category_key': 'brewery',
#          'category_name': 'Brewery',
#          'category_id': '50327c8591d4c4b30a586d5d',
#          'is_primary': True}]},
#       'location': {'venue_address': '502 Texas Ave',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#       'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#        'foursquare_url': 'https://4sq.com/2IJTFbR'},
#       'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#        'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#        'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#       'is_verified': 1}},
#     {'photo_id': 260725438,
#      'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_26/d1f0ceddf29f2ac76a93a31d5e16f173_200x200.jpg',
#       'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_26/d1f0ceddf29f2ac76a93a31d5e16f173_640x640.jpg',
#       'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_26/d1f0ceddf29f2ac76a93a31d5e16f173_1280x1280.jpg',
#       'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_26/d1f0ceddf29f2ac76a93a31d5e16f173_raw.jpg'},
#      'created_at': 'Sat, 26 Oct 2019 19:00:20 +0000',
#      'checkin_id': 822119811,
#      'beer': {'bid': 3063015,
#       'beer_name': 'Prairie Dawg Porter',
#       'beer_abv': 5.9,
#       'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-3063015_38cdd_sm.jpeg',
#       'beer_style': 'Porter - American'},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'user': {'uid': 2109800,
#       'user_name': 'Jdlbk',
#       'first_name': 'Jess',
#       'last_name': 'W',
#       'user_avatar': 'https://gravatar.com/avatar/26951d2bdb4acfcb18b10ab0b2a7ea4a?size=100&d=https%3A%2F%2Funtappd.akamaized.net%2Fsite%2Fassets%2Fimages%2Fdefault_avatar_v3_gravatar.jpg%3Fv%3D2',
#       'is_private': 0},
#      'venue': {'venue_id': 8707470,
#       'venue_name': 'Two Docs Brewing Co.',
#       'venue_slug': 'two-docs-brewing-co',
#       'primary_category': 'Nightlife Spot',
#       'parent_category_id': '4d4b7105d754a06376d81259',
#       'categories': {'count': 1,
#        'items': [{'category_key': 'brewery',
#          'category_name': 'Brewery',
#          'category_id': '50327c8591d4c4b30a586d5d',
#          'is_primary': True}]},
#       'location': {'venue_address': '502 Texas Ave',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#       'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#        'foursquare_url': 'https://4sq.com/2IJTFbR'},
#       'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#        'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#        'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#       'is_verified': 1}},
#     {'photo_id': 260582371,
#      'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_26/d597f0ce32b3c872525eb9102e92ea20_200x200.jpg',
#       'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_26/d597f0ce32b3c872525eb9102e92ea20_640x640.jpg',
#       'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_26/d597f0ce32b3c872525eb9102e92ea20_1280x1280.jpg',
#       'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_26/d597f0ce32b3c872525eb9102e92ea20_raw.jpg'},
#      'created_at': 'Sat, 26 Oct 2019 04:19:47 +0000',
#      'checkin_id': 821803598,
#      'beer': {'bid': 3500094,
#       'beer_name': 'Prairie Dog Porter - Mexican Cocoa',
#       'beer_abv': 0,
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'Porter - Other'},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'user': {'uid': 1429511,
#       'user_name': 'dcsfoyle',
#       'first_name': 'Eric',
#       'last_name': 'R',
#       'user_avatar': 'https://untappd.akamaized.net/profile/a313cb1054443db78d8e914c4780daa4_100x100.jpg',
#       'is_private': 0},
#      'venue': {'venue_id': 8707470,
#       'venue_name': 'Two Docs Brewing Co.',
#       'venue_slug': 'two-docs-brewing-co',
#       'primary_category': 'Nightlife Spot',
#       'parent_category_id': '4d4b7105d754a06376d81259',
#       'categories': {'count': 1,
#        'items': [{'category_key': 'brewery',
#          'category_name': 'Brewery',
#          'category_id': '50327c8591d4c4b30a586d5d',
#          'is_primary': True}]},
#       'location': {'venue_address': '502 Texas Ave',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#       'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#        'foursquare_url': 'https://4sq.com/2IJTFbR'},
#       'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#        'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#        'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#       'is_verified': 1}},
#     {'photo_id': 260581452,
#      'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_26/9b2232b8a81c4408e643552cb57c7351_200x200.jpg',
#       'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_26/9b2232b8a81c4408e643552cb57c7351_640x640.jpg',
#       'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_26/9b2232b8a81c4408e643552cb57c7351_1280x1280.jpg',
#       'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_26/9b2232b8a81c4408e643552cb57c7351_raw.jpg'},
#      'created_at': 'Sat, 26 Oct 2019 04:09:49 +0000',
#      'checkin_id': 821802229,
#      'beer': {'bid': 3440110,
#       'beer_name': 'Doktoberfest',
#       'beer_abv': 6.1,
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'Festbier'},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'user': {'uid': 1017530,
#       'user_name': 'johnnyreina',
#       'first_name': 'Satan',
#       'last_name': '',
#       'user_avatar': 'https://untappd.akamaized.net/profile/e7291361ca25ff19c5944aea3e01e530_100x100.jpg',
#       'is_private': 0},
#      'venue': {'venue_id': 8707470,
#       'venue_name': 'Two Docs Brewing Co.',
#       'venue_slug': 'two-docs-brewing-co',
#       'primary_category': 'Nightlife Spot',
#       'parent_category_id': '4d4b7105d754a06376d81259',
#       'categories': {'count': 1,
#        'items': [{'category_key': 'brewery',
#          'category_name': 'Brewery',
#          'category_id': '50327c8591d4c4b30a586d5d',
#          'is_primary': True}]},
#       'location': {'venue_address': '502 Texas Ave',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#       'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#        'foursquare_url': 'https://4sq.com/2IJTFbR'},
#       'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#        'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#        'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#       'is_verified': 1}},
#     {'photo_id': 260578609,
#      'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_26/89e576a05a08f64a2906a74f2f78ba51_200x200.jpg',
#       'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_26/89e576a05a08f64a2906a74f2f78ba51_640x640.jpg',
#       'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_26/89e576a05a08f64a2906a74f2f78ba51_1280x1280.jpg',
#       'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_26/89e576a05a08f64a2906a74f2f78ba51_raw.jpg'},
#      'created_at': 'Sat, 26 Oct 2019 03:42:42 +0000',
#      'checkin_id': 821794344,
#      'beer': {'bid': 3408493,
#       'beer_name': 'Hayes-E Baby IPA',
#       'beer_abv': 7.1,
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'IPA - New England'},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'user': {'uid': 1017530,
#       'user_name': 'johnnyreina',
#       'first_name': 'Satan',
#       'last_name': '',
#       'user_avatar': 'https://untappd.akamaized.net/profile/e7291361ca25ff19c5944aea3e01e530_100x100.jpg',
#       'is_private': 0},
#      'venue': {'venue_id': 8707470,
#       'venue_name': 'Two Docs Brewing Co.',
#       'venue_slug': 'two-docs-brewing-co',
#       'primary_category': 'Nightlife Spot',
#       'parent_category_id': '4d4b7105d754a06376d81259',
#       'categories': {'count': 1,
#        'items': [{'category_key': 'brewery',
#          'category_name': 'Brewery',
#          'category_id': '50327c8591d4c4b30a586d5d',
#          'is_primary': True}]},
#       'location': {'venue_address': '502 Texas Ave',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#       'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#        'foursquare_url': 'https://4sq.com/2IJTFbR'},
#       'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#        'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#        'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#       'is_verified': 1}},
#     {'photo_id': 260577499,
#      'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_26/0cec2d2c63d8195ea71e09037d2650b9_200x200.jpg',
#       'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_26/0cec2d2c63d8195ea71e09037d2650b9_640x640.jpg',
#       'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_26/0cec2d2c63d8195ea71e09037d2650b9_1280x1280.jpg',
#       'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_26/0cec2d2c63d8195ea71e09037d2650b9_raw.jpg'},
#      'created_at': 'Sat, 26 Oct 2019 03:33:34 +0000',
#      'checkin_id': 821791136,
#      'beer': {'bid': 3408493,
#       'beer_name': 'Hayes-E Baby IPA',
#       'beer_abv': 7.1,
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'IPA - New England'},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'user': {'uid': 1017530,
#       'user_name': 'johnnyreina',
#       'first_name': 'Satan',
#       'last_name': '',
#       'user_avatar': 'https://untappd.akamaized.net/profile/e7291361ca25ff19c5944aea3e01e530_100x100.jpg',
#       'is_private': 0},
#      'venue': {'venue_id': 8707470,
#       'venue_name': 'Two Docs Brewing Co.',
#       'venue_slug': 'two-docs-brewing-co',
#       'primary_category': 'Nightlife Spot',
#       'parent_category_id': '4d4b7105d754a06376d81259',
#       'categories': {'count': 1,
#        'items': [{'category_key': 'brewery',
#          'category_name': 'Brewery',
#          'category_id': '50327c8591d4c4b30a586d5d',
#          'is_primary': True}]},
#       'location': {'venue_address': '502 Texas Ave',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#       'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#        'foursquare_url': 'https://4sq.com/2IJTFbR'},
#       'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#        'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#        'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#       'is_verified': 1}},
#     {'photo_id': 260552871,
#      'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_26/952e03e92a6d47a8af5381e91cf136db_200x200.jpg',
#       'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_26/952e03e92a6d47a8af5381e91cf136db_640x640.jpg',
#       'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_26/952e03e92a6d47a8af5381e91cf136db_1280x1280.jpg',
#       'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_26/952e03e92a6d47a8af5381e91cf136db_raw.jpg'},
#      'created_at': 'Sat, 26 Oct 2019 01:20:44 +0000',
#      'checkin_id': 821721707,
#      'beer': {'bid': 3063015,
#       'beer_name': 'Prairie Dawg Porter',
#       'beer_abv': 5.9,
#       'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-3063015_38cdd_sm.jpeg',
#       'beer_style': 'Porter - American'},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'user': {'uid': 5298782,
#       'user_name': 'redlacedoxfords',
#       'first_name': 'Kelsey',
#       'last_name': 'S',
#       'user_avatar': 'https://untappd.akamaized.net/profile/56835bf4a415ef8dbb681ba00e7e7b5d_100x100.jpg',
#       'is_private': 0},
#      'venue': []},
#     {'photo_id': 260293102,
#      'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_24/9e3175a4e87a3954c8cd40fa72a9270b_200x200.jpg',
#       'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_24/9e3175a4e87a3954c8cd40fa72a9270b_640x640.jpg',
#       'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_24/9e3175a4e87a3954c8cd40fa72a9270b_1280x1280.jpg',
#       'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_24/9e3175a4e87a3954c8cd40fa72a9270b_raw.jpg'},
#      'created_at': 'Thu, 24 Oct 2019 22:43:27 +0000',
#      'checkin_id': 821113091,
#      'beer': {'bid': 3440110,
#       'beer_name': 'Doktoberfest',
#       'beer_abv': 6.1,
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'Festbier'},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'user': {'uid': 3414905,
#       'user_name': 'dpftex',
#       'first_name': 'Danny',
#       'last_name': 'F',
#       'user_avatar': 'https://untappd.akamaized.net/profile/2d871269d7f4e088e418dfe2793e064d_100x100.jpeg',
#       'is_private': 0},
#      'venue': {'venue_id': 3408071,
#       'venue_name': 'Flippers Tavern',
#       'venue_slug': 'flippers-tavern',
#       'primary_category': 'Food',
#       'parent_category_id': '4d4b7105d754a06374d81259',
#       'categories': {'count': 3,
#        'items': [{'category_key': 'hot_dog_joint',
#          'category_name': 'Hot Dog Joint',
#          'category_id': '4bf58dd8d48988d16f941735',
#          'is_primary': True},
#         {'category_key': 'arcade',
#          'category_name': 'Arcade',
#          'category_id': '4bf58dd8d48988d1e1931735',
#          'is_primary': False},
#         {'category_key': 'bar',
#          'category_name': 'Bar',
#          'category_id': '4bf58dd8d48988d116941735',
#          'is_primary': False}]},
#       'location': {'venue_address': '1406 Avenue Q',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'lat': 33.5824,
#        'lng': -101.855},
#       'contact': {'twitter': '', 'venue_url': ''},
#       'foursquare': {'foursquare_id': '55caaa5a498e79b3b94477a7',
#        'foursquare_url': 'http://4sq.com/1N1TItL'},
#       'venue_icon': {'sm': 'https://ss3.4sqi.net/img/categories_v2/food/hotdog_bg_64.png',
#        'md': 'https://ss3.4sqi.net/img/categories_v2/food/hotdog_bg_88.png',
#        'lg': 'https://ss3.4sqi.net/img/categories_v2/food/hotdog_bg_512.png'},
#       'is_verified': 0}},
#     {'photo_id': 260166345,
#      'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_23/b86e4251d6569cf2edf0a1068aeff541_200x200.jpg',
#       'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_23/b86e4251d6569cf2edf0a1068aeff541_640x640.jpg',
#       'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_23/b86e4251d6569cf2edf0a1068aeff541_1280x1280.jpg',
#       'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_23/b86e4251d6569cf2edf0a1068aeff541_raw.jpg'},
#      'created_at': 'Wed, 23 Oct 2019 23:02:43 +0000',
#      'checkin_id': 820818891,
#      'beer': {'bid': 3062868,
#       'beer_name': 'Buddy Hoppy IPA',
#       'beer_abv': 8.2,
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'IPA - American'},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'user': {'uid': 661191,
#       'user_name': 'Jgthomp',
#       'first_name': 'Jason',
#       'last_name': 'T',
#       'user_avatar': 'https://untappd.akamaized.net/profile/72eb38d3243cfba9b57035294292226e_100x100.jpg',
#       'is_private': 0},
#      'venue': {'venue_id': 8707470,
#       'venue_name': 'Two Docs Brewing Co.',
#       'venue_slug': 'two-docs-brewing-co',
#       'primary_category': 'Nightlife Spot',
#       'parent_category_id': '4d4b7105d754a06376d81259',
#       'categories': {'count': 1,
#        'items': [{'category_key': 'brewery',
#          'category_name': 'Brewery',
#          'category_id': '50327c8591d4c4b30a586d5d',
#          'is_primary': True}]},
#       'location': {'venue_address': '502 Texas Ave',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#       'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#        'foursquare_url': 'https://4sq.com/2IJTFbR'},
#       'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#        'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#        'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#       'is_verified': 1}},
#     {'photo_id': 260059867,
#      'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_22/1b87a5ec23cf1196e413e032e6e0bae1_200x200.jpg',
#       'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_22/1b87a5ec23cf1196e413e032e6e0bae1_640x640.jpg',
#       'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_22/1b87a5ec23cf1196e413e032e6e0bae1_1280x1280.jpg',
#       'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_22/1b87a5ec23cf1196e413e032e6e0bae1_raw.jpg'},
#      'created_at': 'Tue, 22 Oct 2019 23:32:43 +0000',
#      'checkin_id': 820573344,
#      'beer': {'bid': 3440110,
#       'beer_name': 'Doktoberfest',
#       'beer_abv': 6.1,
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'Festbier'},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'user': {'uid': 184852,
#       'user_name': 'MarkTTU',
#       'first_name': 'Mark',
#       'last_name': '',
#       'user_avatar': 'https://untappd.akamaized.net/profile/4b6c6af4442c4021c99069ddb3c2648d_100x100.jpg',
#       'is_private': 0},
#      'venue': {'venue_id': 8707470,
#       'venue_name': 'Two Docs Brewing Co.',
#       'venue_slug': 'two-docs-brewing-co',
#       'primary_category': 'Nightlife Spot',
#       'parent_category_id': '4d4b7105d754a06376d81259',
#       'categories': {'count': 1,
#        'items': [{'category_key': 'brewery',
#          'category_name': 'Brewery',
#          'category_id': '50327c8591d4c4b30a586d5d',
#          'is_primary': True}]},
#       'location': {'venue_address': '502 Texas Ave',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#       'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#        'foursquare_url': 'https://4sq.com/2IJTFbR'},
#       'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#        'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#        'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#       'is_verified': 1}},
#     {'photo_id': 259817533,
#      'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_20/a457d5e9ec3377b0d1bea8553990d879_200x200.jpg',
#       'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_20/a457d5e9ec3377b0d1bea8553990d879_640x640.jpg',
#       'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_20/a457d5e9ec3377b0d1bea8553990d879_1280x1280.jpg',
#       'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_20/a457d5e9ec3377b0d1bea8553990d879_raw.jpg'},
#      'created_at': 'Sun, 20 Oct 2019 19:23:51 +0000',
#      'checkin_id': 819991411,
#      'beer': {'bid': 3408493,
#       'beer_name': 'Hayes-E Baby IPA',
#       'beer_abv': 7.1,
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'IPA - New England'},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'user': {'uid': 1847754,
#       'user_name': 'Nobandsland1',
#       'first_name': 'Dirk',
#       'last_name': 'D',
#       'user_avatar': 'https://untappd.akamaized.net/profile/25a524f8bc4cf1a6b70877258bf9906f_100x100.jpg',
#       'is_private': 0},
#      'venue': {'venue_id': 8707470,
#       'venue_name': 'Two Docs Brewing Co.',
#       'venue_slug': 'two-docs-brewing-co',
#       'primary_category': 'Nightlife Spot',
#       'parent_category_id': '4d4b7105d754a06376d81259',
#       'categories': {'count': 1,
#        'items': [{'category_key': 'brewery',
#          'category_name': 'Brewery',
#          'category_id': '50327c8591d4c4b30a586d5d',
#          'is_primary': True}]},
#       'location': {'venue_address': '502 Texas Ave',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#       'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#        'foursquare_url': 'https://4sq.com/2IJTFbR'},
#       'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#        'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#        'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#       'is_verified': 1}},
#     {'photo_id': 259817000,
#      'photo': {'photo_img_sm': 'https://untappd.akamaized.net/photos/2019_10_20/27f53e0838d906a53ac265e1ef6acabb_200x200.jpg',
#       'photo_img_md': 'https://untappd.akamaized.net/photos/2019_10_20/27f53e0838d906a53ac265e1ef6acabb_640x640.jpg',
#       'photo_img_lg': 'https://untappd.akamaized.net/photos/2019_10_20/27f53e0838d906a53ac265e1ef6acabb_1280x1280.jpg',
#       'photo_img_og': 'https://untappd.akamaized.net/photos/2019_10_20/27f53e0838d906a53ac265e1ef6acabb_raw.jpg'},
#      'created_at': 'Sun, 20 Oct 2019 19:21:56 +0000',
#      'checkin_id': 819990171,
#      'beer': {'bid': 3440110,
#       'beer_name': 'Doktoberfest',
#       'beer_abv': 6.1,
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'Festbier'},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'user': {'uid': 1847754,
#       'user_name': 'Nobandsland1',
#       'first_name': 'Dirk',
#       'last_name': 'D',
#       'user_avatar': 'https://untappd.akamaized.net/profile/25a524f8bc4cf1a6b70877258bf9906f_100x100.jpg',
#       'is_private': 0},
#      'venue': {'venue_id': 8707470,
#       'venue_name': 'Two Docs Brewing Co.',
#       'venue_slug': 'two-docs-brewing-co',
#       'primary_category': 'Nightlife Spot',
#       'parent_category_id': '4d4b7105d754a06376d81259',
#       'categories': {'count': 1,
#        'items': [{'category_key': 'brewery',
#          'category_name': 'Brewery',
#          'category_id': '50327c8591d4c4b30a586d5d',
#          'is_primary': True}]},
#       'location': {'venue_address': '502 Texas Ave',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#       'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#        'foursquare_url': 'https://4sq.com/2IJTFbR'},
#       'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#        'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#        'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#       'is_verified': 1}}]},
#   'checkins': {'count': 15,
#    'items': [{'checkin_id': 823627778,
#      'created_at': 'Thu, 31 Oct 2019 01:19:13 +0000',
#      'checkin_comment': '',
#      'rating_score': 0,
#      'user': {'uid': 2328105,
#       'user_name': 'Sdugger1',
#       'first_name': 'Scott',
#       'last_name': 'D.',
#       'location': '',
#       'url': '',
#       'is_supporter': 0,
#       'bio': '',
#       'relationship': None,
#       'user_avatar': 'https://gravatar.com/avatar/03a310a2ae08be9acdec8c93722cec44?size=100&d=https%3A%2F%2Funtappd.akamaized.net%2Fsite%2Fassets%2Fimages%2Fdefault_avatar_v3_gravatar.jpg%3Fv%3D2',
#       'is_private': 0},
#      'beer': {'bid': 3104744,
#       'beer_name': 'Lubbock Light',
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_abv': 4,
#       'beer_ibu': 9,
#       'beer_slug': 'two-docs-brewing-co-lubbock-light',
#       'beer_description': 'An All-American Light beer. Think golf, tailgates, poolside or really anytime you are thirsty and need a beer... or 4.',
#       'beer_style': 'Lager - Helles',
#       'has_had': False,
#       'beer_active': 1},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'venue': {'venue_id': 9090786,
#       'venue_name': 'Growler USA - Lubbock',
#       'venue_slug': 'growler-usa-lubbock',
#       'primary_category_key': 'Food',
#       'primary_category': 'Food',
#       'parent_category_id': '4d4b7105d754a06374d81259',
#       'categories': {'count': 1,
#        'items': [{'category_key': 'restaurant',
#          'category_name': 'Restaurant',
#          'category_id': '4bf58dd8d48988d1c4941735',
#          'is_primary': True}]},
#       'location': {'venue_address': '6030 Marsha Sharp Fwy, Suite 200',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'venue_country': 'United States',
#        'lat': 33.5485,
#        'lng': -101.95},
#       'contact': {'twitter': '@GrowlerLubbock',
#        'venue_url': 'Growlerusa.com/Lubbock'},
#       'foursquare': {'foursquare_id': '5d10ed17de944500235ea31d',
#        'foursquare_url': 'https://4sq.com/2LcGU91'},
#       'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_9090786_674f03d3_bg_64.png',
#        'md': 'https://untappd.akamaized.net/venuelogos/venue_9090786_674f03d3_bg_88.png',
#        'lg': 'https://untappd.akamaized.net/venuelogos/venue_9090786_674f03d3_bg_176.png?v=1'},
#       'is_verified': True},
#      'comments': {'total_count': 0, 'count': 0, 'items': []},
#      'toasts': {'total_count': 1,
#       'count': 1,
#       'auth_toast': None,
#       'items': [{'uid': 6376655,
#         'user': {'uid': 6376655,
#          'user_name': 'TwoDocsBrewingCo',
#          'first_name': 'Two Docs Brewing Co.',
#          'last_name': '',
#          'bio': '',
#          'location': '',
#          'relationship': 'none',
#          'user_avatar': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#          'account_type': 'brewery',
#          'venue_details': [],
#          'brewery_details': {'brewery_id': 420745},
#          'user_link': 'https://untappd.com/brewery/420745'},
#         'like_id': 735888294,
#         'like_owner': False,
#         'created_at': 'Thu, 31 Oct 2019 15:51:57 +0000'}]},
#      'media': {'count': 0, 'items': []},
#      'source': {'app_name': 'Untappd for iPhone - (V2)',
#       'app_website': 'http://untpd.it/iphoneapp'},
#      'badges': {'count': 0, 'items': []}},
#     {'checkin_id': 823623699,
#      'created_at': 'Thu, 31 Oct 2019 01:08:11 +0000',
#      'checkin_comment': '',
#      'rating_score': 3.25,
#      'user': {'uid': 1520691,
#       'user_name': 'MotleyBrue67',
#       'first_name': 'Drew',
#       'last_name': 'C.',
#       'location': '',
#       'url': '',
#       'is_supporter': 0,
#       'bio': '',
#       'relationship': None,
# ...
#     {'total_user_count': 0,
#      'has_had': None,
#      'total_count': 82,
#      'beer': {'bid': 3063015,
#       'beer_name': 'Prairie Dawg Porter',
#       'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-3063015_38cdd_sm.jpeg',
#       'beer_style': 'Porter - American',
#       'beer_abv': 5.9,
#       'beer_ibu': 32,
#       'beer_slug': 'two-docs-brewing-co-prairie-dawg-porter',
#       'beer_description': 'Big notes of chocolate and coffee are balanced out with a late kick of hops. This is our salute to the original inhabitants of the South Plains. If you need something to snuggle up to when the temperature drops, this brew, much like Lubbock’s mascot, will have you feeling all warm and fuzzy.',
#       'is_in_production': 1,
#       'created_at': 'Sat, 02 Feb 2019 01:54:03 +0000',
#       'user_rating_score': 0,
#       'rating_score': 3.788,
#       'rating_count': 72,
#       'on_list': False,
#       'auth_rating': 0,
#       'wish_list': False},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'friends': {'items': [], 'count': 0}},
#     {'total_user_count': 0,
#      'has_had': None,
#      'total_count': 78,
#      'beer': {'bid': 3104757,
#       'beer_name': 'Easy Blonde',
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'Blonde Ale',
#       'beer_abv': 4,
#       'beer_ibu': 16,
#       'beer_slug': 'two-docs-brewing-co-easy-blonde',
#       'beer_description': 'Light, crisp and refreshing with a little kiss of Amarillo hops at the end. This blonde is hard to resist and keeps you coming back for more.',
#       'is_in_production': 1,
#       'created_at': 'Fri, 01 Mar 2019 20:52:50 +0000',
#       'user_rating_score': 0,
#       'rating_score': 3.664,
#       'rating_count': 67,
#       'on_list': False,
#       'auth_rating': 0,
#       'wish_list': False},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'friends': {'items': [], 'count': 0}},
#     {'total_user_count': 0,
#      'has_had': None,
#      'total_count': 71,
#      'beer': {'bid': 3104736,
#       'beer_name': 'Steampunk Ale',
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'California Common',
#       'beer_abv': 4.4,
#       'beer_ibu': 33,
#       'beer_slug': 'two-docs-brewing-co-steampunk-ale',
#       'beer_description': 'Smooth drinking amber colored ale brewed with lager yeast. Bay Area inspired, High Plains crafted.',
#       'is_in_production': 1,
#       'created_at': 'Fri, 01 Mar 2019 20:45:17 +0000',
#       'user_rating_score': 0,
#       'rating_score': 3.68,
#       'rating_count': 64,
#       'on_list': False,
#       'auth_rating': 0,
#       'wish_list': False},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'friends': {'items': [], 'count': 0}},
#     {'total_user_count': 0,
#      'has_had': None,
#      'total_count': 18,
#      'beer': {'bid': 3376550,
#       'beer_name': 'Watermelon Gose',
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'Shandy / Radler',
#       'beer_abv': 3.64,
#       'beer_ibu': 0,
#       'beer_slug': 'two-docs-brewing-co-watermelon-gose',
#       'beer_description': 'Needing a cool down? For a limited time, enjoy our newly crafted Watermelon Gose for a nice time on the patio. ',
#       'is_in_production': 1,
#       'created_at': 'Sat, 10 Aug 2019 15:47:59 +0000',
#       'user_rating_score': 0,
#       'rating_score': 3.8,
#       'rating_count': 15,
#       'on_list': False,
#       'auth_rating': 0,
#       'wish_list': False},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'friends': {'items': [], 'count': 0}},
#     {'total_user_count': 0,
#      'has_had': None,
#      'total_count': 10,
#      'beer': {'bid': 3466636,
#       'beer_name': 'Pickle Gose',
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'Sour - Other',
#       'beer_abv': 4.5,
#       'beer_ibu': 8,
#       'beer_slug': 'two-docs-brewing-co-pickle-gose',
#       'beer_description': '',
#       'is_in_production': 1,
#       'created_at': 'Sat, 05 Oct 2019 13:57:57 +0000',
#       'user_rating_score': 0,
#       'rating_score': 3.825,
#       'rating_count': 10,
#       'on_list': False,
#       'auth_rating': 0,
#       'wish_list': False},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'friends': {'items': [], 'count': 0}},
#     {'total_user_count': 0,
#      'has_had': None,
#      'total_count': 10,
#      'beer': {'bid': 3488043,
#       'beer_name': 'Brunch Bock',
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'Bock - Single / Traditional',
#       'beer_abv': 5.4,
#       'beer_ibu': 19,
#       'beer_slug': 'two-docs-brewing-co-brunch-bock',
#       'beer_description': '',
#       'is_in_production': 1,
#       'created_at': 'Fri, 18 Oct 2019 23:05:45 +0000',
#       'user_rating_score': 0,
#       'rating_score': 0,
#       'rating_count': 7,
#       'on_list': False,
#       'auth_rating': 0,
#       'wish_list': False},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'friends': {'items': [], 'count': 0}},
#     {'total_user_count': 0,
#      'has_had': None,
#      'total_count': 4,
#      'beer': {'bid': 3432355,
#       'beer_name': 'Ruby Red Grapefruit Shandy',
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'Shandy / Radler',
#       'beer_abv': 4,
#       'beer_ibu': 0,
#       'beer_slug': 'two-docs-brewing-co-ruby-red-grapefruit-shandy',
#       'beer_description': '',
#       'is_in_production': 1,
#       'created_at': 'Sat, 14 Sep 2019 13:52:35 +0000',
#       'user_rating_score': 0,
#       'rating_score': 0,
#       'rating_count': 4,
#       'on_list': False,
#       'auth_rating': 0,
#       'wish_list': False},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'friends': {'items': [], 'count': 0}},
#     {'total_user_count': 0,
#      'has_had': None,
#      'total_count': 3,
#      'beer': {'bid': 3412130,
#       'beer_name': 'Game Day IPA',
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'IPA - American',
#       'beer_abv': 0,
#       'beer_ibu': 0,
#       'beer_slug': 'two-docs-brewing-co-game-day-ipa',
#       'beer_description': '',
#       'is_in_production': 1,
#       'created_at': 'Sat, 31 Aug 2019 23:28:45 +0000',
#       'user_rating_score': 0,
#       'rating_score': 0,
#       'rating_count': 3,
#       'on_list': False,
#       'auth_rating': 0,
#       'wish_list': False},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'friends': {'items': [], 'count': 0}},
#     {'total_user_count': 0,
#      'has_had': None,
#      'total_count': 3,
#      'beer': {'bid': 3453729,
#       'beer_name': 'BlackBerry Gose',
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'Sour - Gose - Fruited',
#       'beer_abv': 4.5,
#       'beer_ibu': 8,
#       'beer_slug': 'two-docs-brewing-co-blackberry-gose',
#       'beer_description': '',
#       'is_in_production': 1,
#       'created_at': 'Fri, 27 Sep 2019 21:42:07 +0000',
#       'user_rating_score': 0,
#       'rating_score': 0,
#       'rating_count': 2,
#       'on_list': False,
#       'auth_rating': 0,
#       'wish_list': False},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'friends': {'items': [], 'count': 0}},
#     {'total_user_count': 0,
#      'has_had': None,
#      'total_count': 1,
#      'beer': {'bid': 3500094,
#       'beer_name': 'Prairie Dog Porter - Mexican Cocoa',
#       'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#       'beer_style': 'Porter - Other',
#       'beer_abv': 0,
#       'beer_ibu': 0,
#       'beer_slug': 'two-docs-brewing-co-prairie-dog-porter-mexican-cocoa',
#       'beer_description': 'Two Docs Prairie Dog Porter infused with Mexican Cocoa. Extremely limited release. Oct. 25, 2019',
#       'is_in_production': 1,
#       'created_at': 'Sat, 26 Oct 2019 04:12:03 +0000',
#       'user_rating_score': 0,
#       'rating_score': 0,
#       'rating_count': 1,
#       'on_list': False,
#       'auth_rating': 0,
#       'wish_list': False},
#      'brewery': {'brewery_id': 420745,
#       'brewery_name': 'Two Docs Brewing Co.',
#       'brewery_slug': 'two-docs-brewing',
#       'brewery_page_url': '/TwoDocsBrewingCo',
#       'brewery_type': 'Micro Brewery',
#       'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#       'country_name': 'United States',
#       'contact': {'twitter': '',
#        'facebook': 'https://www.facebook.com/twodocsbrewing',
#        'instagram': 'twodocsbrewing',
#        'url': 'https://twodocsbrewing.com/'},
#       'location': {'brewery_city': 'Lubbock',
#        'brewery_state': 'TX',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'brewery_active': 1},
#      'friends': {'items': [], 'count': 0}}],
#    'collaborations': {'count': 0, 'items': []},
#    'sort_name': 'Most Popular',
#    'sort_key': 'most_popular'},
#   'locations': {'count': 1,
#    'items': [{'venue': {'venue_id': 8707470,
#       'venue_name': 'Two Docs Brewing Co.',
#       'venue_slug': 'two-docs-brewing-co',
#       'primary_category_key': 'Nightlife Spot',
#       'primary_category': 'Nightlife Spot',
#       'parent_category_id': '4d4b7105d754a06376d81259',
#       'categories': {'count': 1,
#        'items': [{'category_key': 'brewery',
#          'category_name': 'Brewery',
#          'category_id': '50327c8591d4c4b30a586d5d',
#          'is_primary': True}]},
#       'location': {'venue_address': '502 Texas Ave',
#        'venue_city': 'Lubbock',
#        'venue_state': 'TX',
#        'venue_country': 'United States',
#        'lat': 33.5909,
#        'lng': -101.846},
#       'contact': {'twitter': '', 'venue_url': 'https://twodocsbrewing.com/'},
#       'foursquare': {'foursquare_id': '5c70ac3d86f4cc00397b6c66',
#        'foursquare_url': 'https://4sq.com/2IJTFbR'},
#       'venue_icon': {'sm': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_64.png',
#        'md': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_88.png',
#        'lg': 'https://untappd.akamaized.net/venuelogos/venue_8707470_59435909_bg_176.png?v=1'},
#       'is_verified': True}}]}}}
# Completed on  2019-10-31 17:57:39.599953

# %%
from uszipcode import SearchEngine

for brewery in brewery_parsed:
    if abs(brewery["brewery_lat"]) > 0 and abs(brewery["brewery_lng"]) > 0:
        search = SearchEngine(simple_zipcode=False)
        result = search.by_coordinates(brewery["brewery_lat"],brewery["brewery_lng"], radius=30, returns=1)
        result = result[0].to_dict()
        display( {
            "brewery_city":brewery["brewery_city"],
            "major_city":result["major_city"],
            "state":result["state"],
            "zipcode":result["zipcode"]
        } )
# Out:
# {'brewery_city': 'Cashmere',
#  'major_city': 'Cashmere',
#  'state': 'WA',
#  'zipcode': '98815'}
# {'brewery_city': 'Lubbock',
#  'major_city': 'Lubbock',
#  'state': 'TX',
#  'zipcode': '79401'}
# {'brewery_city': 'Farmers Branch',
#  'major_city': 'Dallas',
#  'state': 'TX',
#  'zipcode': '75234'}
# {'brewery_city': 'Austin',
#  'major_city': 'Austin',
#  'state': 'TX',
#  'zipcode': '78704'}
# {'brewery_city': 'Houston',
#  'major_city': 'Houston',
#  'state': 'TX',
#  'zipcode': '77003'}
# {'brewery_city': 'San Antonio',
#  'major_city': 'San Antonio',
#  'state': 'TX',
#  'zipcode': '78215'}
# {'brewery_city': 'San Marcos',
#  'major_city': 'Martindale',
#  'state': 'TX',
#  'zipcode': '78655'}
# {'brewery_city': 'Denton',
#  'major_city': 'Denton',
#  'state': 'TX',
#  'zipcode': '76201'}
# {'brewery_city': 'Athens',
#  'major_city': 'Athens',
#  'state': 'TX',
#  'zipcode': '75752'}
# {'brewery_city': 'Austin',
#  'major_city': 'Austin',
#  'state': 'TX',
#  'zipcode': '78758'}
# {'brewery_city': 'Sulphur Springs',
#  'major_city': 'Sulphur Springs',
#  'state': 'TX',
#  'zipcode': '75482'}
# {'brewery_city': 'Marble Falls',
#  'major_city': 'Marble Falls',
#  'state': 'TX',
#  'zipcode': '78654'}
# {'brewery_city': 'Addison',
#  'major_city': 'Addison',
#  'state': 'TX',
#  'zipcode': '75001'}
# {'brewery_city': 'Round Rock',
#  'major_city': 'Round Rock',
#  'state': 'TX',
#  'zipcode': '78664'}
# {'brewery_city': 'Waco',
#  'major_city': 'Waco',
#  'state': 'TX',
#  'zipcode': '76704'}
# {'brewery_city': 'Waco',
#  'major_city': 'Waco',
#  'state': 'TX',
#  'zipcode': '76701'}
# {'brewery_city': 'Liberty Hill',
#  'major_city': 'Liberty Hill',
#  'state': 'TX',
#  'zipcode': '78642'}
# {'brewery_city': 'Austin',
#  'major_city': 'Austin',
#  'state': 'TX',
#  'zipcode': '78758'}
# {'brewery_city': 'Dallas',
#  'major_city': 'Dallas',
#  'state': 'TX',
#  'zipcode': '75207'}
# {'brewery_city': 'Winnsboro',
#  'major_city': 'Winnsboro',
#  'state': 'TX',
#  'zipcode': '75494'}
# {'brewery_city': 'Dallas',
#  'major_city': 'Dallas',
#  'state': 'TX',
#  'zipcode': '75226'}
# {'brewery_city': 'Mansfield',
#  'major_city': 'Mansfield',
#  'state': 'TX',
#  'zipcode': '76063'}
# {'brewery_city': 'Midland',
#  'major_city': 'Midland',
#  'state': 'TX',
#  'zipcode': '79701'}
# {'brewery_city': 'Weatherford',
#  'major_city': 'Weatherford',
#  'state': 'TX',
#  'zipcode': '76086'}
# {'brewery_city': 'Richardson',
#  'major_city': 'Richardson',
#  'state': 'TX',
#  'zipcode': '75081'}
# {'brewery_city': 'Dallas',
#  'major_city': 'Dallas',
#  'state': 'TX',
#  'zipcode': '75202'}
# {'brewery_city': 'McKinney',
#  'major_city': 'Mckinney',
#  'state': 'TX',
#  'zipcode': '75069'}
# {'brewery_city': 'Austin',
#  'major_city': 'Austin',
#  'state': 'TX',
#  'zipcode': '78733'}
# {'brewery_city': 'Richmond',
#  'major_city': 'Richmond',
#  'state': 'TX',
#  'zipcode': '77407'}
# {'brewery_city': 'Dickinson',
#  'major_city': 'Dickinson',
#  'state': 'TX',
#  'zipcode': '77539'}
# {'brewery_city': 'Gilmer',
#  'major_city': 'Gilmer',
#  'state': 'TX',
#  'zipcode': '75645'}
# {'brewery_city': 'Goliad',
#  'major_city': 'Goliad',
#  'state': 'TX',
#  'zipcode': '77963'}
# {'brewery_city': 'Cedar Park',
#  'major_city': 'Leander',
#  'state': 'TX',
#  'zipcode': '78641'}
# {'brewery_city': 'San Antonio',
#  'major_city': 'San Antonio',
#  'state': 'TX',
#  'zipcode': '78204'}
# {'brewery_city': 'Houston',
#  'major_city': 'Houston',
#  'state': 'TX',
#  'zipcode': '77201'}
# {'brewery_city': 'Grapevine',
#  'major_city': 'Grapevine',
#  'state': 'TX',
#  'zipcode': '76051'}
# {'brewery_city': 'Fort Worth',
#  'major_city': 'Fort Worth',
#  'state': 'TX',
#  'zipcode': '76104'}
# {'brewery_city': 'Austin',
#  'major_city': 'Austin',
#  'state': 'TX',
#  'zipcode': '78741'}
# {'brewery_city': 'Denison',
#  'major_city': 'Denison',
#  'state': 'TX',
#  'zipcode': '75020'}
# {'brewery_city': 'Garland',
#  'major_city': 'Dallas',
#  'state': 'TX',
#  'zipcode': '75238'}
# {'brewery_city': 'Greenville',
#  'major_city': 'Greenville',
#  'state': 'TX',
#  'zipcode': '75402'}
# {'brewery_city': 'Arlington',
#  'major_city': 'Arlington',
#  'state': 'TX',
#  'zipcode': '76010'}
# {'brewery_city': 'Austin',
#  'major_city': 'Austin',
#  'state': 'TX',
#  'zipcode': '78742'}
# {'brewery_city': 'Magnolia',
#  'major_city': 'Magnolia',
#  'state': 'TX',
#  'zipcode': '77354'}
# {'brewery_city': 'Corpus Christi',
#  'major_city': 'Corpus Christi',
#  'state': 'TX',
#  'zipcode': '78419'}
# {'brewery_city': 'Fort Worth',
#  'major_city': 'Fort Worth',
#  'state': 'TX',
#  'zipcode': '76102'}
# {'brewery_city': 'College Station',
#  'major_city': 'College Station',
#  'state': 'TX',
#  'zipcode': '77840'}
# {'brewery_city': 'Yuma',
#  'major_city': 'Yuma',
#  'state': 'CO',
#  'zipcode': '80759'}
# {'brewery_city': 'Artesia',
#  'major_city': 'Lake Arthur',
#  'state': 'NM',
#  'zipcode': '88253'}
# {'brewery_city': 'Dallas',
#  'major_city': 'Dallas',
#  'state': 'TX',
#  'zipcode': '75238'}
# {'brewery_city': 'Lewisville',
#  'major_city': 'Lewisville',
#  'state': 'TX',
#  'zipcode': '75057'}
# {'brewery_city': 'Austin',
#  'major_city': 'Austin',
#  'state': 'TX',
#  'zipcode': '78701'}
# {'brewery_city': 'Longmont',
#  'major_city': 'Longmont',
#  'state': 'CO',
#  'zipcode': '80501'}
# {'brewery_city': 'Dallas',
#  'major_city': 'Dallas',
#  'state': 'TX',
#  'zipcode': '75219'}
# {'brewery_city': 'Dallas',
#  'major_city': 'Dallas',
#  'state': 'TX',
#  'zipcode': '75219'}
# {'brewery_city': 'Fort Worth',
#  'major_city': 'Fort Worth',
#  'state': 'TX',
#  'zipcode': '76104'}
# {'brewery_city': 'Fairport',
#  'major_city': 'Fairport',
#  'state': 'NY',
#  'zipcode': '14450'}
# {'brewery_city': 'San Antonio',
#  'major_city': 'San Antonio',
#  'state': 'TX',
#  'zipcode': '78239'}
# {'brewery_city': 'Blanco',
#  'major_city': 'Blanco',
#  'state': 'TX',
#  'zipcode': '78606'}
# {'brewery_city': 'Granbury',
#  'major_city': 'Granbury',
#  'state': 'TX',
#  'zipcode': '76049'}
# {'brewery_city': 'Houston',
#  'major_city': 'Houston',
#  'state': 'TX',
#  'zipcode': '77201'}
# {'brewery_city': 'Houston',
#  'major_city': 'Houston',
#  'state': 'TX',
#  'zipcode': '77201'}
# {'brewery_city': 'Conroe',
#  'major_city': 'Conroe',
#  'state': 'TX',
#  'zipcode': '77301'}
# {'brewery_city': 'Dallas',
#  'major_city': 'Dallas',
#  'state': 'TX',
#  'zipcode': '75207'}
# {'brewery_city': 'Lubbock',
#  'major_city': 'Lubbock',
#  'state': 'TX',
#  'zipcode': '79416'}
# {'brewery_city': 'Austin',
#  'major_city': 'Austin',
#  'state': 'TX',
#  'zipcode': '78737'}
# {'brewery_city': 'Tyler',
#  'major_city': 'Tyler',
#  'state': 'TX',
#  'zipcode': '75701'}
# {'brewery_city': 'McKinney',
#  'major_city': 'Mckinney',
#  'state': 'TX',
#  'zipcode': '75069'}
# {'brewery_city': 'Dripping Springs',
#  'major_city': 'Dripping Springs',
#  'state': 'TX',
#  'zipcode': '78620'}
# {'brewery_city': 'Katy',
#  'major_city': 'Katy',
#  'state': 'TX',
#  'zipcode': '77494'}
# {'brewery_city': 'Tomball',
#  'major_city': 'Houston',
#  'state': 'TX',
#  'zipcode': '77070'}
# {'brewery_city': 'Galveston',
#  'major_city': 'Galveston',
#  'state': 'TX',
#  'zipcode': '77550'}
# {'brewery_city': 'Pharr',
#  'major_city': 'Pharr',
#  'state': 'TX',
#  'zipcode': '78577'}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-54-3878a3d74b1a> in <module>
#       5         search = SearchEngine(simple_zipcode=False)
#       6         result = search.by_coordinates(brewery["brewery_lat"],brewery["brewery_lng"], radius=30, returns=1)
# ----> 7         result = result[0].to_dict()
#       8         display( {
#       9             "brewery_city":brewery["brewery_city"],
#
# IndexError: list index out of range

# %%
all_breweries
# Out:
# [{'Name': '111 Brewing',
#   'Street Address': 111,
#   'Road': 'S FANNIN AVENUE',
#   'City': 'DENISON',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '4/10/2019',
#   'Status': 'In the works',
#   'untappd': [{'brewery': {'brewery_id': 66888,
#      'beer_count': 65,
#      'brewery_name': 'Milepost 111 Brewing Company',
#      'brewery_slug': 'milepost-111-brewing-company',
#      'brewery_page_url': '/milepostbeer',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-Milepost111_66888_590e6.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Cashmere',
#       'brewery_state': 'WA',
#       'lat': 47.5244,
#       'lng': -120.47}}}]},
#  {'Name': '2 Docs Brewing Co',
#   'Street Address': 502,
#   'Road': 'TEXAS AVENUE',
#   'City': 'LUBBOCK',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '10/5/2018',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 420745,
#      'beer_count': 22,
#      'brewery_name': 'Two Docs Brewing Co.',
#      'brewery_slug': 'two-docs-brewing-co',
#      'brewery_page_url': '/TwoDocsBrewingCo',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-420745_c29c8.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Lubbock',
#       'brewery_state': 'TX',
#       'lat': 33.5909,
#       'lng': -101.846}}}]},
#  {'Name': '3 Nations Brewing',
#   'Street Address': 2405,
#   'Road': 'SQUIRE PLACE SUITE 200',
#   'City': 'FARMERS BRANCH',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '5/6/2015',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 205645,
#      'beer_count': 43,
#      'brewery_name': '3 Nations Brewing',
#      'brewery_slug': '3-nations-brewing',
#      'brewery_page_url': '/3NationsBrewing',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-205645_ed87a.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Farmers Branch',
#       'brewery_state': 'TX',
#       'lat': 32.931,
#       'lng': -96.8983}}}]},
#  {'Name': '4th Tap Brewing Cooperative',
#   'Street Address': 10615,
#   'Road': 'METRIC BOULEVARD',
#   'City': 'AUSTIN',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '4/13/2015',
#   'Status': 'Open',
#   'untappd': [{'no_results': True}]},
#  {'Name': '512 Brewing Company',
#   'Street Address': 407,
#   'Road': "RADAM LANE 'F200'",
#   'City': 'AUSTIN',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '5/20/2008',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 1,
#      'beer_count': 156,
#      'brewery_name': '(512) Brewing Company',
#      'brewery_slug': '512-brewing-company',
#      'brewery_page_url': '/512Brewing',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-1_8ccec.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Austin',
#       'brewery_state': 'TX',
#       'lat': 30.2236,
#       'lng': -97.7697}}}]},
#  {'Name': '8th Wonder Brewery',
#   'Street Address': 2202,
#   'Road': 'DALLAS STREET',
#   'City': 'HOUSTON',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '12/29/2011',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 45113,
#      'beer_count': 157,
#      'brewery_name': '8th Wonder Brewery',
#      'brewery_slug': '8th-wonder-brewery',
#      'brewery_page_url': '/8thWonderBrew',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-45113_1e83d.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Houston',
#       'brewery_state': 'TX',
#       'lat': 29.7492,
#       'lng': -95.3558}}}]},
#  {'Name': 'Alamo Beer',
#   'Street Address': 415,
#   'Road': 'BURNET STREET',
#   'City': 'SAN ANTONIO',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '9/29/2014',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 43137,
#      'beer_count': 69,
#      'brewery_name': 'Alamo Beer Company',
#      'brewery_slug': 'alamo-beer-company',
#      'brewery_page_url': '/AlamoBeerCompany',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-AlamoBeerCompany_43137_c831d.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'San Antonio',
#       'brewery_state': 'TX',
#       'lat': 29.4295,
#       'lng': -98.4773}}}]},
#  {'Name': "Allen's Landing Brewing Company",
#   'Street Address': 3540,
#   'Road': 'OAK FOREST DRIVE',
#   'City': 'HOUSTON',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '1/16/2015',
#   'Status': 'Open',
#   'untappd': [{'no_results': True}]},
#  {'Name': 'Altmeyer & Lewis Brewing Company',
#   'Street Address': 15898,
#   'Road': 'HWY 123 NORTH',
#   'City': 'SAN MARCOS',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '7/16/2015',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 294420,
#      'beer_count': 0,
#      'brewery_name': 'Altmeyer & Lewis Brewing Company',
#      'brewery_slug': 'altmeyer-and-lewis-brewing-company',
#      'brewery_page_url': '/AltLewBrewCo15898',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-294420_1e59b.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'San Marcos',
#       'brewery_state': 'TX',
#       'lat': 29.7874,
#       'lng': -97.9467}}}]},
#  {'Name': 'Armadillo Ale Works',
#   'Street Address': 221,
#   'Road': 'S BELL AVENUE',
#   'City': 'DENTON',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '2/19/2015',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 9316,
#      'beer_count': 28,
#      'brewery_name': 'Armadillo Ale Works™',
#      'brewery_slug': 'armadillo-ale-works',
#      'brewery_page_url': '/ArmadilloAleWorks',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-armadilloaleworks_9316.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Denton',
#       'brewery_state': 'TX',
#       'lat': 33.2126,
#       'lng': -97.1281}}}]},
#  {'Name': 'Athens Brewing Company',
#   'Street Address': 101,
#   'Road': 'E TYLER STREET',
#   'City': 'ATHENS',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '4/18/2016',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 267312,
#      'beer_count': 35,
#      'brewery_name': 'Athens Brewing Company',
#      'brewery_slug': 'athens-brewing-company',
#      'brewery_page_url': '/AthensBrewingCompany',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-267312_92b87.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Athens',
#       'brewery_state': 'TX',
#       'lat': 32.2054,
#       'lng': -95.8538}}}]},
#  {'Name': 'Austin Beerworks',
#   'Street Address': 3009,
#   'Road': 'INDUSTRIAL TERRACE SUITE 150',
#   'City': 'AUSTIN',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '12/30/2010',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 11819,
#      'beer_count': 266,
#      'brewery_name': 'Austin Beerworks',
#      'brewery_slug': 'austin-beerworks',
#      'brewery_page_url': '/austinbeerworks',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-austinbeerworks_11819.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Austin',
#       'brewery_state': 'TX',
#       'lat': 30.3798,
#       'lng': -97.7302}}}]},
#  {'Name': 'Backstory  Brewery',
#   'Street Address': 211,
#   'Road': 'MAGNOLIA STREET',
#   'City': 'SULPHUR SPRINGS',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '10/31/2017',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 393158,
#      'beer_count': 40,
#      'brewery_name': 'BackStory Brewery ',
#      'brewery_slug': 'backstory-brewery',
#      'brewery_page_url': '/BackStoryBrewery',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-393158_c09cc.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Sulphur Springs',
#       'brewery_state': 'TX',
#       'lat': 33.1348,
#       'lng': -95.6048}}}]},
#  {'Name': 'BCS-Zoigl',
#   'Street Address': 211,
#   'Road': 'WILLIAM J BRYAN PARKWAY',
#   'City': 'BRYAN',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '12/1/2016',
#   'Status': 'Open',
#   'untappd': [{'no_results': True}]},
#  {'Name': 'Bear King Brewing Company',
#   'Street Address': 207,
#   'Road': 'AVE G',
#   'City': 'MARBLE FALLS',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '11/28/2018',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 421863,
#      'beer_count': 14,
#      'brewery_name': 'Bear King Brewing Company',
#      'brewery_slug': 'bear-king-brewing-company',
#      'brewery_page_url': '/BearKingBrewing',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-421863_8b2e1.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Marble Falls',
#       'brewery_state': 'TX',
#       'lat': 30.5703,
#       'lng': -98.2749}}}]},
#  {'Name': 'Bell Mountain Vineyards',
#   'Street Address': 463,
#   'Road': 'BELL MOUNTAIN ROAD',
#   'City': 'FREDERICKSBURG',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '1/16/2019',
#   'Status': 'In the works',
#   'untappd': [{'no_results': True}]},
#  {'Name': 'Bell Springs Winery',
#   'Street Address': 3700,
#   'Road': 'BELL SPRINGS ROAD',
#   'City': 'DRIPPING SPRINGS',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '7/25/2018',
#   'Status': 'In the works',
#   'untappd': [{'brewery': {'brewery_id': 399545,
#      'beer_count': 0,
#      'brewery_name': 'Bell Springs Winery',
#      'brewery_slug': 'bell-springs-winery',
#      'brewery_page_url': '/w/bell-springs-winery/399545',
#      'brewery_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-brewery-default.png',
#      'country_name': 'United States',
#      'location': {'brewery_city': '',
#       'brewery_state': '',
#       'lat': 0,
#       'lng': 0}}}]},
#  {'Name': 'Bitter Sisters Brewing Company',
#   'Street Address': 15103,
#   'Road': 'SURVEYOR BOULEVARD',
#   'City': 'ADDISON',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '8/22/2014',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 72194,
#      'beer_count': 41,
#      'brewery_name': 'Bitter Sisters Brewing Company',
#      'brewery_slug': 'bitter-sisters-brewing-company',
#      'brewery_page_url': '/bittersistersbrewery',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-72194_2a5ef.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Addison',
#       'brewery_state': 'TX',
#       'lat': 32.9618,
#       'lng': -96.8292}}}]},
#  {'Name': 'Bluebonnet Beer Company',
#   'Street Address': 1700,
#   'Road': 'BRYANT DRIVE UNIT 107',
#   'City': 'ROUND ROCK',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '4/1/2014',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 168065,
#      'beer_count': 51,
#      'brewery_name': 'Bluebonnet Beer Company',
#      'brewery_slug': 'bluebonnet-beer-company',
#      'brewery_page_url': '/BluebonnetBeerCo',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-168065_83cb2.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Round Rock',
#       'brewery_state': 'TX',
#       'lat': 30.4919,
#       'lng': -97.647}}}]},
#  {'Name': 'Braman Brewery',
#   'Street Address': 3421,
#   'Road': 'FM 359 SUITE B',
#   'City': 'RICHMOND',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '5/4/2015',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 48985,
#      'beer_count': 1,
#      'brewery_name': 'Bratman Brewery (Homebrew)',
#      'brewery_slug': 'bratman-brewery',
#      'brewery_page_url': '/w/bratman-brewery/48985',
#      'brewery_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-brewery-default.png',
#      'country_name': 'United States',
#      'location': {'brewery_city': '',
#       'brewery_state': '',
#       'lat': 0,
#       'lng': 0}}}]},
#  {'Name': 'Brotherwell Brewing',
#   'Street Address': 400,
#   'Road': 'E BRIDGE STREET',
#   'City': 'WACO',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '11/9/2017',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 385504,
#      'beer_count': 14,
#      'brewery_name': 'Brotherwell Brewing',
#      'brewery_slug': 'brotherwell-brewing',
#      'brewery_page_url': '/Brotherwell_Brewing',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-385504_d010d.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Waco',
#       'brewery_state': 'TX',
#       'lat': 31.5645,
#       'lng': -97.1243}}},
#    {'brewery': {'brewery_id': 185400,
#      'beer_count': 0,
#      'brewery_name': 'Brotherwell Brewing Co. (Homebrew)',
#      'brewery_slug': 'brotherwell-brewing-co',
#      'brewery_page_url': '/BrotherwellBrewing',
#      'brewery_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-brewery-default.png',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Waco',
#       'brewery_state': 'TX',
#       'lat': 31.5493,
#       'lng': -97.1467}}}]},
#  {'Name': 'Buffalo Bayou Brewing Company',
#   'Street Address': 2101,
#   'Road': 'SUMMER STREET',
#   'City': 'HOUSTON',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '9/24/2018',
#   'Status': 'Open',
#   'untappd': [{'no_results': True}]},
#  {'Name': 'Bull Creek Brewing',
#   'Street Address': 7100,
#   'Road': 'FM 3405 BUILDING 1',
#   'City': 'LIBERTY HILL',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '3/12/2013',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 208827,
#      'beer_count': 32,
#      'brewery_name': 'Bull Creek Brewing ',
#      'brewery_slug': 'bull-creek-brewing',
#      'brewery_page_url': '/w/bull-creek-brewing/208827',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-208827_030d7.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Liberty Hill',
#       'brewery_state': 'TX',
#       'lat': 30.7052,
#       'lng': -97.8702}}}]},
#  {'Name': 'Celis Brewery',
#   'Street Address': 10001,
#   'Road': 'METRIC BOULEVARD',
#   'City': 'AUSTIN',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '5/15/2017',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 305923,
#      'beer_count': 48,
#      'brewery_name': 'Celis Brewery',
#      'brewery_slug': 'celis-brewery',
#      'brewery_page_url': '/CelisBrewery',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-305923_ba931.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Austin',
#       'brewery_state': 'TX',
#       'lat': 30.3797,
#       'lng': -97.716}}}]},
#  {'Name': 'City Orchard',
#   'Street Address': 1201,
#   'Road': 'OLIVER STREET UNIT 108',
#   'City': 'HOUSTON',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '6/18/2018',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 364659,
#      'beer_count': 1,
#      'brewery_name': 'Orchard City Brewing (Homebrew)',
#      'brewery_slug': 'orchard-city-brewing',
#      'brewery_page_url': '/w/orchard-city-brewing/364659',
#      'brewery_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-brewery-default.png',
#      'country_name': 'United States',
#      'location': {'brewery_city': '',
#       'brewery_state': '',
#       'lat': 0,
#       'lng': 0}}}]},
#  {'Name': 'Comfort Brewing',
#   'Street Address': 523,
#   'Road': '7TH STREET SUITE B',
#   'City': 'COMFORT',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '8/29/2016',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 209165,
#      'beer_count': 24,
#      'brewery_name': 'Cold Comfort Brewing (Homebrew)',
#      'brewery_slug': 'cold-comfort-brewing',
#      'brewery_page_url': '/ColdComfortBrewing',
#      'brewery_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-brewery-default.png',
#      'country_name': 'United States',
#      'location': {'brewery_city': '',
#       'brewery_state': '',
#       'lat': 0,
#       'lng': 0}}},
#    {'brewery': {'brewery_id': 124177,
#      'beer_count': 7,
#      'brewery_name': 'Comfort Brewing Co. (Homebrew)',
#      'brewery_slug': 'comfort-brewing-co',
#      'brewery_page_url': '/w/comfort-brewing-co/124177',
#      'brewery_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-brewery-default.png',
#      'country_name': 'United States',
#      'location': {'brewery_city': '',
#       'brewery_state': '',
#       'lat': 0,
#       'lng': 0}}},
#    {'brewery': {'brewery_id': 321023,
#      'beer_count': 3,
#      'brewery_name': 'Cold Comfort Brewing (Homebrew)',
#      'brewery_slug': 'cold-comfort-brewing',
#      'brewery_page_url': '/w/cold-comfort-brewing/321023',
#      'brewery_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-brewery-default.png',
#      'country_name': 'United States',
#      'location': {'brewery_city': '',
#       'brewery_state': '',
#       'lat': 0,
#       'lng': 0}}}]},
#  {'Name': 'Community Beer Company',
#   'Street Address': 1530,
#   'Road': 'INSPIRATION DRIVE SUITE 200',
#   'City': 'DALLAS',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '2/1/2013',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 48372,
#      'beer_count': 213,
#      'brewery_name': 'Community Beer Company',
#      'brewery_slug': 'community-beer-company',
#      'brewery_page_url': '/CommunityBeerCompanyTexas',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-48372_9a99a.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Dallas',
#       'brewery_state': 'TX',
#       'lat': 32.7909,
#       'lng': -96.8158}}},
#    {'brewery': {'brewery_id': 259927,
#      'beer_count': 1,
#      'brewery_name': 'The Community Beer Company',
#      'brewery_slug': 'the-community-beer-company',
#      'brewery_page_url': '/w/the-community-beer-company/259927',
#      'brewery_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-brewery-default.png',
#      'country_name': 'United States',
#      'location': {'brewery_city': '',
#       'brewery_state': '',
#       'lat': 0,
#       'lng': 0}}}]},
#  {'Name': 'Cypress Creek Southern Ales',
#   'Street Address': 200,
#   'Road': 'E CARNEGIE STREET',
#   'City': 'WINNSBORO',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '8/18/2017',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 340519,
#      'beer_count': 47,
#      'brewery_name': 'Cypress Creek Southern Ales',
#      'brewery_slug': 'cypress-creek-southern-ales',
#      'brewery_page_url': '/CypressCreekSouthernAles',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-340519_df9bc.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Winnsboro',
#       'brewery_state': 'TX',
#       'lat': 32.9558,
#       'lng': -95.2895}}}]},
#  {'Name': 'Deep Ellum Barrel House',
#   'Street Address': 2825,
#   'Road': 'CANTON STREET',
#   'City': 'DALLAS',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '4/18/2016',
#   'Status': 'In the works',
#   'untappd': [{'no_results': True}]},
#  {'Name': 'Deep Ellum Brewing Company',
#   'Street Address': 2823,
#   'Road': 'SAINT LOUIS STREET',
#   'City': 'DALLAS',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '3/17/2017',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 11028,
#      'beer_count': 65,
#      'brewery_name': 'Deep Ellum Brewing Company',
#      'brewery_slug': 'deep-ellum-brewing-company',
#      'brewery_page_url': '/DEBC',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-DeepEllumBrewingCompany_11028.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Dallas',
#       'brewery_state': 'TX',
#       'lat': 32.7808,
#       'lng': -96.7817}}}]},
#  {'Name': 'Deep Ellum FTW',
#   'Street Address': 611,
#   'Road': 'UNIVERSITY DRIVE',
#   'City': 'FORT WORTH',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '9/5/2018',
#   'Status': 'Open',
#   'untappd': [{'no_results': True}]},
#  {'Name': 'Dej Buh Stesti Brewing Company',
#   'Street Address': 1328,
#   'Road': 'FM 2915',
#   'City': 'LOVELADY',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '1/8/2016',
#   'Status': 'Open',
#   'untappd': [{'no_results': True}]},
#  {'Name': 'Dirty Job Brewing',
#   'Street Address': 117,
#   'Road': 'N MAIN STREET',
#   'City': 'MANSFIELD',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '5/4/2017',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 226688,
#      'beer_count': 51,
#      'brewery_name': 'Dirty Job Brewing',
#      'brewery_slug': 'dirty-job-brewing',
#      'brewery_page_url': '/DirtyJobBrewing',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-226688_99089.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Mansfield',
#       'brewery_state': 'TX',
#       'lat': 32.5643,
#       'lng': -97.1422}}}]},
#  {'Name': 'DJ Vineyards',
#   'Street Address': 4064,
#   'Road': 'HWY 290W BUILDING B',
#   'City': 'JOHNSON CITY',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '9/19/2017',
#   'Status': 'In the works',
#   'untappd': [{'no_results': True}]},
#  {'Name': 'Eccentric Brewing Company',
#   'Street Address': 1402,
#   'Road': 'COTTON FLAT ROAD',
#   'City': 'MIDLAND',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '5/4/2018',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 399986,
#      'beer_count': 16,
#      'brewery_name': 'Eccentric Brewing Company',
#      'brewery_slug': 'eccentric-brewing-company',
#      'brewery_page_url': '/EccentricBrewingCompany',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-399986_1930a.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Midland',
#       'brewery_state': 'TX',
#       'lat': 31.9803,
#       'lng': -102.095}}}]},
#  {'Name': 'Edgewise Eight Brewing',
#   'Street Address': 6488,
#   'Road': 'FM 920',
#   'City': 'WEATHERFORD',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '10/17/2018',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 358992,
#      'beer_count': 24,
#      'brewery_name': 'Edgewise Eight Brewing',
#      'brewery_slug': 'edgewise-eight-brewing',
#      'brewery_page_url': '/EdgewiseEight',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-358992_39020.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Weatherford',
#       'brewery_state': 'TX',
#       'lat': 32.7593,
#       'lng': -97.7973}}}]},
#  {'Name': 'Four Bullets Brewery',
#   'Street Address': 640,
#   'Road': 'N INTERURBAN STREET',
#   'City': 'RICHARDSON',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '10/7/2014',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 48543,
#      'beer_count': 22,
#      'brewery_name': 'Four Bullets Brewery',
#      'brewery_slug': 'four-bullets-brewery',
#      'brewery_page_url': '/FourBullets',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-48543_bd6e7.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Richardson',
#       'brewery_state': 'TX',
#       'lat': 32.9592,
#       'lng': -96.7261}}}]},
#  {'Name': 'Four Corners Brewing Co.',
#   'Street Address': 1311,
#   'Road': 'S ERVAY',
#   'City': 'DALLAS',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '5/15/2017',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 29815,
#      'beer_count': 133,
#      'brewery_name': 'Four Corners Brewing Company',
#      'brewery_slug': 'four-corners-brewing-company',
#      'brewery_page_url': '/fcbrewing',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-FourCorners_29815.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Dallas',
#       'brewery_state': 'TX',
#       'lat': 32.772,
#       'lng': -96.7918}}}]},
#  {'Name': 'Franconia Brewing Company',
#   'Street Address': 495,
#   'Road': 'MCKINNEY PARKWAY',
#   'City': 'MCKINNEY',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '1/23/2008',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 7329,
#      'beer_count': 79,
#      'brewery_name': 'Franconia Brewing Company ',
#      'brewery_slug': 'franconia-brewing-company',
#      'brewery_page_url': '/FranconiaBrewingCompany',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-FranconiaBrewingCompany_7329.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'McKinney',
#       'brewery_state': 'TX',
#       'lat': 33.2134,
#       'lng': -96.6091}}}]},
#  {'Name': 'Friends And Allies Brewing Company',
#   'Street Address': 979,
#   'Road': 'SPRINGDALE ROAD UNIT 124',
#   'City': 'AUSTIN',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '5/26/2016',
#   'Status': 'Open',
#   'untappd': [{'no_results': True}]},
#  {'Name': 'Frontyard Brewing',
#   'Street Address': 1607,
#   'Road': 'N CUERNAVACA DRIVE UNIT 202',
#   'City': 'AUSTIN',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '5/8/2017',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 383520,
#      'beer_count': 6,
#      'brewery_name': 'Frontyard Brewing',
#      'brewery_slug': 'frontyard-brewing',
#      'brewery_page_url': '/FrontyardBrewing',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-383520_1168a.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Austin',
#       'brewery_state': 'TX',
#       'lat': 30.3394,
#       'lng': -97.8634}}},
#    {'brewery': {'brewery_id': 84693,
#      'beer_count': 32,
#      'brewery_name': "Matson's Front Yard Brewing (Homebrew)",
#      'brewery_slug': 'matsons-front-yard-brewing',
#      'brewery_page_url': '/w/matson-s-front-yard-brewing/84693',
#      'brewery_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-brewery-default.png',
#      'country_name': 'United States',
#      'location': {'brewery_city': '',
#       'brewery_state': '',
#       'lat': 0,
#       'lng': 0}}}]},
#  {'Name': 'Fulbrook Ale Works',
#   'Street Address': 1125,
#   'Road': 'FM 359',
#   'City': 'RICHMOND',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '11/17/2017',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 375720,
#      'beer_count': 38,
#      'brewery_name': 'Fulbrook Ale Works',
#      'brewery_slug': 'fulbrook-ale-works',
#      'brewery_page_url': '/w/fulbrook-ale-works/375720',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-375720_3d87c.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Richmond',
#       'brewery_state': 'TX',
#       'lat': 29.6119,
#       'lng': -95.7438}}}]},
#  {'Name': 'Galveston Bay Beer Company',
#   'Street Address': 12900,
#   'Road': 'FM 3436',
#   'City': 'TEXAS CITY',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '8/12/2014',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 173145,
#      'beer_count': 90,
#      'brewery_name': 'Galveston Bay Beer Company',
#      'brewery_slug': 'galveston-bay-beer-company',
#      'brewery_page_url': '/GalvestonBayBeer',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-173145_32604.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Dickinson',
#       'brewery_state': 'TX',
#       'lat': 29.4836,
#       'lng': -95.0086}}}]},
#  {'Name': 'Gilmer Brewing Company',
#   'Street Address': 101,
#   'Road': 'W TYLER STREET',
#   'City': 'GILMER',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '9/6/2018',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 372138,
#      'beer_count': 9,
#      'brewery_name': 'Gilmer Brewing Company',
#      'brewery_slug': 'gilmer-brewing-company',
#      'brewery_page_url': '/GilmerBrewingCompany',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-372138_62934.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Gilmer',
#       'brewery_state': 'TX',
#       'lat': 32.7285,
#       'lng': -94.9447}}}]},
#  {'Name': 'Goliad Brewing Company',
#   'Street Address': 252,
#   'Road': 'METTING ROAD',
#   'City': 'GOLIAD',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '12/10/2013',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 113303,
#      'beer_count': 18,
#      'brewery_name': 'Goliad Brewing Company',
#      'brewery_slug': 'goliad-brewing-company',
#      'brewery_page_url': '/GoliadBrewingCompany',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-113303_c4d9e.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Goliad',
#       'brewery_state': 'TX',
#       'lat': 28.6683,
#       'lng': -97.3883}}}]},
#  {'Name': 'Gulf Coast Distillers',
#   'Street Address': 5610,
#   'Road': 'CLINTON DRIVE',
#   'City': 'HOUSTON',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '12/7/2018',
#   'Status': 'In the works',
#   'untappd': [{'no_results': True}]},
#  {'Name': 'Hedgehog Brewing',
#   'Street Address': 3200,
#   'Road': 'WOODALL DRIVE UNIT C-1',
#   'City': 'CEDAR PARK',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '1/23/2019',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 427843,
#      'beer_count': 3,
#      'brewery_name': 'Hedgehog Brewing',
#      'brewery_slug': 'hedgehog-brewing',
#      'brewery_page_url': '/HedgehogBrewing',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-427843_514e0.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Cedar Park',
#       'brewery_state': 'TX',
#       'lat': 30.5149,
#       'lng': -97.877}}},
#    {'brewery': {'brewery_id': 311640,
#      'beer_count': 4,
#      'brewery_name': 'Crazy Hedgehog Brewing (Homebrew)',
#      'brewery_slug': 'crazy-hedgehog-brewing',
#      'brewery_page_url': '/w/crazy-hedgehog-brewing/311640',
#      'brewery_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-brewery-default.png',
#      'country_name': 'Finland',
#      'location': {'brewery_city': '',
#       'brewery_state': '',
#       'lat': 0,
#       'lng': 0}}},
#    {'brewery': {'brewery_id': 135747,
#      'beer_count': 3,
#      'brewery_name': 'Cat And Hedgehog Brewing Co.  (Homebrew)',
#      'brewery_slug': 'cat-and-hedgehog-brewing-co',
#      'brewery_page_url': '/w/cat-and-hedgehog-brewing-co/135747',
#      'brewery_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-brewery-default.png',
#      'country_name': 'United States',
#      'location': {'brewery_city': '',
#       'brewery_state': '',
#       'lat': 0,
#       'lng': 0}}}]},
#  {'Name': 'Hemisphere Brewing Co.',
#   'Street Address': 2015,
#   'Road': 'KRISTY LANE',
#   'City': 'ROCKWALL',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '6/1/2016',
#   'Status': 'Open',
#   'untappd': [{'no_results': True}]},
#  {'Name': 'Highwheel Brewing',
#   'Street Address': 1902,
#   'Road': 'S FLORES STREET',
#   'City': 'SAN ANTONIO',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '9/24/2015',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 292601,
#      'beer_count': 27,
#      'brewery_name': 'Dorćol Distilling + Brewing Co.',
#      'brewery_slug': 'dorcol-distilling-brewing-co',
#      'brewery_page_url': '/Highwheel',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-292601_840fd.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'San Antonio',
#       'brewery_state': 'TX',
#       'lat': 29.4057,
#       'lng': -98.5023}}},
#    {'brewery': {'brewery_id': 194689,
#      'beer_count': 15,
#      'brewery_name': 'High Wheel Brewing (Homebrew)',
#      'brewery_slug': 'high-wheel-brewing',
#      'brewery_page_url': '/HighwheelBrewing',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-194689_6811d.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': '',
#       'brewery_state': '',
#       'lat': 0,
#       'lng': 0}}}]},
#  {'Name': 'Holler Brewing',
#   'Street Address': 2206,
#   'Road': 'EDWARDS STREET SUITE A',
#   'City': 'HOUSTON',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '9/8/2015',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 270322,
#      'beer_count': 114,
#      'brewery_name': 'Holler Brewing Co.',
#      'brewery_slug': 'holler-brewing-co',
#      'brewery_page_url': '/Hollerbeer',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-270322_d9976.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Houston',
#       'brewery_state': 'TX',
#       'lat': 29.7708,
#       'lng': -95.3803}}},
#    {'brewery': {'brewery_id': 105092,
#      'beer_count': 3,
#      'brewery_name': "Hoot 'n' Holler Brewing Co. (Homebrew)",
#      'brewery_slug': 'hoot-n-holler-brewing-co',
#      'brewery_page_url': '/w/hoot-n-holler-brewing-co/105092',
#      'brewery_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-brewery-default.png',
#      'country_name': 'United States',
#      'location': {'brewery_city': '',
#       'brewery_state': '',
#       'lat': 0,
#       'lng': 0}}},
#    {'brewery': {'brewery_id': 189923,
#      'beer_count': 2,
#      'brewery_name': 'Slaughter Holler Brewing (Homebrew)',
#      'brewery_slug': 'slaughter-holler-brewing',
#      'brewery_page_url': '/w/slaughter-holler-brewing/189923',
#      'brewery_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-brewery-default.png',
#      'country_name': 'United States',
#      'location': {'brewery_city': '',
#       'brewery_state': '',
#       'lat': 0,
#       'lng': 0}}}]},
#  {'Name': 'Hop And Sting Brewing Company',
#   'Street Address': 906,
#   'Road': 'JEAN STREET',
#   'City': 'GRAPEVINE',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '10/24/2017',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 330503,
#      'beer_count': 44,
#      'brewery_name': 'Hop And Sting Brewing Company',
#      'brewery_slug': 'hop-and-sting-brewing-company',
#      'brewery_page_url': '/HopAndSting',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-330503_255ce.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Grapevine',
#       'brewery_state': 'TX',
#       'lat': 32.9326,
#       'lng': -97.0748}}}]},
#  {'Name': 'Hopfusion Ale Works',
#   'Street Address': 200,
#   'Road': 'E BROADWAY AVENUE',
#   'City': 'FORT WORTH',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '1/29/2016',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 197427,
#      'beer_count': 91,
#      'brewery_name': 'HopFusion Ale Works',
#      'brewery_slug': 'hopfusion-ale-works',
#      'brewery_page_url': '/HopFusionAleWorks',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-197427_a5419.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Fort Worth',
#       'brewery_state': 'TX',
#       'lat': 32.7416,
#       'lng': -97.3247}}}]},
#  {'Name': 'Independence Brewing Co.',
#   'Street Address': 3913,
#   'Road': 'TODD LN #607',
#   'City': 'AUSTIN',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '9/22/2004',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 2252,
#      'beer_count': 25,
#      'brewery_name': 'Independence Brewing Co.',
#      'brewery_slug': 'independence-brewing-co',
#      'brewery_page_url': '/indybrewing',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-2252_e7e1d.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Austin',
#       'brewery_state': 'TX',
#       'lat': 30.2131,
#       'lng': -97.7358}}}]},
#  {'Name': 'Ivanhoe Ale Works',
#   'Street Address': 220,
#   'Road': 'W MAIN STREET',
#   'City': 'DENISON',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '1/2/2015',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 204652,
#      'beer_count': 19,
#      'brewery_name': 'Ivanhoe Ale Works',
#      'brewery_slug': 'ivanhoe-ale-works',
#      'brewery_page_url': '/IvanhoeAleWorks',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-204652_68fd4.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Denison',
#       'brewery_state': 'TX',
#       'lat': 33.7551,
#       'lng': -96.5378}}}]},
#  {'Name': 'Karbach Brewing Company',
#   'Street Address': 2032,
#   'Road': 'KARBACH STREET',
#   'City': 'HOUSTON',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '3/7/2011',
#   'Status': 'Open',
#   'untappd': [{'no_results': True}]},
#  {'Name': 'Lake Austin Ales (Operating in Celis)',
#   'Street Address': 9705,
#   'Road': 'BURNET ROAD SUITE 612',
#   'City': 'AUSTIN',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '5/4/2015',
#   'Status': 'Open',
#   'untappd': [{'no_results': True}]},
#  {'Name': 'Lakewood Brewing Company',
#   'Street Address': 2302,
#   'Road': 'EXECUTIVE DRIVE',
#   'City': 'GARLAND',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '5/1/2012',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 11862,
#      'beer_count': 90,
#      'brewery_name': 'Lakewood Brewing Company',
#      'brewery_slug': 'lakewood-brewing-company',
#      'brewery_page_url': '/lakewoodbrewing',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-11862_b9a46.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Garland',
#       'brewery_state': 'TX',
#       'lat': 32.8899,
#       'lng': -96.6809}}}]},
#  {'Name': 'Landon Winery',
#   'Street Address': 2400,
#   'Road': 'JOHNSON STREET',
#   'City': 'GREENVILLE',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '3/9/2017',
#   'Status': 'In the works',
#   'untappd': [{'brewery': {'brewery_id': 356910,
#      'beer_count': 5,
#      'brewery_name': 'Landon Winery',
#      'brewery_slug': 'landon-winery',
#      'brewery_page_url': '/w/landon-winery/356910',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-356910_838c0.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Greenville',
#       'brewery_state': 'TX',
#       'lat': 33.1401,
#       'lng': -96.1067}}}]},
#  {'Name': 'Legal Draft Beer Co.',
#   'Street Address': 500,
#   'Road': 'E DIVISION STREET',
#   'City': 'ARLINGTON',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '4/1/2016',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 235234,
#      'beer_count': 55,
#      'brewery_name': 'Legal Draft Beer Co.',
#      'brewery_slug': 'legal-draft-beer-co',
#      'brewery_page_url': '/LegalDraftBeerCo',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-235234_144d2.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Arlington',
#       'brewery_state': 'TX',
#       'lat': 32.7382,
#       'lng': -97.1025}}}]},
#  {'Name': 'Live Oak Brewing Company',
#   'Street Address': 1615,
#   'Road': 'CROZIER LANE',
#   'City': 'AUSTIN',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '10/20/2015',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 797,
#      'beer_count': 41,
#      'brewery_name': 'Live Oak Brewing Company',
#      'brewery_slug': 'live-oak-brewing-company',
#      'brewery_page_url': '/LiveOakBrewingCompany',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-LiveOakBrewing_797.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Austin',
#       'brewery_state': 'TX',
#       'lat': 30.22,
#       'lng': -97.6608}}}]},
#  {'Name': 'Lone Pint Brewery',
#   'Street Address': 507,
#   'Road': 'COMMERCE STREET',
#   'City': 'MAGNOLIA',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '9/10/2012',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 47425,
#      'beer_count': 45,
#      'brewery_name': 'Lone Pint Brewery',
#      'brewery_slug': 'lone-pint-brewery',
#      'brewery_page_url': '/LonePintBrewery',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-lonepintbrewery_47425.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Magnolia',
#       'brewery_state': 'TX',
#       'lat': 30.2089,
#       'lng': -95.7514}}}]},
#  {'Name': 'Long Wood Spoon Brewing',
#   'Street Address': 4098,
#   'Road': 'BUSINESS PARK DRIVE',
#   'City': 'AMARILLO',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '6/23/2015',
#   'Status': 'Open',
#   'untappd': [{'no_results': True}]},
#  {'Name': 'Lorelei Brewing Company',
#   'Street Address': 520,
#   'Road': 'NAS DRIVE BUILDING BL002',
#   'City': 'CORPUS CHRISTI',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '11/26/2018',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 249178,
#      'beer_count': 41,
#      'brewery_name': 'Lorelei Brewing Company',
#      'brewery_slug': 'lorelei-brewing-company',
#      'brewery_page_url': '/LoreleiBrewingCompany',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-249178_50e58.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Corpus Christi',
#       'brewery_state': 'TX',
#       'lat': 27.6743,
#       'lng': -97.2793}}}]},
#  {'Name': 'Martin House Brewing Company',
#   'Street Address': 220,
#   'Road': 'S SYLVANIA AVENUE SUITE 209',
#   'City': 'FORT WORTH',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '11/8/2012',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 27621,
#      'beer_count': 447,
#      'brewery_name': 'Martin House Brewing Company',
#      'brewery_slug': 'martin-house-brewing-company',
#      'brewery_page_url': '/martinhousebrewing',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-MartinHouseBrewingCompany_27621.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Fort Worth',
#       'brewery_state': 'TX',
#       'lat': 32.7637,
#       'lng': -97.3098}}}]},
#  {'Name': 'Maverick Brewery',
#   'Street Address': 115,
#   'Road': 'BROADWAY',
#   'City': 'SAN ANTONIO',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '11/5/2018',
#   'Status': 'In the works',
#   'untappd': [{'brewery': {'brewery_id': 302408,
#      'beer_count': 1,
#      'brewery_name': 'Mean Maverick Brewery (Homebrew)',
#      'brewery_slug': 'mean-maverick-brewery',
#      'brewery_page_url': '/w/mean-maverick-brewery/302408',
#      'brewery_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-brewery-default.png',
#      'country_name': 'United States',
#      'location': {'brewery_city': '',
#       'brewery_state': '',
#       'lat': 0,
#       'lng': 0}}}]},
#  {'Name': 'New Republic Brewing Company',
#   'Street Address': 11405,
#   'Road': 'N DOWLING ROAD UNIT C',
#   'City': 'COLLEGE STATION',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '3/16/2011',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 8767,
#      'beer_count': 119,
#      'brewery_name': 'New Republic Brewing Company',
#      'brewery_slug': 'new-republic-brewing-company',
#      'brewery_page_url': '/newrepublicbrewing',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-8767_4ef73.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'College Station',
#       'brewery_state': 'TX',
#       'lat': 30.565,
#       'lng': -96.3501}}}]},
#  {'Name': 'Nine Band Brewing Co',
#   'Street Address': 9,
#   'Road': 'PRESTIGE CIRCLE',
#   'City': 'ALLEN',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '1/26/2018',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 435311,
#      'beer_count': 1,
#      'brewery_name': 'Dragan Brewing & Wine Company',
#      'brewery_slug': 'dragan-brewing-and-wine-company',
#      'brewery_page_url': '/w/dragan-brewing-wine-company/435311',
#      'brewery_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-brewery-default.png',
#      'country_name': 'Canada',
#      'location': {'brewery_city': '',
#       'brewery_state': '',
#       'lat': 0,
#       'lng': 0}}},
#    {'brewery': {'brewery_id': 393699,
#      'beer_count': 7,
#      'brewery_name': 'Tumbleweed Brewing & Wine Co',
#      'brewery_slug': 'tumbleweed-brewing-and-wine-co',
#      'brewery_page_url': '/w/tumbleweed-brewing-wine-co/393699',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-393699_40ea6.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Yuma',
#       'brewery_state': 'CO',
#       'lat': 40.1245,
#       'lng': -102.724}}},
#    {'brewery': {'brewery_id': 151825,
#      'beer_count': 0,
#      'brewery_name': 'Cottonwood Wine and Brewing',
#      'brewery_slug': 'cottonwood-wine-and-brewing',
#      'brewery_page_url': '/w/cottonwood-wine-and-brewing/151825',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-151825_4a8d5.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Artesia',
#       'brewery_state': 'NM',
#       'lat': 32.9294,
#       'lng': -104.438}}},
#    {'brewery': {'brewery_id': 140190,
#      'beer_count': 2,
#      'brewery_name': 'Pine Creek Brewing & Logging Co (Homebrew)',
#      'brewery_slug': 'pine-creek-brewing-and-logging-co',
#      'brewery_page_url': '/w/pine-creek-brewing-logging-co/140190',
#      'brewery_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-brewery-default.png',
#      'country_name': 'United States',
#      'location': {'brewery_city': '',
#       'brewery_state': '',
#       'lat': 0,
#       'lng': 0}}}]},
#  {'Name': 'NLand Surf Park',
#   'Street Address': 4836,
#   'Road': 'HWY 71 EAST',
#   'City': 'DEL VALLE',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '8/7/2017',
#   'Status': 'Open',
#   'untappd': [{'no_results': True}]},
#  {'Name': 'Oak Cliff Brewing Company',
#   'Street Address': 1300,
#   'Road': 'S POLK STREET SUITE 222',
#   'City': 'DALLAS',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '4/4/2018',
#   'Status': 'Open',
#   'untappd': [{'no_results': True}]},
#  {'Name': 'Oak Highlands Brewery',
#   'Street Address': 10484,
#   'Road': 'BROCKWOOD ROAD',
#   'City': 'DALLAS',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '5/18/2015',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 65272,
#      'beer_count': 110,
#      'brewery_name': 'Oak Highlands Brewery',
#      'brewery_slug': 'oak-highlands-brewery',
#      'brewery_page_url': '/OakHighlands',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-65272_4b2d5.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Dallas',
#       'brewery_state': 'TX',
#       'lat': 32.8901,
#       'lng': -96.7046}}}]},
#  {'Name': 'Old Town Brewhouse',
#   'Street Address': 146,
#   'Road': 'WHATLEY AVENUE',
#   'City': 'LEWISVILLE',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '11/4/2013',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 71438,
#      'beer_count': 41,
#      'brewery_name': 'Old Town BrewHouse',
#      'brewery_slug': 'old-town-brewhouse',
#      'brewery_page_url': '/OldTownBrewHouse',
#      'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-71438_f9671.jpeg',
#      'country_name': 'United States',
#      'location': {'brewery_city': 'Lewisville',
#       'brewery_state': 'TX',
#       'lat': 33.0437,
#       'lng': -96.9932}}}]},
#  {'Name': 'Orf Brewing',
#   'Street Address': 4700,
#   'Road': 'BURLESON ROAD UNIT F',
#   'City': 'AUSTIN',
#   'State': 'TX',
#   'Brewery License': 'Brewery',
#   'License Date': '1/6/2016',
#   'Status': 'Open',
#   'untappd': [{'brewery': {'brewery_id': 16504,
#      'beer_count': 17,
#      'brewery_name': 'Orf Brewing',
# ...
#   'License Date': '10/27/2014',
#   'Status': 'Open'},
#  {'Name': 'Roadmap Brewing',
#   'Street Address': '723',
#   'Road': 'N ALAMO STREET SUITES 102-04',
#   'City': 'SAN ANTONIO',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '6/15/2018',
#   'Status': 'Open'},
#  {'Name': 'Root Cellar Cafe',
#   'Street Address': '215',
#   'Road': 'N LBJ',
#   'City': 'SAN MARCOS',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '5/1/2008',
#   'Status': 'Open'},
#  {'Name': 'Rough Diamond Brewery',
#   'Street Address': '101',
#   'Road': 'KENDALIA CIRCLE',
#   'City': 'SPRING BRANCH',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '1/17/2018',
#   'Status': 'Open'},
#  {'Name': 'Roughhouse Brewing',
#   'Street Address': '612',
#   'Road': 'OAKWOOD LOOP',
#   'City': 'SAN MARCOS',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '9/27/2018',
#   'Status': 'Open'},
#  {'Name': 'Ruggedman Brewing Company',
#   'Street Address': '7600',
#   'Road': 'OLD BASTROP ROAD',
#   'City': 'NEW BRAUNFELS',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '8/30/2016',
#   'Status': 'Open'},
#  {'Name': 'Saloon Door Brewing',
#   'Street Address': '105',
#   'Road': 'MAGELLAN CIRCLE SUITE A',
#   'City': 'WEBSTER',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '1/20/2016',
#   'Status': 'Open'},
#  {'Name': 'San Gabriel River Brewery Inc.',
#   'Street Address': '500',
#   'Road': 'CHAPARRAL DRIVE',
#   'City': 'LIBERTY HILL',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '7/7/2015',
#   'Status': 'Open'},
#  {'Name': 'Save The World Brewing Co.',
#   'Street Address': '1510',
#   'Road': 'RESOURCE PARKWAY',
#   'City': 'MARBLE FALLS',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '9/29/2017',
#   'Status': 'Open'},
#  {'Name': "Sean Patrick's",
#   'Street Address': '202',
#   'Road': 'E SAN ANTONIO SUITE 119',
#   'City': 'SAN MARCOS',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '10/4/2010',
#   'Status': 'Open'},
#  {'Name': 'Seguin Brewing Company',
#   'Street Address': '111',
#   'Road': 'W GONZALES STREET',
#   'City': 'SEGUIN',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '8/1/2016',
#   'Status': 'Open'},
#  {'Name': 'Shannon Brewing Company',
#   'Street Address': '818',
#   'Road': 'N MAIN STREET',
#   'City': 'KELLER',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '3/30/2016',
#   'Status': 'Open'},
#  {'Name': 'Sigma Brewing Company',
#   'Street Address': '3118',
#   'Road': "HARRISBURG BOULEVARD '108'",
#   'City': 'HOUSTON',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '6/5/2017',
#   'Status': 'Open'},
#  {'Name': 'Six Brothers Brewing',
#   'Street Address': '957',
#   'Road': 'N 2ND STREET',
#   'City': 'ABILENE',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '4/24/2019',
#   'Status': 'Open'},
#  {'Name': 'Six Car Pub & Brewery',
#   'Street Address': '625',
#   'Road': 'S POLK STREET',
#   'City': 'AMARILLO',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '8/22/2017',
#   'Status': 'Open'},
#  {'Name': 'Skull Mechanix Brewing',
#   'Street Address': '1005',
#   'Road': 'E SAINT ELMO ROAD BUILDING 2',
#   'City': 'AUSTIN',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '1/12/2017',
#   'Status': 'Open'},
#  {'Name': 'Small Brewpub',
#   'Street Address': '333',
#   'Road': 'W JEFFERSON BOULEVARD',
#   'City': 'DALLAS',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '9/24/2014',
#   'Status': 'Open'},
#  {'Name': 'Sockdolager Brewing Company',
#   'Street Address': '720',
#   'Road': 'CHINA STREET',
#   'City': 'ABILENE',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '9/1/2016',
#   'Status': 'Open'},
#  {'Name': 'Soco Taphouse',
#   'Street Address': '113',
#   'Road': 'E CONCHO AVENUE SUITE L',
#   'City': 'SAN ANGELO',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '3/10/2015',
#   'Status': 'Open'},
#  {'Name': 'Soul Fire Brewing Company',
#   'Street Address': '206',
#   'Road': 'N OAK STREET SUITE A',
#   'City': 'ROANOKE',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '10/11/2018',
#   'Status': 'In the works'},
#  {'Name': 'Southerleigh Fine Food And Brewery',
#   'Street Address': '136',
#   'Road': 'E GRAYSON SUITE 120',
#   'City': 'SAN ANTONIO',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '11/3/2014',
#   'Status': 'Open'},
#  {'Name': 'Southern Heights Brewing Co',
#   'Street Address': '6014',
#   'Road': 'TECHNI CENTER DRIVE',
#   'City': 'AUSTIN',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '9/1/2017',
#   'Status': 'Open'},
#  {'Name': 'Southern Roots Brewing Co.',
#   'Street Address': '219',
#   'Road': 'N 8TH STREET',
#   'City': 'WACO',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '2/7/2019',
#   'Status': 'In the works'},
#  {'Name': 'Southern Yankee Beer Company',
#   'Street Address': '930',
#   'Road': 'FM 1960 SUITE G',
#   'City': 'HOUSTON',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '8/14/2018',
#   'Status': 'Open'},
#  {'Name': 'Spindle Tap Brewery Llc',
#   'Street Address': '10622',
#   'Road': 'HIRSCH ROAD BUILDING B',
#   'City': 'HOUSTON',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '4/14/2016',
#   'Status': 'Open'},
#  {'Name': 'St Elmo Brewing Company',
#   'Street Address': '440',
#   'Road': 'E SAINT ELMO ROAD SUITE G2',
#   'City': 'AUSTIN',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '4/22/2016',
#   'Status': 'Open'},
#  {'Name': 'Steam Theory Brewing Company',
#   'Street Address': '340',
#   'Road': 'SINGLETON BOULEVARD SUITE 100',
#   'City': 'DALLAS',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '2/28/2018',
#   'Status': 'Open'},
#  {'Name': 'Struggle Street Brewing Company',
#   'Street Address': '2140',
#   'Road': 'CALDER AVENUE',
#   'City': 'BEAUMONT',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '4/15/2019',
#   'Status': nan},
#  {'Name': 'Suds Monkey Brewing Company',
#   'Street Address': '1032',
#   'Road': 'CANYON BEND DRIVE',
#   'City': 'DRIPPING SPRINGS',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '5/13/2016',
#   'Status': 'Open'},
#  {'Name': 'Sun Brewing Company',
#   'Street Address': '101',
#   'Road': 'LA UNION ROAD',
#   'City': 'CANUTILLO',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '4/23/2014',
#   'Status': 'Open'},
#  {'Name': 'Symposium Brewpub',
#   'Street Address': '310',
#   'Road': '19TH STREET',
#   'City': 'GALVESTON',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '1/15/2019',
#   'Status': 'Open'},
#  {'Name': 'Tall City Brewing Co.',
#   'Street Address': '3303',
#   'Road': 'W GOLF COURSE ROAD',
#   'City': 'MIDLAND',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '11/27/2018',
#   'Status': 'Open'},
#  {'Name': 'Texas Beer Company',
#   'Street Address': '1331',
#   'Road': 'W 2ND STREET',
#   'City': 'TAYLOR',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '8/7/2017',
#   'Status': 'Open'},
#  {'Name': 'Texas Beer Refinery',
#   'Street Address': '1825',
#   'Road': "FM 1266 'B'",
#   'City': 'DICKINSON',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '9/5/2014',
#   'Status': 'Open'},
#  {'Name': 'Texas Leaguer Brewing Company',
#   'Street Address': '13503',
#   'Road': 'PIKE ROAD SUITE 100',
#   'City': 'MISSOURI CITY',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '8/18/2017',
#   'Status': 'Open'},
#  {'Name': 'The Austin Beer Garden Brewing Company',
#   'Street Address': '1305',
#   'Road': 'W OLTORF STREET SUITE 200',
#   'City': 'AUSTIN',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '4/4/2013',
#   'Status': 'Open'},
#  {'Name': 'The Black Star Co-Op',
#   'Street Address': '7020',
#   'Road': 'EASY WIND DRIVE SUITE 100',
#   'City': 'AUSTIN',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '11/9/2017',
#   'Status': 'Open'},
#  {'Name': 'The Blue Onion',
#   'Street Address': '423',
#   'Road': 'S INTERNATIONAL BOULEVARD',
#   'City': 'WESLACO',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '4/3/2007',
#   'Status': 'Open'},
#  {'Name': 'The Brewery',
#   'Street Address': '429',
#   'Road': 'N ALISTER STREET',
#   'City': 'PORT ARANSAS',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '12/17/2015',
#   'Status': 'Open'},
#  {'Name': 'The Brewery Lbk',
#   'Street Address': '1204',
#   'Road': 'BROADWAY',
#   'City': 'LUBBOCK',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '10/20/2014',
#   'Status': 'Open'},
#  {'Name': 'The Brewtorium',
#   'Street Address': '6015',
#   'Road': 'DILLARD CIRCLE SUITE A',
#   'City': 'AUSTIN',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '4/3/2017',
#   'Status': 'Open'},
#  {'Name': 'The Collective Brewing Project',
#   'Street Address': '112',
#   'Road': 'ST LOUIS AVENUE',
#   'City': 'FORT WORTH',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '8/14/2014',
#   'Status': 'Open'},
#  {'Name': 'The Dodging Duck Brewhaus',
#   'Street Address': '402',
#   'Road': 'RIVER ROAD',
#   'City': 'BOERNE',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '2/5/2002',
#   'Status': 'Open'},
#  {'Name': 'The Draught House Pub',
#   'Street Address': '4112',
#   'Road': 'MEDICAL PARKWAY 1ST FLOOR',
#   'City': 'AUSTIN',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '4/6/1999',
#   'Status': 'Open'},
#  {'Name': 'The Faust Hotel & Brewing Co.',
#   'Street Address': '499',
#   'Road': 'S CASTELL AVENUE',
#   'City': 'NEW BRAUNFELS',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '1/14/2015',
#   'Status': 'Open'},
#  {'Name': 'The Moon Tower Inn',
#   'Street Address': '3004',
#   'Road': 'CANAL STREET',
#   'City': 'HOUSTON',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '8/19/2010',
#   'Status': 'Open'},
#  {'Name': 'The Phoenix On Westheimer',
#   'Street Address': '1915',
#   'Road': 'WESTHEIMER ROAD',
#   'City': 'HOUSTON',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '1/11/2007',
#   'Status': 'Open'},
#  {'Name': 'The Shade Tree Saloon And Grill',
#   'Street Address': '13430',
#   'Road': 'HWY 281 NORTH',
#   'City': 'SPRING BRANCH',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '7/26/2016',
#   'Status': 'Open'},
#  {'Name': 'The Triple J Chophouse & Brew Co.',
#   'Street Address': '1807',
#   'Road': 'BUDDY HOLLY AVENUE',
#   'City': 'LUBBOCK',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '8/4/2006',
#   'Status': 'Open'},
#  {'Name': 'Three Nails Brewery',
#   'Street Address': '212',
#   'Road': 'N OAK',
#   'City': 'ROANOKE',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '3/13/2018',
#   'Status': 'In the works'},
#  {'Name': 'TKO Libations',
#   'Street Address': '2520',
#   'Road': "KING ARTHUR BOULEVARD '109'",
#   'City': 'LEWISVILLE',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '2/14/2017',
#   'Status': 'Open'},
#  {'Name': 'Truck Yard/Beard Science',
#   'Street Address': '5959',
#   'Road': 'GROVE LANE',
#   'City': 'THE COLONY',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '11/8/2018',
#   'Status': 'In the works'},
#  {'Name': 'True Anomaly Brewing Company',
#   'Street Address': '2012',
#   'Road': 'DALLAS STREET',
#   'City': 'HOUSTON',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '10/16/2018',
#   'Status': 'Open'},
#  {'Name': 'Turning Point Beer',
#   'Street Address': '1307',
#   'Road': 'BROWN TRAIL',
#   'City': 'BEDFORD',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '1/12/2018',
#   'Status': 'Open'},
#  {'Name': 'Tusculum Brewing Company',
#   'Street Address': '236',
#   'Road': 'S MAIN STREET',
#   'City': 'BOERNE',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '8/13/2018',
#   'Status': 'Open'},
#  {'Name': 'Twin Peaks',
#   'Street Address': '1500',
#   'Road': 'MARKET PLACE',
#   'City': 'IRVING',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '3/19/2013',
#   'Status': 'Open'},
#  {'Name': 'Twisted Acre Brewery',
#   'Street Address': '16103',
#   'Road': 'GRANT ROAD SPACE J',
#   'City': 'CYPRESS',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '2/8/2018',
#   'Status': 'Open'},
#  {'Name': 'Two Wheel Brewing Company',
#   'Street Address': '535',
#   'Road': 'LOOP 4 SOUTH',
#   'City': 'BUDA',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '10/27/2016',
#   'Status': 'Open'},
#  {'Name': "Uncle Buck's Brewery & Steak House",
#   'Street Address': '2501',
#   'Road': 'BASS PRO DRIVE SUITE 100',
#   'City': 'GRAPEVINE',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '4/27/2007',
#   'Status': 'Open'},
#  {'Name': 'Union Bear',
#   'Street Address': '5880',
#   'Road': 'HWY 121 SUITE 101',
#   'City': 'PLANO',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '7/28/2017',
#   'Status': 'Open'},
#  {'Name': 'Unlawful Assembly Brewing',
#   'Street Address': '7800',
#   'Road': 'WINDROSE AVENUE',
#   'City': 'PLANO',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '9/22/2017',
#   'Status': 'Open'},
#  {'Name': 'Vallensons Brewing Company',
#   'Street Address': '4081',
#   'Road': 'RICE DRIER ROAD',
#   'City': 'PEARLAND',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '1/10/2017',
#   'Status': 'Open'},
#  {'Name': 'Vista Brewing',
#   'Street Address': '13551',
#   'Road': 'FM 150 WEST',
#   'City': 'DRIFTWOOD',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '1/5/2018',
#   'Status': 'Open'},
#  {'Name': 'Waco Ale Company',
#   'Street Address': '806',
#   'Road': 'AUSTIN AVENUE',
#   'City': 'WACO',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '12/12/2018',
#   'Status': 'In the works'},
#  {'Name': 'Walking Beam Brewing Co.',
#   'Street Address': '1019',
#   'Road': 'HALSELL STREET',
#   'City': 'BRIDGEPORT',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '11/6/2018',
#   'Status': 'Open'},
#  {'Name': 'Walking Stick Brewing Company Inc',
#   'Street Address': '956',
#   'Road': 'JUDIWAY STREET',
#   'City': 'HOUSTON',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '10/25/2016',
#   'Status': 'Open'},
#  {'Name': 'Weathered Souls Brewing Company',
#   'Street Address': '606',
#   'Road': 'EMBASSY OAKS SUITES 350 & 500',
#   'City': 'SAN ANTONIO',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '5/17/2016',
#   'Status': 'Open'},
#  {'Name': 'White Rock Alehouse & Brewery',
#   'Street Address': '7331',
#   'Road': 'GASTON AVENUE SUITE 100',
#   'City': 'DALLAS',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '43048',
#   'Status': 'Open'},
#  {'Name': 'Whitestone Brewery',
#   'Street Address': '601',
#   'Road': 'E WHITESTONE BOULEVARD',
#   'City': 'CEDAR PARK',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '42151',
#   'Status': 'Open'},
#  {'Name': 'Whole Foods Market Brewing Company',
#   'Street Address': '1700',
#   'Road': 'POST OAK BOULEVARD',
#   'City': 'HOUSTON',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '41779',
#   'Status': 'Open'},
#  {'Name': 'Wichita Falls Brewing Company',
#   'Street Address': '701',
#   'Road': 'INDIANA AVENUE',
#   'City': 'WICHITA FALLS',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '42801',
#   'Status': 'Open'},
#  {'Name': 'Wicked Boxer Brewing',
#   'Street Address': '16326',
#   'Road': 'MUESCHKE SUITE E-10',
#   'City': 'CYPRESS',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '42906',
#   'Status': 'Open'},
#  {'Name': 'Wimberley Brewing Company',
#   'Street Address': '9595',
#   'Road': 'RR 12 SUITE 9',
#   'City': 'WIMBERLEY',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '39517',
#   'Status': 'Open'},
#  {'Name': 'Zero One Ale House',
#   'Street Address': '20',
#   'Road': 'W BEAUREGARD AVENUE',
#   'City': 'SAN ANGELO',
#   'State': 'TX',
#   'Brewery License': 'Brewpub',
#   'License Date': '40941',
#   'Status': 'Open'}]
